# %%
import pandas as pd

fname = "test1_copycopy_O1n2_output.csv"
try:
    df12 = pd.read_csv(fname)
    if 'experiment' in df12.columns:
        df12['experiment'] = df12['experiment'].astype(str).str.replace(
            r"(fisher)(?!_O1n2)", r"\1_O1n2", regex=True
        )
    # print(df12.to_string(index=False))
except FileNotFoundError:
    print(f"File not found: {fname}")
except Exception as e:
    print("Error reading file:", e)

fname = "test1_copycopy_Fonly_output.csv"
try:
    dfF = pd.read_csv(fname)
    if 'experiment' in dfF.columns:
        dfF['experiment'] = dfF['experiment'].astype(str).str.replace(
            r"(fisher)(?!_Fonly)", r"\1_Fonly", regex=True
        )
    # print(dfF.to_string(index=False))
except FileNotFoundError:
    print(f"File not found: {fname}")
except Exception as e:
    print("Error reading file:", e)

df = pd.concat([df12, dfF])
print(df.to_string(index=False))
# Out:
#                     experiment  epoch  train_loss  test_accuracy
#        resnet101_baseline_adam      0    0.310267          95.60
#        resnet101_baseline_adam      1    0.094525          97.57
#        resnet101_baseline_adam      2    0.109089          96.19
#        resnet101_baseline_adam      3    0.108679          98.47
#        resnet101_baseline_adam      4    0.049943          98.60
#        resnet101_baseline_adam      5    0.042636          98.74
#        resnet101_baseline_adam      6    0.043132          87.71
#        resnet101_baseline_adam      7    0.078077          98.68
#        resnet101_baseline_adam      8    0.045206          98.82
#        resnet101_baseline_adam      9    0.081834          96.90
#     resnet101_baseline_rmsprop      0    0.501073          90.43
#     resnet101_baseline_rmsprop      1    0.135604          98.05
#     resnet101_baseline_rmsprop      2    0.107219          98.20
#     resnet101_baseline_rmsprop      3    0.113435          98.30
#     resnet101_baseline_rmsprop      4    0.101561          98.45
#     resnet101_baseline_rmsprop      5    0.072818          98.97
#     resnet101_baseline_rmsprop      6    0.048520          99.09
#     resnet101_baseline_rmsprop      7    0.043705          99.18
#     resnet101_baseline_rmsprop      8    0.052300          99.14
#     resnet101_baseline_rmsprop      9    0.035339          99.17
#         resnet101_baseline_sgd      0    1.663662          75.88
#         resnet101_baseline_sgd      1    0.578183          88.62
#         resnet101_baseline_sgd      2    0.328172          92.98
#         resnet101_baseline_sgd      3    0.230310          94.55
#         resnet101_baseline_sgd      4    0.180214          95.54
#         resnet101_baseline_sgd      5    0.148573          96.08
#         resnet101_baseline_sgd      6    0.124959          96.63
#         resnet101_baseline_sgd      7    0.107377          96.85
#         resnet101_baseline_sgd      8    0.091706          97.03
#         resnet101_baseline_sgd      9    0.081777          97.16
#     resnet101_fisher_O1n2_adam      0    0.546211          97.03
#     resnet101_fisher_O1n2_adam      1    0.274194          97.78
#     resnet101_fisher_O1n2_adam      2    0.247512          98.05
#     resnet101_fisher_O1n2_adam      3    0.200905          98.48
#     resnet101_fisher_O1n2_adam      4    0.174127          98.86
#     resnet101_fisher_O1n2_adam      5    0.170149          98.91
#     resnet101_fisher_O1n2_adam      6    0.155368          98.97
#     resnet101_fisher_O1n2_adam      7    0.152272          98.24
#     resnet101_fisher_O1n2_adam      8    0.140965          99.19
#     resnet101_fisher_O1n2_adam      9    0.129978          99.00
#  resnet101_fisher_O1n2_rmsprop      0    0.893595          91.89
#  resnet101_fisher_O1n2_rmsprop      1    0.319124          96.86
#  resnet101_fisher_O1n2_rmsprop      2    0.222579          98.78
#  resnet101_fisher_O1n2_rmsprop      3    0.169485          98.75
#  resnet101_fisher_O1n2_rmsprop      4    0.142383          99.07
#  resnet101_fisher_O1n2_rmsprop      5    0.135313          98.38
#  resnet101_fisher_O1n2_rmsprop      6    0.111451          98.65
#  resnet101_fisher_O1n2_rmsprop      7    0.097487          98.99
#  resnet101_fisher_O1n2_rmsprop      8    0.094574          99.25
#  resnet101_fisher_O1n2_rmsprop      9    0.087477          99.04
#      resnet101_fisher_O1n2_sgd      0    2.212217          22.97
#      resnet101_fisher_O1n2_sgd      1    1.967690          33.09
#      resnet101_fisher_O1n2_sgd      2    1.824498          36.24
#      resnet101_fisher_O1n2_sgd      3    1.716324          35.44
#      resnet101_fisher_O1n2_sgd      4    1.600599          51.26
#      resnet101_fisher_O1n2_sgd      5    1.442031          51.77
#      resnet101_fisher_O1n2_sgd      6    1.300452          59.19
#      resnet101_fisher_O1n2_sgd      7    1.167884          55.45
#      resnet101_fisher_O1n2_sgd      8    1.045376          69.73
#      resnet101_fisher_O1n2_sgd      9    0.925081          80.08
#         resnet18_baseline_adam      0    0.134467          98.29
#         resnet18_baseline_adam      1    0.060481          98.55
#         resnet18_baseline_adam      2    0.044576          98.57
#         resnet18_baseline_adam      3    0.039785          99.02
#         resnet18_baseline_adam      4    0.031318          98.87
#         resnet18_baseline_adam      5    0.028978          99.06
#         resnet18_baseline_adam      6    0.024538          99.28
#         resnet18_baseline_adam      7    0.023200          99.33
#         resnet18_baseline_adam      8    0.019885          99.07
#         resnet18_baseline_adam      9    0.020237          99.02
#      resnet18_baseline_rmsprop      0    0.164924          90.89
#      resnet18_baseline_rmsprop      1    0.069751          98.49
#      resnet18_baseline_rmsprop      2    0.047548          97.90
#      resnet18_baseline_rmsprop      3    0.036427          99.18
#      resnet18_baseline_rmsprop      4    0.030642          99.14
#      resnet18_baseline_rmsprop      5    0.024932          99.19
#      resnet18_baseline_rmsprop      6    0.022068          98.88
#      resnet18_baseline_rmsprop      7    0.018439          99.25
#      resnet18_baseline_rmsprop      8    0.016632          98.78
#      resnet18_baseline_rmsprop      9    0.015264          99.31
#          resnet18_baseline_sgd      0    0.556311          94.30
#          resnet18_baseline_sgd      1    0.171748          96.31
#          resnet18_baseline_sgd      2    0.116471          97.07
#          resnet18_baseline_sgd      3    0.087915          97.44
#          resnet18_baseline_sgd      4    0.071788          97.55
#          resnet18_baseline_sgd      5    0.059959          97.76
#          resnet18_baseline_sgd      6    0.049612          97.84
#          resnet18_baseline_sgd      7    0.042250          97.99
#          resnet18_baseline_sgd      8    0.035759          97.94
#          resnet18_baseline_sgd      9    0.031148          98.02
#      resnet18_fisher_O1n2_adam      0    0.181458          98.25
#      resnet18_fisher_O1n2_adam      1    0.067370          98.79
#      resnet18_fisher_O1n2_adam      2    0.051851          98.75
#      resnet18_fisher_O1n2_adam      3    0.044396          98.79
#      resnet18_fisher_O1n2_adam      4    0.039354          98.81
#      resnet18_fisher_O1n2_adam      5    0.036401          99.13
#      resnet18_fisher_O1n2_adam      6    0.028913          99.26
#      resnet18_fisher_O1n2_adam      7    0.029174          99.25
#      resnet18_fisher_O1n2_adam      8    0.024914          99.42
#      resnet18_fisher_O1n2_adam      9    0.023354          99.51
#   resnet18_fisher_O1n2_rmsprop      0    0.363534          94.69
#   resnet18_fisher_O1n2_rmsprop      1    0.097890          98.91
#   resnet18_fisher_O1n2_rmsprop      2    0.068540          99.04
#   resnet18_fisher_O1n2_rmsprop      3    0.057918          98.94
#   resnet18_fisher_O1n2_rmsprop      4    0.052370          98.79
#   resnet18_fisher_O1n2_rmsprop      5    0.042213          99.37
#   resnet18_fisher_O1n2_rmsprop      6    0.038493          99.40
#   resnet18_fisher_O1n2_rmsprop      7    0.034682          99.41
#   resnet18_fisher_O1n2_rmsprop      8    0.032217          99.52
#   resnet18_fisher_O1n2_rmsprop      9    0.026516          99.41
#       resnet18_fisher_O1n2_sgd      0    2.225844          34.69
#       resnet18_fisher_O1n2_sgd      1    1.948770          42.18
#       resnet18_fisher_O1n2_sgd      2    1.732439          54.58
#       resnet18_fisher_O1n2_sgd      3    1.481571          71.22
#       resnet18_fisher_O1n2_sgd      4    1.112671          81.79
#       resnet18_fisher_O1n2_sgd      5    0.801054          86.45
#       resnet18_fisher_O1n2_sgd      6    0.594038          92.99
#       resnet18_fisher_O1n2_sgd      7    0.458650          90.81
#       resnet18_fisher_O1n2_sgd      8    0.368453          79.62
#       resnet18_fisher_O1n2_sgd      9    0.309295          91.34
#         resnet50_baseline_adam      0    0.243791          96.57
#         resnet50_baseline_adam      1    0.089117          98.43
#         resnet50_baseline_adam      2    0.079501          76.69
#         resnet50_baseline_adam      3    0.161366          98.12
#         resnet50_baseline_adam      4    0.158675          98.39
#         resnet50_baseline_adam      5    0.091277          98.00
#         resnet50_baseline_adam      6    0.119997          95.47
#         resnet50_baseline_adam      7    0.075925          98.70
#         resnet50_baseline_adam      8    0.048684          98.83
#         resnet50_baseline_adam      9    0.037067          98.76
#      resnet50_baseline_rmsprop      0    0.329387          96.76
#      resnet50_baseline_rmsprop      1    0.146020          98.29
#      resnet50_baseline_rmsprop      2    0.121024          98.25
#      resnet50_baseline_rmsprop      3    0.096073          91.47
#      resnet50_baseline_rmsprop      4    0.053794          98.02
#      resnet50_baseline_rmsprop      5    0.057887          99.11
#      resnet50_baseline_rmsprop      6    0.044421          99.27
#      resnet50_baseline_rmsprop      7    0.035765          99.15
#      resnet50_baseline_rmsprop      8    0.035533          99.20
#      resnet50_baseline_rmsprop      9    0.034727          98.97
#          resnet50_baseline_sgd      0    1.440893          83.35
#          resnet50_baseline_sgd      1    0.403673          92.04
#          resnet50_baseline_sgd      2    0.243275          94.45
#          resnet50_baseline_sgd      3    0.174298          95.51
#          resnet50_baseline_sgd      4    0.135981          96.08
#          resnet50_baseline_sgd      5    0.106062          96.46
#          resnet50_baseline_sgd      6    0.090304          96.91
#          resnet50_baseline_sgd      7    0.075256          96.99
#          resnet50_baseline_sgd      8    0.061234          97.23
#          resnet50_baseline_sgd      9    0.051580          97.34
#      resnet50_fisher_O1n2_adam      0    0.421824          96.94
#      resnet50_fisher_O1n2_adam      1    0.167345          98.54
#      resnet50_fisher_O1n2_adam      2    0.131673          98.79
#      resnet50_fisher_O1n2_adam      3    0.111154          98.21
#      resnet50_fisher_O1n2_adam      4    0.096021          98.43
#      resnet50_fisher_O1n2_adam      5    0.090362          99.07
#      resnet50_fisher_O1n2_adam      6    0.083728          98.79
#      resnet50_fisher_O1n2_adam      7    0.074391          99.22
#      resnet50_fisher_O1n2_adam      8    0.069903          98.87
#      resnet50_fisher_O1n2_adam      9    0.064695          98.86
#   resnet50_fisher_O1n2_rmsprop      0    0.719557          79.78
#   resnet50_fisher_O1n2_rmsprop      1    0.235725          95.51
#   resnet50_fisher_O1n2_rmsprop      2    0.169570          97.66
#   resnet50_fisher_O1n2_rmsprop      3    0.144212          98.20
#   resnet50_fisher_O1n2_rmsprop      4    0.119821          98.94
#   resnet50_fisher_O1n2_rmsprop      5    0.114526          99.27
#   resnet50_fisher_O1n2_rmsprop      6    0.103541          98.57
#   resnet50_fisher_O1n2_rmsprop      7    0.091551          98.94
#   resnet50_fisher_O1n2_rmsprop      8    0.084231          99.17
#   resnet50_fisher_O1n2_rmsprop      9    0.071902          99.21
#       resnet50_fisher_O1n2_sgd      0    2.174664          25.98
#       resnet50_fisher_O1n2_sgd      1    1.920109          24.57
#       resnet50_fisher_O1n2_sgd      2    1.779738          37.71
#       resnet50_fisher_O1n2_sgd      3    1.649799          46.07
#       resnet50_fisher_O1n2_sgd      4    1.494199          57.81
#       resnet50_fisher_O1n2_sgd      5    1.333475          63.37
#       resnet50_fisher_O1n2_sgd      6    1.192696          64.21
#       resnet50_fisher_O1n2_sgd      7    1.057908          72.79
#       resnet50_fisher_O1n2_sgd      8    0.908991          68.25
#       resnet50_fisher_O1n2_sgd      9    0.762817          83.87
#              vit_baseline_adam      0    2.154691          23.33
#              vit_baseline_adam      1    1.963315          24.91
#              vit_baseline_adam      2    1.957887          27.94
#              vit_baseline_adam      3    1.978693          26.66
#              vit_baseline_adam      4    1.939506          25.95
#              vit_baseline_adam      5    1.971854          26.33
#              vit_baseline_adam      6    2.080110          21.81
#              vit_baseline_adam      7    1.982840          23.41
#              vit_baseline_adam      8    1.956590          27.82
#              vit_baseline_adam      9    2.004313          22.24
#           vit_baseline_rmsprop      0    2.297034          24.68
#           vit_baseline_rmsprop      1    2.033370          26.19
#           vit_baseline_rmsprop      2    2.007247          27.46
#           vit_baseline_rmsprop      3    1.969158          22.07
#           vit_baseline_rmsprop      4    1.986463          25.28
#           vit_baseline_rmsprop      5    2.039699          11.09
#           vit_baseline_rmsprop      6    2.012055          26.12
#           vit_baseline_rmsprop      7    2.018183          26.64
#           vit_baseline_rmsprop      8    1.994743          23.39
#           vit_baseline_rmsprop      9    2.007039          26.42
#               vit_baseline_sgd      0    1.606010          45.88
#               vit_baseline_sgd      1    1.108666          67.60
#               vit_baseline_sgd      2    0.852273          75.55
#               vit_baseline_sgd      3    0.665450          77.44
#               vit_baseline_sgd      4    0.514302          75.37
#               vit_baseline_sgd      5    0.392308          82.23
#               vit_baseline_sgd      6    0.304489          91.88
#               vit_baseline_sgd      7    0.252732          77.86
#               vit_baseline_sgd      8    0.208470          90.92
#               vit_baseline_sgd      9    0.178508          93.23
#           vit_fisher_O1n2_adam      0    2.303138          11.35
#           vit_fisher_O1n2_adam      1    2.301312          11.35
#           vit_fisher_O1n2_adam      2    2.301284          11.35
#           vit_fisher_O1n2_adam      3    2.301312          11.35
#           vit_fisher_O1n2_adam      4    2.301335          11.35
#           vit_fisher_O1n2_adam      5    2.301303          11.35
#           vit_fisher_O1n2_adam      6    2.301285          11.35
#           vit_fisher_O1n2_adam      7    2.301340          11.35
#           vit_fisher_O1n2_adam      8    2.301284          11.35
#           vit_fisher_O1n2_adam      9    2.301264          11.35
#        vit_fisher_O1n2_rmsprop      0    2.308317          11.35
#        vit_fisher_O1n2_rmsprop      1    2.301314          11.35
#        vit_fisher_O1n2_rmsprop      2    2.301289          11.35
#        vit_fisher_O1n2_rmsprop      3    2.301286          11.35
#        vit_fisher_O1n2_rmsprop      4    2.301298          11.35
#        vit_fisher_O1n2_rmsprop      5    2.301309          11.35
#        vit_fisher_O1n2_rmsprop      6    2.301312          11.35
#        vit_fisher_O1n2_rmsprop      7    2.301307          11.35
#        vit_fisher_O1n2_rmsprop      8    2.301299          11.35
#        vit_fisher_O1n2_rmsprop      9    2.301293          11.35
#            vit_fisher_O1n2_sgd      0    1.774811          54.16
#            vit_fisher_O1n2_sgd      1    1.331056          53.49
#            vit_fisher_O1n2_sgd      2    1.090909          63.05
#            vit_fisher_O1n2_sgd      3    0.906183          74.57
#            vit_fisher_O1n2_sgd      4    0.737497          79.02
#            vit_fisher_O1n2_sgd      5    0.591691          84.21
#            vit_fisher_O1n2_sgd      6    0.491297          88.21
#            vit_fisher_O1n2_sgd      7    0.399983          88.52
#            vit_fisher_O1n2_sgd      8    0.342638          89.45
#            vit_fisher_O1n2_sgd      9    0.298419          89.08
#    resnet101_fisher_Fonly_adam      0    0.539075          96.19
#    resnet101_fisher_Fonly_adam      1    0.224284          97.94
#    resnet101_fisher_Fonly_adam      2    0.168821          98.47
#    resnet101_fisher_Fonly_adam      3    0.148502          98.12
#    resnet101_fisher_Fonly_adam      4    0.133084          98.82
#    resnet101_fisher_Fonly_adam      5    0.114848          98.70
#    resnet101_fisher_Fonly_adam      6    0.116431          99.22
#    resnet101_fisher_Fonly_adam      7    0.106159          98.85
#    resnet101_fisher_Fonly_adam      8    0.096791          99.22
#    resnet101_fisher_Fonly_adam      9    0.093266          99.21
# resnet101_fisher_Fonly_rmsprop      0    0.951167          60.42
# resnet101_fisher_Fonly_rmsprop      1    0.327364          94.54
# resnet101_fisher_Fonly_rmsprop      2    0.243122          98.57
# resnet101_fisher_Fonly_rmsprop      3    0.194289          98.74
# resnet101_fisher_Fonly_rmsprop      4    0.166426          98.48
# resnet101_fisher_Fonly_rmsprop      5    0.144687          95.96
# resnet101_fisher_Fonly_rmsprop      6    0.131857          99.14
# resnet101_fisher_Fonly_rmsprop      7    0.112535          98.98
# resnet101_fisher_Fonly_rmsprop      8    0.106667          99.23
# resnet101_fisher_Fonly_rmsprop      9    0.101430          98.41
#     resnet101_fisher_Fonly_sgd      0    2.180214          25.63
#     resnet101_fisher_Fonly_sgd      1    1.946665          32.23
#     resnet101_fisher_Fonly_sgd      2    1.816157          39.02
#     resnet101_fisher_Fonly_sgd      3    1.720177          38.48
#     resnet101_fisher_Fonly_sgd      4    1.595327          46.95
#     resnet101_fisher_Fonly_sgd      5    1.451713          34.52
#     resnet101_fisher_Fonly_sgd      6    1.302704          43.44
#     resnet101_fisher_Fonly_sgd      7    1.169203          66.99
#     resnet101_fisher_Fonly_sgd      8    1.044649          68.72
#     resnet101_fisher_Fonly_sgd      9    0.910596          78.99
#     resnet18_fisher_Fonly_adam      0    0.180853          97.04
#     resnet18_fisher_Fonly_adam      1    0.065905          98.42
#     resnet18_fisher_Fonly_adam      2    0.051808          98.48
#     resnet18_fisher_Fonly_adam      3    0.044992          98.58
#     resnet18_fisher_Fonly_adam      4    0.038564          99.40
#     resnet18_fisher_Fonly_adam      5    0.036630          99.36
#     resnet18_fisher_Fonly_adam      6    0.029515          99.24
#     resnet18_fisher_Fonly_adam      7    0.027678          98.91
#     resnet18_fisher_Fonly_adam      8    0.026023          99.49
#     resnet18_fisher_Fonly_adam      9    0.022382          99.34
#  resnet18_fisher_Fonly_rmsprop      0    0.404223          98.32
#  resnet18_fisher_Fonly_rmsprop      1    0.104951          98.67
#  resnet18_fisher_Fonly_rmsprop      2    0.073581          98.86
#  resnet18_fisher_Fonly_rmsprop      3    0.060297          99.32
#  resnet18_fisher_Fonly_rmsprop      4    0.051056          98.95
#  resnet18_fisher_Fonly_rmsprop      5    0.044432          99.12
#  resnet18_fisher_Fonly_rmsprop      6    0.040620          99.10
#  resnet18_fisher_Fonly_rmsprop      7    0.034307          99.24
#  resnet18_fisher_Fonly_rmsprop      8    0.033098          99.35
#  resnet18_fisher_Fonly_rmsprop      9    0.029370          99.53
#      resnet18_fisher_Fonly_sgd      0    2.170417          34.74
#      resnet18_fisher_Fonly_sgd      1    1.872334          47.60
#      resnet18_fisher_Fonly_sgd      2    1.655461          63.56
#      resnet18_fisher_Fonly_sgd      3    1.372221          74.67
#      resnet18_fisher_Fonly_sgd      4    1.004566          86.00
#      resnet18_fisher_Fonly_sgd      5    0.717077          91.24
#      resnet18_fisher_Fonly_sgd      6    0.535277          87.38
#      resnet18_fisher_Fonly_sgd      7    0.417793          92.72
#      resnet18_fisher_Fonly_sgd      8    0.342679          94.68
#      resnet18_fisher_Fonly_sgd      9    0.286984          96.01
#     resnet50_fisher_Fonly_adam      0    0.431236          98.11
#     resnet50_fisher_Fonly_adam      1    0.190897          98.11
#     resnet50_fisher_Fonly_adam      2    0.145858          98.28
#     resnet50_fisher_Fonly_adam      3    0.132042          98.24
#     resnet50_fisher_Fonly_adam      4    0.117062          98.90
#     resnet50_fisher_Fonly_adam      5    0.104217          98.41
#     resnet50_fisher_Fonly_adam      6    0.101831          99.16
#     resnet50_fisher_Fonly_adam      7    0.089821          99.19
#     resnet50_fisher_Fonly_adam      8    0.086588          98.60
#     resnet50_fisher_Fonly_adam      9    0.081295          99.28
#  resnet50_fisher_Fonly_rmsprop      0    1.157298          89.74
#  resnet50_fisher_Fonly_rmsprop      1    0.738969          88.28
#  resnet50_fisher_Fonly_rmsprop      2    0.589829          94.21
#  resnet50_fisher_Fonly_rmsprop      3    0.491027          98.61
#  resnet50_fisher_Fonly_rmsprop      4    0.458022          92.57
#  resnet50_fisher_Fonly_rmsprop      5    0.431135          98.80
#  resnet50_fisher_Fonly_rmsprop      6    0.411577          93.13
#  resnet50_fisher_Fonly_rmsprop      7    0.364214          96.59
#  resnet50_fisher_Fonly_rmsprop      8    0.342842          98.86
#  resnet50_fisher_Fonly_rmsprop      9    0.329001          98.63
#      resnet50_fisher_Fonly_sgd      0    2.163879          26.24
#      resnet50_fisher_Fonly_sgd      1    1.893498          35.61
#      resnet50_fisher_Fonly_sgd      2    1.750739          39.81
#      resnet50_fisher_Fonly_sgd      3    1.614866          51.68
#      resnet50_fisher_Fonly_sgd      4    1.443671          62.86
#      resnet50_fisher_Fonly_sgd      5    1.231615          69.73
#      resnet50_fisher_Fonly_sgd      6    1.009486          72.15
#      resnet50_fisher_Fonly_sgd      7    0.821916          81.57
#      resnet50_fisher_Fonly_sgd      8    0.670064          86.54
#      resnet50_fisher_Fonly_sgd      9    0.552476          88.19
#          vit_fisher_Fonly_adam      0    2.303004          11.35
#          vit_fisher_Fonly_adam      1    2.301297          11.35
#          vit_fisher_Fonly_adam      2    2.301283          11.35
#          vit_fisher_Fonly_adam      3    2.301287          11.35
#          vit_fisher_Fonly_adam      4    2.301314          11.35
#          vit_fisher_Fonly_adam      5    2.301305          11.35
#          vit_fisher_Fonly_adam      6    2.301294          11.35
#          vit_fisher_Fonly_adam      7    2.301316          11.35
#          vit_fisher_Fonly_adam      8    2.301309          11.35
#          vit_fisher_Fonly_adam      9    2.301300          11.35
#       vit_fisher_Fonly_rmsprop      0    2.308394          11.35
#       vit_fisher_Fonly_rmsprop      1    2.301303          11.35
#       vit_fisher_Fonly_rmsprop      2    2.301290          11.35
#       vit_fisher_Fonly_rmsprop      3    2.301287          11.35
#       vit_fisher_Fonly_rmsprop      4    2.301306          11.35
#       vit_fisher_Fonly_rmsprop      5    2.301306          11.35
#       vit_fisher_Fonly_rmsprop      6    2.301316          11.35
#       vit_fisher_Fonly_rmsprop      7    2.301262          11.35
#       vit_fisher_Fonly_rmsprop      8    2.301302          11.35
#       vit_fisher_Fonly_rmsprop      9    2.301289          11.35
#           vit_fisher_Fonly_sgd      0    1.816188          45.00
#           vit_fisher_Fonly_sgd      1    1.362341          48.69
#           vit_fisher_Fonly_sgd      2    1.093859          73.24
#           vit_fisher_Fonly_sgd      3    0.878217          60.29
#           vit_fisher_Fonly_sgd      4    0.703696          82.30
#           vit_fisher_Fonly_sgd      5    0.573885          83.53
#           vit_fisher_Fonly_sgd      6    0.464483          88.84
#           vit_fisher_Fonly_sgd      7    0.392953          87.15
#           vit_fisher_Fonly_sgd      8    0.330774          91.80
#           vit_fisher_Fonly_sgd      9    0.296004          93.34

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import colorsys

def _adjust_lightness(color, factor):
    r, g, b = mcolors.to_rgb(color)
    h, l, s = colorsys.rgb_to_hls(r, g, b)
    l = max(0.0, min(1.0, l * factor))
    return colorsys.hls_to_rgb(h, l, s)

def _first_token(experiment_name):
    parts = str(experiment_name).lower().split('_')
    return parts[0:3] if parts else str(experiment_name).lower()

def experiment_color(experiment_name, token_to_base):
    first_token = _first_token(experiment_name)
    is_baseline = 'baseline' in str(experiment_name).lower()

    base = token_to_base[first_token]
    if is_baseline:
        return _adjust_lightness(base, 0.55)  # darker for baseline
    return _adjust_lightness(base, 1.35)      # brighter for non-baseline

# filter experiments containing 'adam'
df_adam = df[df['experiment'].str.contains('adam', case=False, na=False)]

if df_adam.empty:
    print("No experiments with 'adam' found in 'experiment' column.")
else:
    token_order = sorted({str(name).split('_')[0].lower() for name in df_adam['experiment'].unique()})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for name, grp in df_adam.groupby('experiment'):
        color = experiment_color(name, token_to_base)
        axes[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
        axes[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('train_loss')
    axes[0].set_title("Train Loss (experiments containing 'adam')")
    axes[0].legend(fontsize='small', loc='best')
    axes[0].grid(True)

    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('test_accuracy')
    axes[1].set_title("Test Accuracy (experiments containing 'adam')")
    axes[1].legend(fontsize='small', loc='best')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %%
# filter experiments containing 'adam' but exclude any with 'vit'
df_adam_no_vit = df[
    df['experiment'].str.contains('adam', case=False, na=False) &
    ~df['experiment'].str.contains('vit', case=False, na=False)
]

if df_adam_no_vit.empty:
    print("No 'adam' experiments found after excluding ViT.")
else:
    token_order = sorted({_first_token(name) for name in df_adam_no_vit['experiment'].unique()})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for name, grp in df_adam_no_vit.groupby('experiment'):
        color = experiment_color(name, token_to_base)
        axes[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
        axes[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('train_loss')
    axes[0].set_title("Train Loss (adam, excluding ViT)")
    axes[0].legend(fontsize='small', loc='best')
    axes[0].grid(True)

    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('test_accuracy')
    axes[1].set_title("Test Accuracy (adam, excluding ViT)")
    axes[1].legend(fontsize='small', loc='best')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %%
# filter experiments containing 'sgd' but exclude any with 'vit'
df_sgd_no_vit = df[
    df['experiment'].str.contains('sgd', case=False, na=False) &
    ~df['experiment'].str.contains('vit', case=False, na=False)
]

if df_sgd_no_vit.empty:
    print("No 'sgd' experiments found after excluding ViT.")
else:
    token_order = sorted({_first_token(name) for name in df_sgd_no_vit['experiment'].unique()})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for name, grp in df_sgd_no_vit.groupby('experiment'):
        color = experiment_color(name, token_to_base)
        axes[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
        axes[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('train_loss')
    axes[0].set_title("Train Loss (sgd, excluding ViT)")
    axes[0].legend(fontsize='small', loc='best')
    axes[0].grid(True)

    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('test_accuracy')
    axes[1].set_title("Test Accuracy (sgd, excluding ViT)")
    axes[1].legend(fontsize='small', loc='best')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %%
# filter experiments containing 'rmsprop' but exclude any with 'vit'
df_rmsprop_no_vit = df[
    df['experiment'].str.contains('rmsprop', case=False, na=False) &
    ~df['experiment'].str.contains('vit', case=False, na=False)
]

# additional filtered set (excluding res101)
df_rmsprop_no_vit_res101 = df[
    df['experiment'].str.contains('rmsprop', case=False, na=False) &
    ~df['experiment'].str.contains('vit', case=False, na=False) &
    ~df['experiment'].str.contains('resnet101', case=False, na=False)
]

if df_rmsprop_no_vit.empty and df_rmsprop_no_vit_res101.empty:
    print("No 'rmsprop' experiments found after excluding ViT.")
else:
    # shared color mapping across both dataframes (same experiment -> same color)
    all_names = set(df_rmsprop_no_vit['experiment'].unique()).union(
        set(df_rmsprop_no_vit_res101['experiment'].unique())
    )
    token_order = sorted({_first_token(name) for name in all_names})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    # Figure 1: df_rmsprop_no_vit
    if not df_rmsprop_no_vit.empty:
        fig1, axes1 = plt.subplots(1, 2, figsize=(14, 5))
        for name, grp in df_rmsprop_no_vit.groupby('experiment'):
            color = experiment_color(name, token_to_base)
            axes1[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
            axes1[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

        axes1[0].set_xlabel('epoch')
        axes1[0].set_ylabel('train_loss')
        axes1[0].set_title("Train Loss (rmsprop, excluding ViT)")
        axes1[0].legend(fontsize='small', loc='best')
        axes1[0].grid(True)

        axes1[1].set_xlabel('epoch')
        axes1[1].set_ylabel('test_accuracy')
        axes1[1].set_title("Test Accuracy (rmsprop, excluding ViT)")
        axes1[1].legend(fontsize='small', loc='best')
        axes1[1].grid(True)

        plt.tight_layout()
        plt.show()
    else:
        print("df_rmsprop_no_vit is empty.")

    # Figure 2: df_rmsprop_no_vit_res101
    if not df_rmsprop_no_vit_res101.empty:
        fig2, axes2 = plt.subplots(1, 2, figsize=(14, 5))
        for name, grp in df_rmsprop_no_vit_res101.groupby('experiment'):
            color = experiment_color(name, token_to_base)
            axes2[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
            axes2[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

        axes2[0].set_xlabel('epoch')
        axes2[0].set_ylabel('train_loss')
        axes2[0].set_title("Train Loss (rmsprop, excluding ViT and res101)")
        axes2[0].legend(fontsize='small', loc='best')
        axes2[0].grid(True)

        axes2[1].set_xlabel('epoch')
        axes2[1].set_ylabel('test_accuracy')
        axes2[1].set_title("Test Accuracy (rmsprop, excluding ViT and res101)")
        axes2[1].legend(fontsize='small', loc='best')
        axes2[1].grid(True)

        plt.tight_layout()
        plt.show()
    else:
        print("df_rmsprop_no_vit_res101 is empty.")

# %%
def _last_token(experiment_name):
    parts = str(experiment_name).lower().split('_')
    return parts[-1] if parts else str(experiment_name).lower()

def experiment_color_last_token(experiment_name, token_to_base):
    last_token = _last_token(experiment_name)
    is_baseline = 'baseline' in str(experiment_name).lower()

    base = token_to_base[last_token]
    if is_baseline:
        return _adjust_lightness(base, 0.55)  # darker for baseline
    return _adjust_lightness(base, 1.35)      # brighter for non-baseline

# filter experiments containing 'vit'
df_vit = df[
    df['experiment'].str.contains('vit', case=False, na=False)
]

if df_vit.empty:
    print("No 'vit' experiments found.")
else:
    token_order = sorted({_last_token(name) for name in df_vit['experiment'].unique()})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for name, grp in df_vit.groupby('experiment'):
        color = experiment_color_last_token(name, token_to_base)
        axes[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
        axes[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('train_loss')
    axes[0].set_title("Train Loss (vit)")
    axes[0].legend(fontsize='small', loc='best')
    axes[0].grid(True)

    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('test_accuracy')
    axes[1].set_title("Test Accuracy (vit)")
    axes[1].legend(fontsize='small', loc='best')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %%
# filter experiments containing 'vit'
df_vit = df[
    df['experiment'].str.contains('vit', case=False, na=False) &
    ~df['experiment'].str.contains('sgd', case=False, na=False)
]

if df_vit.empty:
    print("No 'vit' experiments found.")
else:
    token_order = sorted({_last_token(name) for name in df_vit['experiment'].unique()})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for name, grp in df_vit.groupby('experiment'):
        color = experiment_color_last_token(name, token_to_base)
        axes[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
        axes[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('train_loss')
    axes[0].set_title("Train Loss (vit)")
    axes[0].legend(fontsize='small', loc='best')
    axes[0].grid(True)

    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('test_accuracy')
    axes[1].set_title("Test Accuracy (vit)")
    axes[1].legend(fontsize='small', loc='best')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()
