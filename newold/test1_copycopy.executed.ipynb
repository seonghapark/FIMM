# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# Dataset parameters
NUM_CLASSES = 10
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

K_PROBES = 4
EPSILON = 0.1

# Device setup for CUDA
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Load MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST mean and std
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

class MNISTClassifier(nn.Module):
    def __init__(self, num_classes, k_probes, epsilon):
        super().__init__()
        self.epsilon = epsilon
        self.k_probes = k_probes
        self.num_classes = num_classes

        v = torch.randn(k_probes, 2)  # 2D probe directions
        v = v / torch.norm(v, dim=1, keepdim=True)
        self.register_buffer('probes', v)

        # ResNet18 backbone
        resnet_model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet18', pretrained=False)
        self.intro = nn.Sequential(
            resnet_model.conv1,
            resnet_model.bn1,
            resnet_model.relu,
            resnet_model.maxpool
        )
        self.layer1 = resnet_model.layer1
        self.layer2 = resnet_model.layer2
        self.layer3 = resnet_model.layer3
        self.layer4 = resnet_model.layer4
        self.averagepool = resnet_model.avgpool

        # Classification head (512 + O0/O1/O2 + 4 fisher terms = 519)
        self.classifier = nn.Sequential(
            nn.Linear(512 + 3 + 4, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def compute_score(self, x):
        if not x.requires_grad:
            x.requires_grad_(True)

        # Compute energy as mean of representation
        energy = x.mean()

        grads = torch.autograd.grad(
            outputs=energy,
            inputs=x,
            create_graph=True,
            retain_graph=True
        )[0]

        grads_flat = grads.view(grads.size(0), -1)

        # Use only first 2 dimensions or project to 2D space
        if grads_flat.size(1) >= 2:
            grads_2d = grads_flat[:, :2]
        else:
            grads_2d = grads_flat

        scores = -torch.matmul(grads_2d, self.probes.T)
        return scores

    def compute_local_fisher(self, x):
        scores = self.compute_score(x)
        fisher_info = (scores ** 2).mean(dim=1, keepdim=True)
        return fisher_info

    def forward(self, x):
        # Convert 1-channel to 3-channel (RGB) by repeating
        if x.size(1) == 1:
            x = x.repeat(1, 3, 1, 1)  # [batch, 3, 28, 28]

        # Resize to ResNet input size (224x224)
        x_resized = F.interpolate(x, size=(224, 224), mode='bilinear', align_corners=False)

        with torch.set_grad_enabled(True):
            if not x_resized.requires_grad:
                x_resized.requires_grad_(True)

            # Compute derivatives with respect to input
            O0 = self.compute_local_fisher(x_resized)

            # For image tensors, use small Gaussian perturbations instead of probe directions
            perturbation = torch.randn_like(x_resized) * self.epsilon
            x_pos = x_resized + perturbation
            x_neg = x_resized - perturbation

            I_pos = self.compute_local_fisher(x_pos)
            I_neg = self.compute_local_fisher(x_neg)

            O1 = (I_pos - I_neg) / (2 * self.epsilon)
            O2 = (I_pos - 2 * O0 + I_neg) / (self.epsilon ** 2)

        # Forward through ResNet
        h = self.intro(x_resized)

        # Apply layers and compute Fisher at each stage
        h = self.layer1(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer1 = self.compute_local_fisher(h)

        h = self.layer2(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer2 = self.compute_local_fisher(h)

        h = self.layer3(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer3 = self.compute_local_fisher(h)

        h = self.layer4(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer4 = self.compute_local_fisher(h)

        # Global average pool
        h_pooled = self.averagepool(h)
        h_flat = h_pooled.flatten(1)

        # Concatenate all features
        fish_concat = torch.cat([fish_layer1, fish_layer2, fish_layer3, fish_layer4], dim=1)
        features = torch.cat([h_flat, O0, O1, O2, fish_concat], dim=1)

        # Classify
        logits = self.classifier(features)
        return logits

def run_experiment(model, opt):
    model = model.to(device)
    optimizer = opt
    criterion = nn.CrossEntropyLoss()

    train_losses = []
    test_accuracies = []

    print("Starting MNIST Training...")
    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

            if batch_idx % 100 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")

        avg_loss = epoch_loss / len(train_loader)
        train_losses.append(avg_loss)

        # Evaluate on test set
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()

        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

# For each model, create the model, create an optimizer bound to that model, then pass optimizer into run_experiment
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.Adam(model.parameters(), lr=LR)
train_losses_resnet18_fisher_adam, test_accuracies_resnet18_fisher_adam = run_experiment(model, opt)

model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.SGD(model.parameters(), lr=LR)
train_losses_resnet18_fisher_sgd, test_accuracies_resnet18_fisher_sgd = run_experiment(model, opt)

model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.RMSprop(model.parameters(), lr=LR)
train_losses_resnet18_fisher_rmsprop, test_accuracies_resnet18_fisher_rmsprop = run_experiment(model, opt)

# Plot training results
epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_resnet18_fisher_adam, 'Adam', 'o', 'blue'),
    (train_losses_resnet18_fisher_sgd, 'SGD', 's', 'orange'),
    (train_losses_resnet18_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_resnet18_fisher_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_resnet18_fisher_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_resnet18_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ResNet18_Fisher Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ResNet18_Fisher Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_resnet18_fisher_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_resnet18_fisher_training.png'")
plt.show()
# Out:
# Using device: cuda
# Train samples: 60000, Test samples: 10000
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.3134
# Epoch 0, Batch 100/938: Loss=0.3963
# Epoch 0, Batch 200/938: Loss=0.1713
# Epoch 0, Batch 300/938: Loss=0.1463
# Epoch 0, Batch 400/938: Loss=0.0643
# Epoch 0, Batch 500/938: Loss=0.1003
# Epoch 0, Batch 600/938: Loss=0.0483
# Epoch 0, Batch 700/938: Loss=0.0585
# Epoch 0, Batch 800/938: Loss=0.0839
# Epoch 0, Batch 900/938: Loss=0.0750
# Epoch 0 | Train Loss: 0.1799 | Test Accuracy: 97.86%
# Epoch 1, Batch 0/938: Loss=0.0169
# Epoch 1, Batch 100/938: Loss=0.1077
# Epoch 1, Batch 200/938: Loss=0.0298
# Epoch 1, Batch 300/938: Loss=0.1016
# Epoch 1, Batch 400/938: Loss=0.0542
# Epoch 1, Batch 500/938: Loss=0.0093
# Epoch 1, Batch 600/938: Loss=0.0536
# Epoch 1, Batch 700/938: Loss=0.0839
# Epoch 1, Batch 800/938: Loss=0.0264
# Epoch 1, Batch 900/938: Loss=0.0124
# Epoch 1 | Train Loss: 0.0691 | Test Accuracy: 99.05%
# Epoch 2, Batch 0/938: Loss=0.0520
# Epoch 2, Batch 100/938: Loss=0.0114
# Epoch 2, Batch 200/938: Loss=0.0465
# Epoch 2, Batch 300/938: Loss=0.0601
# Epoch 2, Batch 400/938: Loss=0.0108
# Epoch 2, Batch 500/938: Loss=0.0098
# Epoch 2, Batch 600/938: Loss=0.0787
# Epoch 2, Batch 700/938: Loss=0.1044
# Epoch 2, Batch 800/938: Loss=0.0041
# Epoch 2, Batch 900/938: Loss=0.0146
# Epoch 2 | Train Loss: 0.0516 | Test Accuracy: 99.30%
# Epoch 3, Batch 0/938: Loss=0.0048
# Epoch 3, Batch 100/938: Loss=0.0335
# Epoch 3, Batch 200/938: Loss=0.0460
# Epoch 3, Batch 300/938: Loss=0.0154
# Epoch 3, Batch 400/938: Loss=0.0308
# Epoch 3, Batch 500/938: Loss=0.1826
# Epoch 3, Batch 600/938: Loss=0.0117
# Epoch 3, Batch 700/938: Loss=0.0495
# Epoch 3, Batch 800/938: Loss=0.0242
# Epoch 3, Batch 900/938: Loss=0.0256
# Epoch 3 | Train Loss: 0.0452 | Test Accuracy: 99.12%
# Epoch 4, Batch 0/938: Loss=0.0060
# Epoch 4, Batch 100/938: Loss=0.0581
# Epoch 4, Batch 200/938: Loss=0.0056
# Epoch 4, Batch 300/938: Loss=0.0231
# Epoch 4, Batch 400/938: Loss=0.0196
# Epoch 4, Batch 500/938: Loss=0.0133
# Epoch 4, Batch 600/938: Loss=0.0519
# Epoch 4, Batch 700/938: Loss=0.0051
# Epoch 4, Batch 800/938: Loss=0.0316
# Epoch 4, Batch 900/938: Loss=0.0109
# Epoch 4 | Train Loss: 0.0386 | Test Accuracy: 99.02%
# Epoch 5, Batch 0/938: Loss=0.0664
# Epoch 5, Batch 100/938: Loss=0.0033
# Epoch 5, Batch 200/938: Loss=0.0495
# Epoch 5, Batch 300/938: Loss=0.0471
# Epoch 5, Batch 400/938: Loss=0.0058
# Epoch 5, Batch 500/938: Loss=0.0670
# Epoch 5, Batch 600/938: Loss=0.0013
# Epoch 5, Batch 700/938: Loss=0.1566
# Epoch 5, Batch 800/938: Loss=0.0028
# Epoch 5, Batch 900/938: Loss=0.0053
# Epoch 5 | Train Loss: 0.0358 | Test Accuracy: 99.12%
# Epoch 6, Batch 0/938: Loss=0.0677
# Epoch 6, Batch 100/938: Loss=0.0113
# Epoch 6, Batch 200/938: Loss=0.0421
# Epoch 6, Batch 300/938: Loss=0.0036
# Epoch 6, Batch 400/938: Loss=0.0067
# Epoch 6, Batch 500/938: Loss=0.0451
# Epoch 6, Batch 600/938: Loss=0.0066
# Epoch 6, Batch 700/938: Loss=0.0006
# Epoch 6, Batch 800/938: Loss=0.0074
# Epoch 6, Batch 900/938: Loss=0.0395
# Epoch 6 | Train Loss: 0.0297 | Test Accuracy: 99.33%
# Epoch 7, Batch 0/938: Loss=0.0011
# Epoch 7, Batch 100/938: Loss=0.0007
# Epoch 7, Batch 200/938: Loss=0.0134
# Epoch 7, Batch 300/938: Loss=0.0066
# Epoch 7, Batch 400/938: Loss=0.0079
# Epoch 7, Batch 500/938: Loss=0.0477
# Epoch 7, Batch 600/938: Loss=0.0375
# Epoch 7, Batch 700/938: Loss=0.0028
# Epoch 7, Batch 800/938: Loss=0.1668
# Epoch 7, Batch 900/938: Loss=0.0127
# Epoch 7 | Train Loss: 0.0269 | Test Accuracy: 99.37%
# Epoch 8, Batch 0/938: Loss=0.0091
# Epoch 8, Batch 100/938: Loss=0.0129
# Epoch 8, Batch 200/938: Loss=0.0998
# Epoch 8, Batch 300/938: Loss=0.0005
# Epoch 8, Batch 400/938: Loss=0.0030
# Epoch 8, Batch 500/938: Loss=0.0125
# Epoch 8, Batch 600/938: Loss=0.0172
# Epoch 8, Batch 700/938: Loss=0.0581
# Epoch 8, Batch 800/938: Loss=0.0030
# Epoch 8, Batch 900/938: Loss=0.0057
# Epoch 8 | Train Loss: 0.0273 | Test Accuracy: 99.31%
# Epoch 9, Batch 0/938: Loss=0.0146
# Epoch 9, Batch 100/938: Loss=0.0066
# Epoch 9, Batch 200/938: Loss=0.0056
# Epoch 9, Batch 300/938: Loss=0.0315
# Epoch 9, Batch 400/938: Loss=0.0004
# Epoch 9, Batch 500/938: Loss=0.0076
# Epoch 9, Batch 600/938: Loss=0.0028
# Epoch 9, Batch 700/938: Loss=0.0144
# Epoch 9, Batch 800/938: Loss=0.0006
# Epoch 9, Batch 900/938: Loss=0.0103
# Epoch 9 | Train Loss: 0.0225 | Test Accuracy: 99.35%
# Final Test Accuracy: 99.35%
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.2976
# Epoch 0, Batch 100/938: Loss=2.3120
# Epoch 0, Batch 200/938: Loss=2.3227
# Epoch 0, Batch 300/938: Loss=2.2601
# Epoch 0, Batch 400/938: Loss=2.2106
# Epoch 0, Batch 500/938: Loss=2.1867
# Epoch 0, Batch 600/938: Loss=2.1891
# Epoch 0, Batch 700/938: Loss=2.1559
# Epoch 0, Batch 800/938: Loss=2.1516
# Epoch 0, Batch 900/938: Loss=2.0873
# Epoch 0 | Train Loss: 2.2248 | Test Accuracy: 28.30%
# Epoch 1, Batch 0/938: Loss=2.1074
# Epoch 1, Batch 100/938: Loss=2.0068
# Epoch 1, Batch 200/938: Loss=2.0269
# Epoch 1, Batch 300/938: Loss=2.0274
# Epoch 1, Batch 400/938: Loss=1.9301
# Epoch 1, Batch 500/938: Loss=1.9047
# Epoch 1, Batch 600/938: Loss=1.8486
# Epoch 1, Batch 700/938: Loss=2.0013
# Epoch 1, Batch 800/938: Loss=1.8118
# Epoch 1, Batch 900/938: Loss=1.7446
# Epoch 1 | Train Loss: 1.9620 | Test Accuracy: 47.45%
# Epoch 2, Batch 0/938: Loss=1.8217
# Epoch 2, Batch 100/938: Loss=1.8057
# Epoch 2, Batch 200/938: Loss=1.8378
# Epoch 2, Batch 300/938: Loss=1.9064
# Epoch 2, Batch 400/938: Loss=1.7648
# Epoch 2, Batch 500/938: Loss=1.7509
# Epoch 2, Batch 600/938: Loss=1.6996
# Epoch 2, Batch 700/938: Loss=1.8205
# Epoch 2, Batch 800/938: Loss=1.5467
# Epoch 2, Batch 900/938: Loss=1.6918
# Epoch 2 | Train Loss: 1.7527 | Test Accuracy: 57.77%
# Epoch 3, Batch 0/938: Loss=1.6204
# Epoch 3, Batch 100/938: Loss=1.6242
# Epoch 3, Batch 200/938: Loss=1.6220
# Epoch 3, Batch 300/938: Loss=1.5447
# Epoch 3, Batch 400/938: Loss=1.4647
# Epoch 3, Batch 500/938: Loss=1.5254
# Epoch 3, Batch 600/938: Loss=1.4851
# Epoch 3, Batch 700/938: Loss=1.3594
# Epoch 3, Batch 800/938: Loss=1.5234
# Epoch 3, Batch 900/938: Loss=1.3447
# Epoch 3 | Train Loss: 1.5139 | Test Accuracy: 65.52%
# Epoch 4, Batch 0/938: Loss=1.3239
# Epoch 4, Batch 100/938: Loss=1.3764
# Epoch 4, Batch 200/938: Loss=1.2990
# Epoch 4, Batch 300/938: Loss=1.4084
# Epoch 4, Batch 400/938: Loss=1.0768
# Epoch 4, Batch 500/938: Loss=1.1997
# Epoch 4, Batch 600/938: Loss=1.0542
# Epoch 4, Batch 700/938: Loss=1.2157
# Epoch 4, Batch 800/938: Loss=1.0207
# Epoch 4, Batch 900/938: Loss=1.1540
# Epoch 4 | Train Loss: 1.1709 | Test Accuracy: 81.66%
# Epoch 5, Batch 0/938: Loss=0.9211
# Epoch 5, Batch 100/938: Loss=1.0389
# Epoch 5, Batch 200/938: Loss=0.8347
# Epoch 5, Batch 300/938: Loss=0.8016
# Epoch 5, Batch 400/938: Loss=0.7863
# Epoch 5, Batch 500/938: Loss=0.7788
# Epoch 5, Batch 600/938: Loss=0.9605
# Epoch 5, Batch 700/938: Loss=0.8410
# Epoch 5, Batch 800/938: Loss=0.7739
# Epoch 5, Batch 900/938: Loss=0.7786
# Epoch 5 | Train Loss: 0.8426 | Test Accuracy: 80.74%
# Epoch 6, Batch 0/938: Loss=0.6952
# Epoch 6, Batch 100/938: Loss=0.7213
# Epoch 6, Batch 200/938: Loss=0.7444
# Epoch 6, Batch 300/938: Loss=0.7283
# Epoch 6, Batch 400/938: Loss=0.6233
# Epoch 6, Batch 500/938: Loss=0.6220
# Epoch 6, Batch 600/938: Loss=0.6852
# Epoch 6, Batch 700/938: Loss=0.4991
# Epoch 6, Batch 800/938: Loss=0.5818
# Epoch 6, Batch 900/938: Loss=0.5156
# Epoch 6 | Train Loss: 0.6203 | Test Accuracy: 92.01%
# Epoch 7, Batch 0/938: Loss=0.4566
# Epoch 7, Batch 100/938: Loss=0.6391
# Epoch 7, Batch 200/938: Loss=0.4366
# Epoch 7, Batch 300/938: Loss=0.4282
# Epoch 7, Batch 400/938: Loss=0.5645
# Epoch 7, Batch 500/938: Loss=0.4212
# Epoch 7, Batch 600/938: Loss=0.3593
# Epoch 7, Batch 700/938: Loss=0.3590
# Epoch 7, Batch 800/938: Loss=0.3784
# Epoch 7, Batch 900/938: Loss=0.5520
# Epoch 7 | Train Loss: 0.4768 | Test Accuracy: 91.71%
# Epoch 8, Batch 0/938: Loss=0.3759
# Epoch 8, Batch 100/938: Loss=0.3509
# Epoch 8, Batch 200/938: Loss=0.2280
# Epoch 8, Batch 300/938: Loss=0.3746
# Epoch 8, Batch 400/938: Loss=0.3390
# Epoch 8, Batch 500/938: Loss=0.3194
# Epoch 8, Batch 600/938: Loss=0.4074
# Epoch 8, Batch 700/938: Loss=0.3945
# Epoch 8, Batch 800/938: Loss=0.2459
# Epoch 8, Batch 900/938: Loss=0.3543
# Epoch 8 | Train Loss: 0.3844 | Test Accuracy: 94.40%
# Epoch 9, Batch 0/938: Loss=0.3728
# Epoch 9, Batch 100/938: Loss=0.2388
# Epoch 9, Batch 200/938: Loss=0.3550
# Epoch 9, Batch 300/938: Loss=0.4899
# Epoch 9, Batch 400/938: Loss=0.4122
# Epoch 9, Batch 500/938: Loss=0.2238
# Epoch 9, Batch 600/938: Loss=0.2475
# Epoch 9, Batch 700/938: Loss=0.1782
# Epoch 9, Batch 800/938: Loss=0.3042
# Epoch 9, Batch 900/938: Loss=0.3050
# Epoch 9 | Train Loss: 0.3198 | Test Accuracy: 95.87%
# Final Test Accuracy: 95.87%
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.3146
# Epoch 0, Batch 100/938: Loss=0.6944
# Epoch 0, Batch 200/938: Loss=0.4441
# Epoch 0, Batch 300/938: Loss=0.3137
# Epoch 0, Batch 400/938: Loss=0.2129
# Epoch 0, Batch 500/938: Loss=0.1371
# Epoch 0, Batch 600/938: Loss=0.0447
# Epoch 0, Batch 700/938: Loss=0.2025
# Epoch 0, Batch 800/938: Loss=0.2907
# Epoch 0, Batch 900/938: Loss=0.0130
# Epoch 0 | Train Loss: 0.3149 | Test Accuracy: 95.27%
# Epoch 1, Batch 0/938: Loss=0.1460
# Epoch 1, Batch 100/938: Loss=0.1074
# Epoch 1, Batch 200/938: Loss=0.0682
# Epoch 1, Batch 300/938: Loss=0.0305
# Epoch 1, Batch 400/938: Loss=0.0699
# Epoch 1, Batch 500/938: Loss=0.0690
# Epoch 1, Batch 600/938: Loss=0.0727
# Epoch 1, Batch 700/938: Loss=0.0703
# Epoch 1, Batch 800/938: Loss=0.1741
# Epoch 1, Batch 900/938: Loss=0.0953
# Epoch 1 | Train Loss: 0.0888 | Test Accuracy: 98.99%
# Epoch 2, Batch 0/938: Loss=0.0331
# Epoch 2, Batch 100/938: Loss=0.0370
# Epoch 2, Batch 200/938: Loss=0.0166
# Epoch 2, Batch 300/938: Loss=0.0310
# Epoch 2, Batch 400/938: Loss=0.0281
# Epoch 2, Batch 500/938: Loss=0.2638
# Epoch 2, Batch 600/938: Loss=0.0345
# Epoch 2, Batch 700/938: Loss=0.0292
# Epoch 2, Batch 800/938: Loss=0.0887
# Epoch 2, Batch 900/938: Loss=0.0472
# Epoch 2 | Train Loss: 0.0645 | Test Accuracy: 99.17%
# Epoch 3, Batch 0/938: Loss=0.0186
# Epoch 3, Batch 100/938: Loss=0.0128
# Epoch 3, Batch 200/938: Loss=0.0218
# Epoch 3, Batch 300/938: Loss=0.0404
# Epoch 3, Batch 400/938: Loss=0.0102
# Epoch 3, Batch 500/938: Loss=0.0880
# Epoch 3, Batch 600/938: Loss=0.2327
# Epoch 3, Batch 700/938: Loss=0.0894
# Epoch 3, Batch 800/938: Loss=0.0030
# Epoch 3, Batch 900/938: Loss=0.0152
# Epoch 3 | Train Loss: 0.0506 | Test Accuracy: 98.89%
# Epoch 4, Batch 0/938: Loss=0.2151
# Epoch 4, Batch 100/938: Loss=0.0446
# Epoch 4, Batch 200/938: Loss=0.0055
# Epoch 4, Batch 300/938: Loss=0.0114
# Epoch 4, Batch 400/938: Loss=0.2058
# Epoch 4, Batch 500/938: Loss=0.0273
# Epoch 4, Batch 600/938: Loss=0.0063
# Epoch 4, Batch 700/938: Loss=0.0044
# Epoch 4, Batch 800/938: Loss=0.0017
# Epoch 4, Batch 900/938: Loss=0.1235
# Epoch 4 | Train Loss: 0.0428 | Test Accuracy: 99.37%
# Epoch 5, Batch 0/938: Loss=0.0676
# Epoch 5, Batch 100/938: Loss=0.0115
# Epoch 5, Batch 200/938: Loss=0.0107
# Epoch 5, Batch 300/938: Loss=0.0142
# Epoch 5, Batch 400/938: Loss=0.0213
# Epoch 5, Batch 500/938: Loss=0.0241
# Epoch 5, Batch 600/938: Loss=0.0774
# Epoch 5, Batch 700/938: Loss=0.0002
# Epoch 5, Batch 800/938: Loss=0.0325
# Epoch 5, Batch 900/938: Loss=0.0418
# Epoch 5 | Train Loss: 0.0375 | Test Accuracy: 97.20%
# Epoch 6, Batch 0/938: Loss=0.0742
# Epoch 6, Batch 100/938: Loss=0.0278
# Epoch 6, Batch 200/938: Loss=0.0324
# Epoch 6, Batch 300/938: Loss=0.0330
# Epoch 6, Batch 400/938: Loss=0.0145
# Epoch 6, Batch 500/938: Loss=0.0044
# Epoch 6, Batch 600/938: Loss=0.0206
# Epoch 6, Batch 700/938: Loss=0.0103
# Epoch 6, Batch 800/938: Loss=0.0213
# Epoch 6, Batch 900/938: Loss=0.0027
# Epoch 6 | Train Loss: 0.0339 | Test Accuracy: 99.26%
# Epoch 7, Batch 0/938: Loss=0.0419
# Epoch 7, Batch 100/938: Loss=0.0277
# Epoch 7, Batch 200/938: Loss=0.0301
# Epoch 7, Batch 300/938: Loss=0.0602
# Epoch 7, Batch 400/938: Loss=0.0035
# Epoch 7, Batch 500/938: Loss=0.1161
# Epoch 7, Batch 600/938: Loss=0.0114
# Epoch 7, Batch 700/938: Loss=0.0433
# Epoch 7, Batch 800/938: Loss=0.0901
# Epoch 7, Batch 900/938: Loss=0.0257
# Epoch 7 | Train Loss: 0.0284 | Test Accuracy: 99.16%
# Epoch 8, Batch 0/938: Loss=0.0081
# Epoch 8, Batch 100/938: Loss=0.0925
# Epoch 8, Batch 200/938: Loss=0.0167
# Epoch 8, Batch 300/938: Loss=0.0150
# Epoch 8, Batch 400/938: Loss=0.0058
# Epoch 8, Batch 500/938: Loss=0.0236
# Epoch 8, Batch 600/938: Loss=0.0033
# Epoch 8, Batch 700/938: Loss=0.0123
# Epoch 8, Batch 800/938: Loss=0.0018
# Epoch 8, Batch 900/938: Loss=0.0197
# Epoch 8 | Train Loss: 0.0262 | Test Accuracy: 99.17%
# Epoch 9, Batch 0/938: Loss=0.0507
# Epoch 9, Batch 100/938: Loss=0.0071
# Epoch 9, Batch 200/938: Loss=0.0045
# Epoch 9, Batch 300/938: Loss=0.0700
# Epoch 9, Batch 400/938: Loss=0.0751
# Epoch 9, Batch 500/938: Loss=0.0028
# Epoch 9, Batch 600/938: Loss=0.0003
# Epoch 9, Batch 700/938: Loss=0.0165
# Epoch 9, Batch 800/938: Loss=0.1365
# Epoch 9, Batch 900/938: Loss=0.0047
# Epoch 9 | Train Loss: 0.0258 | Test Accuracy: 99.46%
# Final Test Accuracy: 99.46%
# Training plots saved as 'mnist_resnet18_fisher_training.png'

# %%
import copy
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt

# Setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Hyperparameters
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

# Download and prepare MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST mean and std
])

print("Downloading MNIST dataset...")
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

# Download ResNet18 (not pretrained)
print("Downloading ResNet18 model...")
base_resnet18 = models.resnet18(weights=None)

# Modify first layer to accept 1-channel input (MNIST is grayscale)
base_resnet18.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)

# Modify output layer for 10 classes
num_ftrs = base_resnet18.fc.in_features
base_resnet18.fc = nn.Linear(num_ftrs, 10)

def make_resnet18():
    return copy.deepcopy(base_resnet18)

def run_experiment(model, optimizer):
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()

    print(f"Starting Training for {EPOCHS} epochs...")
    train_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0.0
        batch_count = 0
        
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            batch_count += 1
            
            if batch_idx % 150 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")
        
        avg_loss = epoch_loss / batch_count
        train_losses.append(avg_loss)
        
        # Evaluation phase
        model.eval()
        correct = 0
        total = 0
        
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()
        
        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print("\nTraining Complete!")
    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

# For each model, create the model, create an optimizer bound to that model, then pass optimizer into run_experiment
model = make_resnet18()
optimizer = optim.Adam(model.parameters(), lr=LR)
train_losses_resnet18_baseline_adam, test_accuracies_resnet18_baseline_adam = run_experiment(model, optimizer)

model = make_resnet18()
optimizer = optim.SGD(model.parameters(), lr=LR)
train_losses_resnet18_baseline_sgd, test_accuracies_resnet18_baseline_sgd = run_experiment(model, optimizer)

model = make_resnet18()
optimizer = optim.RMSprop(model.parameters(), lr=LR)
train_losses_resnet18_baseline_rmsprop, test_accuracies_resnet18_baseline_rmsprop = run_experiment(model, optimizer)

# Plot training results
epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_resnet18_baseline_adam, 'Adam', 'o', 'blue'),
    (train_losses_resnet18_baseline_sgd, 'SGD', 's', 'orange'),
    (train_losses_resnet18_baseline_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_resnet18_baseline_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_resnet18_baseline_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_resnet18_baseline_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ResNet18_baseline Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ResNet18_baseline Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_resnet18_baseline_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_resnet18_baseline_training.png'")
plt.show()
# Out:
# Using device: cuda
# Downloading MNIST dataset...
# Train samples: 60000, Test samples: 10000
# Downloading ResNet18 model...
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.6082
# Epoch 0, Batch 150/938: Loss=0.1607
# Epoch 0, Batch 300/938: Loss=0.0817
# Epoch 0, Batch 450/938: Loss=0.0653
# Epoch 0, Batch 600/938: Loss=0.0017
# Epoch 0, Batch 750/938: Loss=0.0885
# Epoch 0, Batch 900/938: Loss=0.0016
# Epoch 0 | Train Loss: 0.1365 | Test Accuracy: 97.97%
# Epoch 1, Batch 0/938: Loss=0.0626
# Epoch 1, Batch 150/938: Loss=0.0257
# Epoch 1, Batch 300/938: Loss=0.0059
# Epoch 1, Batch 450/938: Loss=0.0530
# Epoch 1, Batch 600/938: Loss=0.1061
# Epoch 1, Batch 750/938: Loss=0.0899
# Epoch 1, Batch 900/938: Loss=0.0025
# Epoch 1 | Train Loss: 0.0582 | Test Accuracy: 98.04%
# Epoch 2, Batch 0/938: Loss=0.0866
# Epoch 2, Batch 150/938: Loss=0.1923
# Epoch 2, Batch 300/938: Loss=0.1428
# Epoch 2, Batch 450/938: Loss=0.0122
# Epoch 2, Batch 600/938: Loss=0.0211
# Epoch 2, Batch 750/938: Loss=0.0384
# Epoch 2, Batch 900/938: Loss=0.1420
# Epoch 2 | Train Loss: 0.0446 | Test Accuracy: 98.61%
# Epoch 3, Batch 0/938: Loss=0.0340
# Epoch 3, Batch 150/938: Loss=0.0555
# Epoch 3, Batch 300/938: Loss=0.0071
# Epoch 3, Batch 450/938: Loss=0.0145
# Epoch 3, Batch 600/938: Loss=0.0031
# Epoch 3, Batch 750/938: Loss=0.0044
# Epoch 3, Batch 900/938: Loss=0.0014
# Epoch 3 | Train Loss: 0.0392 | Test Accuracy: 98.77%
# Epoch 4, Batch 0/938: Loss=0.0126
# Epoch 4, Batch 150/938: Loss=0.0576
# Epoch 4, Batch 300/938: Loss=0.0257
# Epoch 4, Batch 450/938: Loss=0.0237
# Epoch 4, Batch 600/938: Loss=0.0076
# Epoch 4, Batch 750/938: Loss=0.0794
# Epoch 4, Batch 900/938: Loss=0.0051
# Epoch 4 | Train Loss: 0.0317 | Test Accuracy: 98.83%
# Epoch 5, Batch 0/938: Loss=0.0051
# Epoch 5, Batch 150/938: Loss=0.0105
# Epoch 5, Batch 300/938: Loss=0.0194
# Epoch 5, Batch 450/938: Loss=0.0025
# Epoch 5, Batch 600/938: Loss=0.0154
# Epoch 5, Batch 750/938: Loss=0.1032
# Epoch 5, Batch 900/938: Loss=0.0118
# Epoch 5 | Train Loss: 0.0288 | Test Accuracy: 99.17%
# Epoch 6, Batch 0/938: Loss=0.0304
# Epoch 6, Batch 150/938: Loss=0.0530
# Epoch 6, Batch 300/938: Loss=0.0015
# Epoch 6, Batch 450/938: Loss=0.2343
# Epoch 6, Batch 600/938: Loss=0.0105
# Epoch 6, Batch 750/938: Loss=0.1721
# Epoch 6, Batch 900/938: Loss=0.0063
# Epoch 6 | Train Loss: 0.0254 | Test Accuracy: 99.13%
# Epoch 7, Batch 0/938: Loss=0.0007
# Epoch 7, Batch 150/938: Loss=0.0351
# Epoch 7, Batch 300/938: Loss=0.0180
# Epoch 7, Batch 450/938: Loss=0.0016
# Epoch 7, Batch 600/938: Loss=0.0011
# Epoch 7, Batch 750/938: Loss=0.0006
# Epoch 7, Batch 900/938: Loss=0.0079
# Epoch 7 | Train Loss: 0.0227 | Test Accuracy: 99.19%
# Epoch 8, Batch 0/938: Loss=0.0050
# Epoch 8, Batch 150/938: Loss=0.0011
# Epoch 8, Batch 300/938: Loss=0.0790
# Epoch 8, Batch 450/938: Loss=0.0005
# Epoch 8, Batch 600/938: Loss=0.0769
# Epoch 8, Batch 750/938: Loss=0.0044
# Epoch 8, Batch 900/938: Loss=0.0167
# Epoch 8 | Train Loss: 0.0234 | Test Accuracy: 99.01%
# Epoch 9, Batch 0/938: Loss=0.0211
# Epoch 9, Batch 150/938: Loss=0.0009
# Epoch 9, Batch 300/938: Loss=0.0004
# Epoch 9, Batch 450/938: Loss=0.1448
# Epoch 9, Batch 600/938: Loss=0.0002
# Epoch 9, Batch 750/938: Loss=0.0023
# Epoch 9, Batch 900/938: Loss=0.0009
# Epoch 9 | Train Loss: 0.0179 | Test Accuracy: 99.19%
#
# Training Complete!
# Final Test Accuracy: 99.19%
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.6891
# Epoch 0, Batch 150/938: Loss=0.9756
# Epoch 0, Batch 300/938: Loss=0.6225
# Epoch 0, Batch 450/938: Loss=0.5971
# Epoch 0, Batch 600/938: Loss=0.2937
# Epoch 0, Batch 750/938: Loss=0.3402
# Epoch 0, Batch 900/938: Loss=0.1827
# Epoch 0 | Train Loss: 0.5450 | Test Accuracy: 94.50%
# Epoch 1, Batch 0/938: Loss=0.1677
# Epoch 1, Batch 150/938: Loss=0.1881
# Epoch 1, Batch 300/938: Loss=0.1656
# Epoch 1, Batch 450/938: Loss=0.2116
# Epoch 1, Batch 600/938: Loss=0.2051
# Epoch 1, Batch 750/938: Loss=0.1138
# Epoch 1, Batch 900/938: Loss=0.0286
# Epoch 1 | Train Loss: 0.1734 | Test Accuracy: 96.46%
# Epoch 2, Batch 0/938: Loss=0.1684
# Epoch 2, Batch 150/938: Loss=0.0737
# Epoch 2, Batch 300/938: Loss=0.1118
# Epoch 2, Batch 450/938: Loss=0.0908
# Epoch 2, Batch 600/938: Loss=0.1454
# Epoch 2, Batch 750/938: Loss=0.1397
# Epoch 2, Batch 900/938: Loss=0.1531
# Epoch 2 | Train Loss: 0.1170 | Test Accuracy: 97.07%
# Epoch 3, Batch 0/938: Loss=0.1701
# Epoch 3, Batch 150/938: Loss=0.0844
# Epoch 3, Batch 300/938: Loss=0.1460
# Epoch 3, Batch 450/938: Loss=0.0376
# Epoch 3, Batch 600/938: Loss=0.0733
# Epoch 3, Batch 750/938: Loss=0.0853
# Epoch 3, Batch 900/938: Loss=0.0304
# Epoch 3 | Train Loss: 0.0893 | Test Accuracy: 97.52%
# Epoch 4, Batch 0/938: Loss=0.1137
# Epoch 4, Batch 150/938: Loss=0.0836
# Epoch 4, Batch 300/938: Loss=0.0158
# Epoch 4, Batch 450/938: Loss=0.1130
# Epoch 4, Batch 600/938: Loss=0.0762
# Epoch 4, Batch 750/938: Loss=0.0434
# Epoch 4, Batch 900/938: Loss=0.0275
# Epoch 4 | Train Loss: 0.0711 | Test Accuracy: 97.65%
# Epoch 5, Batch 0/938: Loss=0.0244
# Epoch 5, Batch 150/938: Loss=0.0443
# Epoch 5, Batch 300/938: Loss=0.0562
# Epoch 5, Batch 450/938: Loss=0.0219
# Epoch 5, Batch 600/938: Loss=0.0498
# Epoch 5, Batch 750/938: Loss=0.0891
# Epoch 5, Batch 900/938: Loss=0.0671
# Epoch 5 | Train Loss: 0.0591 | Test Accuracy: 97.88%
# Epoch 6, Batch 0/938: Loss=0.0372
# Epoch 6, Batch 150/938: Loss=0.0450
# Epoch 6, Batch 300/938: Loss=0.0519
# Epoch 6, Batch 450/938: Loss=0.0427
# Epoch 6, Batch 600/938: Loss=0.0324
# Epoch 6, Batch 750/938: Loss=0.0258
# Epoch 6, Batch 900/938: Loss=0.0398
# Epoch 6 | Train Loss: 0.0480 | Test Accuracy: 97.95%
# Epoch 7, Batch 0/938: Loss=0.0314
# Epoch 7, Batch 150/938: Loss=0.0076
# Epoch 7, Batch 300/938: Loss=0.0226
# Epoch 7, Batch 450/938: Loss=0.0514
# Epoch 7, Batch 600/938: Loss=0.0853
# Epoch 7, Batch 750/938: Loss=0.1253
# Epoch 7, Batch 900/938: Loss=0.0510
# Epoch 7 | Train Loss: 0.0412 | Test Accuracy: 98.09%
# Epoch 8, Batch 0/938: Loss=0.0722
# Epoch 8, Batch 150/938: Loss=0.0153
# Epoch 8, Batch 300/938: Loss=0.0265
# Epoch 8, Batch 450/938: Loss=0.0348
# Epoch 8, Batch 600/938: Loss=0.0174
# Epoch 8, Batch 750/938: Loss=0.0117
# Epoch 8, Batch 900/938: Loss=0.0407
# Epoch 8 | Train Loss: 0.0363 | Test Accuracy: 98.26%
# Epoch 9, Batch 0/938: Loss=0.0193
# Epoch 9, Batch 150/938: Loss=0.0931
# Epoch 9, Batch 300/938: Loss=0.0444
# Epoch 9, Batch 450/938: Loss=0.0263
# Epoch 9, Batch 600/938: Loss=0.0501
# Epoch 9, Batch 750/938: Loss=0.0059
# Epoch 9, Batch 900/938: Loss=0.0255
# Epoch 9 | Train Loss: 0.0315 | Test Accuracy: 98.22%
#
# Training Complete!
# Final Test Accuracy: 98.22%
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.5013
# Epoch 0, Batch 150/938: Loss=0.0895
# Epoch 0, Batch 300/938: Loss=0.0293
# Epoch 0, Batch 450/938: Loss=0.1095
# Epoch 0, Batch 600/938: Loss=0.0566
# Epoch 0, Batch 750/938: Loss=0.1492
# Epoch 0, Batch 900/938: Loss=0.0051
# Epoch 0 | Train Loss: 0.1607 | Test Accuracy: 94.05%
# Epoch 1, Batch 0/938: Loss=0.1009
# Epoch 1, Batch 150/938: Loss=0.0479
# Epoch 1, Batch 300/938: Loss=0.0150
# Epoch 1, Batch 450/938: Loss=0.0967
# Epoch 1, Batch 600/938: Loss=0.0261
# Epoch 1, Batch 750/938: Loss=0.0196
# Epoch 1, Batch 900/938: Loss=0.0459
# Epoch 1 | Train Loss: 0.0636 | Test Accuracy: 98.49%
# Epoch 2, Batch 0/938: Loss=0.0074
# Epoch 2, Batch 150/938: Loss=0.0624
# Epoch 2, Batch 300/938: Loss=0.0041
# Epoch 2, Batch 450/938: Loss=0.0915
# Epoch 2, Batch 600/938: Loss=0.0061
# Epoch 2, Batch 750/938: Loss=0.0959
# Epoch 2, Batch 900/938: Loss=0.0313
# Epoch 2 | Train Loss: 0.0451 | Test Accuracy: 98.71%
# Epoch 3, Batch 0/938: Loss=0.0118
# Epoch 3, Batch 150/938: Loss=0.0031
# Epoch 3, Batch 300/938: Loss=0.0461
# Epoch 3, Batch 450/938: Loss=0.0041
# Epoch 3, Batch 600/938: Loss=0.0685
# Epoch 3, Batch 750/938: Loss=0.0078
# Epoch 3, Batch 900/938: Loss=0.0030
# Epoch 3 | Train Loss: 0.0352 | Test Accuracy: 99.10%
# Epoch 4, Batch 0/938: Loss=0.0084
# Epoch 4, Batch 150/938: Loss=0.0846
# Epoch 4, Batch 300/938: Loss=0.0638
# Epoch 4, Batch 450/938: Loss=0.0073
# Epoch 4, Batch 600/938: Loss=0.0147
# Epoch 4, Batch 750/938: Loss=0.0291
# Epoch 4, Batch 900/938: Loss=0.0514
# Epoch 4 | Train Loss: 0.0311 | Test Accuracy: 96.00%
# Epoch 5, Batch 0/938: Loss=0.0235
# Epoch 5, Batch 150/938: Loss=0.0145
# Epoch 5, Batch 300/938: Loss=0.0346
# Epoch 5, Batch 450/938: Loss=0.0149
# Epoch 5, Batch 600/938: Loss=0.0045
# Epoch 5, Batch 750/938: Loss=0.0017
# Epoch 5, Batch 900/938: Loss=0.0022
# Epoch 5 | Train Loss: 0.0246 | Test Accuracy: 98.69%
# Epoch 6, Batch 0/938: Loss=0.0090
# Epoch 6, Batch 150/938: Loss=0.0002
# Epoch 6, Batch 300/938: Loss=0.0361
# Epoch 6, Batch 450/938: Loss=0.0010
# Epoch 6, Batch 600/938: Loss=0.0262
# Epoch 6, Batch 750/938: Loss=0.0337
# Epoch 6, Batch 900/938: Loss=0.0068
# Epoch 6 | Train Loss: 0.0214 | Test Accuracy: 99.35%
# Epoch 7, Batch 0/938: Loss=0.0042
# Epoch 7, Batch 150/938: Loss=0.0300
# Epoch 7, Batch 300/938: Loss=0.0002
# Epoch 7, Batch 450/938: Loss=0.0055
# Epoch 7, Batch 600/938: Loss=0.0009
# Epoch 7, Batch 750/938: Loss=0.0005
# Epoch 7, Batch 900/938: Loss=0.0089
# Epoch 7 | Train Loss: 0.0186 | Test Accuracy: 99.26%
# Epoch 8, Batch 0/938: Loss=0.0014
# Epoch 8, Batch 150/938: Loss=0.0072
# Epoch 8, Batch 300/938: Loss=0.0122
# Epoch 8, Batch 450/938: Loss=0.0392
# Epoch 8, Batch 600/938: Loss=0.0005
# Epoch 8, Batch 750/938: Loss=0.0118
# Epoch 8, Batch 900/938: Loss=0.0004
# Epoch 8 | Train Loss: 0.0170 | Test Accuracy: 98.97%
# Epoch 9, Batch 0/938: Loss=0.0001
# Epoch 9, Batch 150/938: Loss=0.0002
# Epoch 9, Batch 300/938: Loss=0.0064
# Epoch 9, Batch 450/938: Loss=0.0011
# Epoch 9, Batch 600/938: Loss=0.0006
# Epoch 9, Batch 750/938: Loss=0.0559
# Epoch 9, Batch 900/938: Loss=0.0451
# Epoch 9 | Train Loss: 0.0143 | Test Accuracy: 99.29%
#
# Training Complete!
# Final Test Accuracy: 99.29%
# Training plots saved as 'mnist_resnet18_baseline_training.png'

# %%
import torch, torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# Dataset parameters
NUM_CLASSES = 10
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

K_PROBES = 4
EPSILON = 0.1

# Device setup for CUDA
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Load MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST mean and std
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

class MNISTClassifier(nn.Module):
    def __init__(self, num_classes, k_probes, epsilon):
        super().__init__()
        self.epsilon = epsilon
        self.k_probes = k_probes
        self.num_classes = num_classes

        v = torch.randn(k_probes, 2)  # 2D probe directions
        v = v / torch.norm(v, dim=1, keepdim=True)
        self.register_buffer('probes', v)

        # ResNet50 backbone
        resnet_model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet50', pretrained=False)
        self.intro = nn.Sequential(
            resnet_model.conv1,
            resnet_model.bn1,
            resnet_model.relu,
            resnet_model.maxpool
        )
        self.layer1 = resnet_model.layer1
        self.layer2 = resnet_model.layer2
        self.layer3 = resnet_model.layer3
        self.layer4 = resnet_model.layer4
        self.averagepool = resnet_model.avgpool

        # Classification head (2048 + O0/O1/O2 + 4 fisher terms = 2055)
        self.classifier = nn.Sequential(
            nn.Linear(2048 + 3 + 4, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def compute_score(self, x):
        if not x.requires_grad:
            x.requires_grad_(True)

        energy = x.mean()
        grads = torch.autograd.grad(
            outputs=energy,
            inputs=x,
            create_graph=True,
            retain_graph=True
        )[0]

        grads_flat = grads.view(grads.size(0), -1)
        if grads_flat.size(1) >= 2:
            grads_2d = grads_flat[:, :2]
        else:
            grads_2d = grads_flat

        scores = -torch.matmul(grads_2d, self.probes.T)
        return scores

    def compute_local_fisher(self, x):
        scores = self.compute_score(x)
        fisher_info = (scores ** 2).mean(dim=1, keepdim=True)
        return fisher_info

    def forward(self, x):
        if x.size(1) == 1:
            x = x.repeat(1, 3, 1, 1)

        x_resized = F.interpolate(x, size=(224, 224), mode='bilinear', align_corners=False)

        with torch.set_grad_enabled(True):
            if not x_resized.requires_grad:
                x_resized.requires_grad_(True)

            O0 = self.compute_local_fisher(x_resized)

            perturbation = torch.randn_like(x_resized) * self.epsilon
            x_pos = x_resized + perturbation
            x_neg = x_resized - perturbation

            I_pos = self.compute_local_fisher(x_pos)
            I_neg = self.compute_local_fisher(x_neg)

            O1 = (I_pos - I_neg) / (2 * self.epsilon)
            O2 = (I_pos - 2 * O0 + I_neg) / (self.epsilon ** 2)

        h = self.intro(x_resized)

        h = self.layer1(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer1 = self.compute_local_fisher(h)

        h = self.layer2(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer2 = self.compute_local_fisher(h)

        h = self.layer3(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer3 = self.compute_local_fisher(h)

        h = self.layer4(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer4 = self.compute_local_fisher(h)

        h_pooled = self.averagepool(h)
        h_flat = h_pooled.flatten(1)

        fish_concat = torch.cat([fish_layer1, fish_layer2, fish_layer3, fish_layer4], dim=1)
        features = torch.cat([h_flat, O0, O1, O2, fish_concat], dim=1)

        logits = self.classifier(features)
        return logits

def run_experiment(model, opt):
    model = model.to(device)
    optimizer = opt
    criterion = nn.CrossEntropyLoss()

    train_losses = []
    test_accuracies = []

    print("Starting MNIST Training...")
    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

            if batch_idx % 100 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")

        avg_loss = epoch_loss / len(train_loader)
        train_losses.append(avg_loss)

        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()

        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.Adam(model.parameters(), lr=LR)
train_losses_resnet50_fisher_adam, test_accuracies_resnet50_fisher_adam = run_experiment(model, opt)

model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.SGD(model.parameters(), lr=LR)
train_losses_resnet50_fisher_sgd, test_accuracies_resnet50_fisher_sgd = run_experiment(model, opt)

model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.RMSprop(model.parameters(), lr=LR)
train_losses_resnet50_fisher_rmsprop, test_accuracies_resnet50_fisher_rmsprop = run_experiment(model, opt)

epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_resnet50_fisher_adam, 'Adam', 'o', 'blue'),
    (train_losses_resnet50_fisher_sgd, 'SGD', 's', 'orange'),
    (train_losses_resnet50_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_resnet50_fisher_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_resnet50_fisher_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_resnet50_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ResNet50_Fisher Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ResNet50_Fisher Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_resnet50_fisher_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_resnet50_fisher_training.png'")
plt.show()
# Out:
# Using device: cuda
# Train samples: 60000, Test samples: 10000
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.3884
# Epoch 0, Batch 100/938: Loss=0.4740
# Epoch 0, Batch 200/938: Loss=0.4056
# Epoch 0, Batch 300/938: Loss=0.4081
# Epoch 0, Batch 400/938: Loss=0.2643
# Epoch 0, Batch 500/938: Loss=0.3080
# Epoch 0, Batch 600/938: Loss=0.3421
# Epoch 0, Batch 700/938: Loss=0.1455
# Epoch 0, Batch 800/938: Loss=0.2320
# Epoch 0, Batch 900/938: Loss=0.0767
# Epoch 0 | Train Loss: 0.3727 | Test Accuracy: 97.56%
# Epoch 1, Batch 0/938: Loss=0.1536
# Epoch 1, Batch 100/938: Loss=0.2141
# Epoch 1, Batch 200/938: Loss=0.0962
# Epoch 1, Batch 300/938: Loss=0.1453
# Epoch 1, Batch 400/938: Loss=0.0747
# Epoch 1, Batch 500/938: Loss=0.3196
# Epoch 1, Batch 600/938: Loss=0.1366
# Epoch 1, Batch 700/938: Loss=0.0957
# Epoch 1, Batch 800/938: Loss=0.0598
# Epoch 1, Batch 900/938: Loss=0.1467
# Epoch 1 | Train Loss: 0.1611 | Test Accuracy: 98.76%
# Epoch 2, Batch 0/938: Loss=0.2588
# Epoch 2, Batch 100/938: Loss=0.1084
# Epoch 2, Batch 200/938: Loss=0.0878
# Epoch 2, Batch 300/938: Loss=0.0341
# Epoch 2, Batch 400/938: Loss=0.2823
# Epoch 2, Batch 500/938: Loss=0.1262
# Epoch 2, Batch 600/938: Loss=0.1387
# Epoch 2, Batch 700/938: Loss=0.1212
# Epoch 2, Batch 800/938: Loss=0.1169
# Epoch 2, Batch 900/938: Loss=0.0695
# Epoch 2 | Train Loss: 0.1323 | Test Accuracy: 98.85%
# Epoch 3, Batch 0/938: Loss=0.0782
# Epoch 3, Batch 100/938: Loss=0.1892
# Epoch 3, Batch 200/938: Loss=0.0994
# Epoch 3, Batch 300/938: Loss=0.0337
# Epoch 3, Batch 400/938: Loss=0.0706
# Epoch 3, Batch 500/938: Loss=0.0663
# Epoch 3, Batch 600/938: Loss=0.2260
# Epoch 3, Batch 700/938: Loss=0.1274
# Epoch 3, Batch 800/938: Loss=0.0988
# Epoch 3, Batch 900/938: Loss=0.1190
# Epoch 3 | Train Loss: 0.1089 | Test Accuracy: 99.23%
# Epoch 4, Batch 0/938: Loss=0.0250
# Epoch 4, Batch 100/938: Loss=0.0338
# Epoch 4, Batch 200/938: Loss=0.1306
# Epoch 4, Batch 300/938: Loss=0.0437
# Epoch 4, Batch 400/938: Loss=0.1900
# Epoch 4, Batch 500/938: Loss=0.2313
# Epoch 4, Batch 600/938: Loss=0.0803
# Epoch 4, Batch 700/938: Loss=0.1048
# Epoch 4, Batch 800/938: Loss=0.0337
# Epoch 4, Batch 900/938: Loss=0.2085
# Epoch 4 | Train Loss: 0.1004 | Test Accuracy: 98.30%
# Epoch 5, Batch 0/938: Loss=0.0931
# Epoch 5, Batch 100/938: Loss=0.0068
# Epoch 5, Batch 200/938: Loss=0.0364
# Epoch 5, Batch 300/938: Loss=0.0086
# Epoch 5, Batch 400/938: Loss=0.0353
# Epoch 5, Batch 500/938: Loss=0.0726
# Epoch 5, Batch 600/938: Loss=0.0188
# Epoch 5, Batch 700/938: Loss=0.0911
# Epoch 5, Batch 800/938: Loss=0.0409
# Epoch 5, Batch 900/938: Loss=0.1271
# Epoch 5 | Train Loss: 0.0918 | Test Accuracy: 97.88%
# Epoch 6, Batch 0/938: Loss=0.0529
# Epoch 6, Batch 100/938: Loss=0.1241
# Epoch 6, Batch 200/938: Loss=0.0625
# Epoch 6, Batch 300/938: Loss=0.0445
# Epoch 6, Batch 400/938: Loss=0.0628
# Epoch 6, Batch 500/938: Loss=0.0574
# Epoch 6, Batch 600/938: Loss=0.0650
# Epoch 6, Batch 700/938: Loss=0.1725
# Epoch 6, Batch 800/938: Loss=0.0533
# Epoch 6, Batch 900/938: Loss=0.1314
# Epoch 6 | Train Loss: 0.0837 | Test Accuracy: 99.12%
# Epoch 7, Batch 0/938: Loss=0.0585
# Epoch 7, Batch 100/938: Loss=0.0680
# Epoch 7, Batch 200/938: Loss=0.0717
# Epoch 7, Batch 300/938: Loss=0.0887
# Epoch 7, Batch 400/938: Loss=0.1256
# Epoch 7, Batch 500/938: Loss=0.0702
# Epoch 7, Batch 600/938: Loss=0.0142
# Epoch 7, Batch 700/938: Loss=0.0545
# Epoch 7, Batch 800/938: Loss=0.0589
# Epoch 7, Batch 900/938: Loss=0.0934
# Epoch 7 | Train Loss: 0.0768 | Test Accuracy: 99.05%
# Epoch 8, Batch 0/938: Loss=0.0228
# Epoch 8, Batch 100/938: Loss=0.0432
# Epoch 8, Batch 200/938: Loss=0.0145
# Epoch 8, Batch 300/938: Loss=0.0499
# Epoch 8, Batch 400/938: Loss=0.3503
# Epoch 8, Batch 500/938: Loss=0.0446
# Epoch 8, Batch 600/938: Loss=0.0245
# Epoch 8, Batch 700/938: Loss=0.0214
# Epoch 8, Batch 800/938: Loss=0.0189
# Epoch 8, Batch 900/938: Loss=0.1552
# Epoch 8 | Train Loss: 0.0677 | Test Accuracy: 99.21%
# Epoch 9, Batch 0/938: Loss=0.0423
# Epoch 9, Batch 100/938: Loss=0.0193
# Epoch 9, Batch 200/938: Loss=0.0095
# Epoch 9, Batch 300/938: Loss=0.0185
# Epoch 9, Batch 400/938: Loss=0.2244
# Epoch 9, Batch 500/938: Loss=0.0210
# Epoch 9, Batch 600/938: Loss=0.0965
# Epoch 9, Batch 700/938: Loss=0.0513
# Epoch 9, Batch 800/938: Loss=0.0162
# Epoch 9, Batch 900/938: Loss=0.1172
# Epoch 9 | Train Loss: 0.0677 | Test Accuracy: 99.21%
# Final Test Accuracy: 99.21%
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.3659
# Epoch 0, Batch 100/938: Loss=2.2754
# Epoch 0, Batch 200/938: Loss=2.2345
# Epoch 0, Batch 300/938: Loss=2.2093
# Epoch 0, Batch 400/938: Loss=2.1565
# Epoch 0, Batch 500/938: Loss=2.0838
# Epoch 0, Batch 600/938: Loss=2.1197
# Epoch 0, Batch 700/938: Loss=2.0743
# Epoch 0, Batch 800/938: Loss=2.0425
# Epoch 0, Batch 900/938: Loss=1.9872
# Epoch 0 | Train Loss: 2.1601 | Test Accuracy: 27.08%
# Epoch 1, Batch 0/938: Loss=1.9950
# Epoch 1, Batch 100/938: Loss=2.0278
# Epoch 1, Batch 200/938: Loss=1.9241
# Epoch 1, Batch 300/938: Loss=2.0668
# Epoch 1, Batch 400/938: Loss=1.9386
# Epoch 1, Batch 500/938: Loss=1.8348
# Epoch 1, Batch 600/938: Loss=1.9172
# Epoch 1, Batch 700/938: Loss=1.8909
# Epoch 1, Batch 800/938: Loss=1.8737
# Epoch 1, Batch 900/938: Loss=1.7830
# Epoch 1 | Train Loss: 1.9020 | Test Accuracy: 13.86%
# Epoch 2, Batch 0/938: Loss=1.9368
# Epoch 2, Batch 100/938: Loss=1.9254
# Epoch 2, Batch 200/938: Loss=1.6863
# Epoch 2, Batch 300/938: Loss=1.7333
# Epoch 2, Batch 400/938: Loss=1.8937
# Epoch 2, Batch 500/938: Loss=1.8430
# Epoch 2, Batch 600/938: Loss=1.6281
# Epoch 2, Batch 700/938: Loss=1.6777
# Epoch 2, Batch 800/938: Loss=2.0716
# Epoch 2, Batch 900/938: Loss=1.6839
# Epoch 2 | Train Loss: 1.7735 | Test Accuracy: 28.97%
# Epoch 3, Batch 0/938: Loss=1.6833
# Epoch 3, Batch 100/938: Loss=1.5357
# Epoch 3, Batch 200/938: Loss=1.6838
# Epoch 3, Batch 300/938: Loss=1.7067
# Epoch 3, Batch 400/938: Loss=1.5503
# Epoch 3, Batch 500/938: Loss=1.7010
# Epoch 3, Batch 600/938: Loss=1.5202
# Epoch 3, Batch 700/938: Loss=1.6720
# Epoch 3, Batch 800/938: Loss=1.5423
# Epoch 3, Batch 900/938: Loss=1.5649
# Epoch 3 | Train Loss: 1.6416 | Test Accuracy: 48.23%
# Epoch 4, Batch 0/938: Loss=1.4662
# Epoch 4, Batch 100/938: Loss=1.4364
# Epoch 4, Batch 200/938: Loss=1.6055
# Epoch 4, Batch 300/938: Loss=1.6847
# Epoch 4, Batch 400/938: Loss=1.6296
# Epoch 4, Batch 500/938: Loss=1.4412
# Epoch 4, Batch 600/938: Loss=1.2779
# Epoch 4, Batch 700/938: Loss=1.4022
# Epoch 4, Batch 800/938: Loss=1.4987
# Epoch 4, Batch 900/938: Loss=1.2481
# Epoch 4 | Train Loss: 1.4709 | Test Accuracy: 53.75%
# Epoch 5, Batch 0/938: Loss=1.1923
# Epoch 5, Batch 100/938: Loss=1.3505
# Epoch 5, Batch 200/938: Loss=1.2411
# Epoch 5, Batch 300/938: Loss=1.2533
# Epoch 5, Batch 400/938: Loss=1.3336
# Epoch 5, Batch 500/938: Loss=1.4171
# Epoch 5, Batch 600/938: Loss=1.2002
# Epoch 5, Batch 700/938: Loss=1.1918
# Epoch 5, Batch 800/938: Loss=1.3165
# Epoch 5, Batch 900/938: Loss=1.0912
# Epoch 5 | Train Loss: 1.3017 | Test Accuracy: 63.80%
# Epoch 6, Batch 0/938: Loss=1.1853
# Epoch 6, Batch 100/938: Loss=1.1924
# Epoch 6, Batch 200/938: Loss=1.1969
# Epoch 6, Batch 300/938: Loss=1.1616
# Epoch 6, Batch 400/938: Loss=1.2394
# Epoch 6, Batch 500/938: Loss=1.1121
# Epoch 6, Batch 600/938: Loss=1.0943
# Epoch 6, Batch 700/938: Loss=1.0912
# Epoch 6, Batch 800/938: Loss=1.1027
# Epoch 6, Batch 900/938: Loss=1.0236
# Epoch 6 | Train Loss: 1.1603 | Test Accuracy: 51.02%
# Epoch 7, Batch 0/938: Loss=1.1670
# Epoch 7, Batch 100/938: Loss=0.9444
# Epoch 7, Batch 200/938: Loss=1.0845
# Epoch 7, Batch 300/938: Loss=1.0554
# Epoch 7, Batch 400/938: Loss=1.0002
# Epoch 7, Batch 500/938: Loss=0.8801
# Epoch 7, Batch 600/938: Loss=0.8777
# Epoch 7, Batch 700/938: Loss=0.9289
# Epoch 7, Batch 800/938: Loss=0.8690
# Epoch 7, Batch 900/938: Loss=1.1953
# Epoch 7 | Train Loss: 1.0113 | Test Accuracy: 70.03%
# Epoch 8, Batch 0/938: Loss=1.0624
# Epoch 8, Batch 100/938: Loss=0.9349
# Epoch 8, Batch 200/938: Loss=1.1589
# Epoch 8, Batch 300/938: Loss=1.0536
# Epoch 8, Batch 400/938: Loss=0.8231
# Epoch 8, Batch 500/938: Loss=1.0590
# Epoch 8, Batch 600/938: Loss=0.9623
# Epoch 8, Batch 700/938: Loss=0.9638
# Epoch 8, Batch 800/938: Loss=0.6757
# Epoch 8, Batch 900/938: Loss=0.7511
# Epoch 8 | Train Loss: 0.8672 | Test Accuracy: 76.77%
# Epoch 9, Batch 0/938: Loss=0.8588
# Epoch 9, Batch 100/938: Loss=0.6403
# Epoch 9, Batch 200/938: Loss=0.5761
# Epoch 9, Batch 300/938: Loss=0.9652
# Epoch 9, Batch 400/938: Loss=0.6560
# Epoch 9, Batch 500/938: Loss=0.7097
# Epoch 9, Batch 600/938: Loss=0.7590
# Epoch 9, Batch 700/938: Loss=0.7907
# Epoch 9, Batch 800/938: Loss=0.5914
# Epoch 9, Batch 900/938: Loss=0.5326
# Epoch 9 | Train Loss: 0.7203 | Test Accuracy: 84.61%
# Final Test Accuracy: 84.61%
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.3291
# Epoch 0, Batch 100/938: Loss=1.6670
# Epoch 0, Batch 200/938: Loss=0.9041
# Epoch 0, Batch 300/938: Loss=0.9982
# Epoch 0, Batch 400/938: Loss=0.6120
# Epoch 0, Batch 500/938: Loss=0.5049
# Epoch 0, Batch 600/938: Loss=0.5116
# Epoch 0, Batch 700/938: Loss=0.4013
# Epoch 0, Batch 800/938: Loss=0.4589
# Epoch 0, Batch 900/938: Loss=0.4113
# Epoch 0 | Train Loss: 0.8811 | Test Accuracy: 95.86%
# Epoch 1, Batch 0/938: Loss=0.4460
# Epoch 1, Batch 100/938: Loss=0.5592
# Epoch 1, Batch 200/938: Loss=0.6401
# Epoch 1, Batch 300/938: Loss=0.4824
# Epoch 1, Batch 400/938: Loss=0.4432
# Epoch 1, Batch 500/938: Loss=0.3935
# Epoch 1, Batch 600/938: Loss=0.4751
# Epoch 1, Batch 700/938: Loss=0.3222
# Epoch 1, Batch 800/938: Loss=0.2907
# Epoch 1, Batch 900/938: Loss=0.5900
# Epoch 1 | Train Loss: 0.3897 | Test Accuracy: 94.08%
# Epoch 2, Batch 0/938: Loss=0.3564
# Epoch 2, Batch 100/938: Loss=0.3879
# Epoch 2, Batch 200/938: Loss=0.2928
# Epoch 2, Batch 300/938: Loss=0.2590
# Epoch 2, Batch 400/938: Loss=0.3984
# Epoch 2, Batch 500/938: Loss=0.2148
# Epoch 2, Batch 600/938: Loss=0.5121
# Epoch 2, Batch 700/938: Loss=0.4498
# Epoch 2, Batch 800/938: Loss=0.4593
# Epoch 2, Batch 900/938: Loss=0.3277
# Epoch 2 | Train Loss: 0.2996 | Test Accuracy: 97.73%
# Epoch 3, Batch 0/938: Loss=0.1783
# Epoch 3, Batch 100/938: Loss=0.2374
# Epoch 3, Batch 200/938: Loss=0.3879
# Epoch 3, Batch 300/938: Loss=0.1198
# Epoch 3, Batch 400/938: Loss=0.2169
# Epoch 3, Batch 500/938: Loss=0.1962
# Epoch 3, Batch 600/938: Loss=0.5771
# Epoch 3, Batch 700/938: Loss=0.1403
# Epoch 3, Batch 800/938: Loss=0.1347
# Epoch 3, Batch 900/938: Loss=0.2267
# Epoch 3 | Train Loss: 0.2401 | Test Accuracy: 98.96%
# Epoch 4, Batch 0/938: Loss=0.3482
# Epoch 4, Batch 100/938: Loss=0.1503
# Epoch 4, Batch 200/938: Loss=0.1159
# Epoch 4, Batch 300/938: Loss=0.1199
# Epoch 4, Batch 400/938: Loss=0.0910
# Epoch 4, Batch 500/938: Loss=0.2871
# Epoch 4, Batch 600/938: Loss=0.2525
# Epoch 4, Batch 700/938: Loss=0.1440
# Epoch 4, Batch 800/938: Loss=0.1520
# Epoch 4, Batch 900/938: Loss=0.3578
# Epoch 4 | Train Loss: 0.1970 | Test Accuracy: 97.84%
# Epoch 5, Batch 0/938: Loss=0.2981
# Epoch 5, Batch 100/938: Loss=0.3211
# Epoch 5, Batch 200/938: Loss=0.1189
# Epoch 5, Batch 300/938: Loss=0.1736
# Epoch 5, Batch 400/938: Loss=0.0638
# Epoch 5, Batch 500/938: Loss=0.1415
# Epoch 5, Batch 600/938: Loss=0.1651
# Epoch 5, Batch 700/938: Loss=0.1321
# Epoch 5, Batch 800/938: Loss=0.3232
# Epoch 5, Batch 900/938: Loss=0.1934
# Epoch 5 | Train Loss: 0.1827 | Test Accuracy: 98.24%
# Epoch 6, Batch 0/938: Loss=0.1904
# Epoch 6, Batch 100/938: Loss=0.1626
# Epoch 6, Batch 200/938: Loss=0.1127
# Epoch 6, Batch 300/938: Loss=0.6169
# Epoch 6, Batch 400/938: Loss=0.1685
# Epoch 6, Batch 500/938: Loss=0.1120
# Epoch 6, Batch 600/938: Loss=0.1065
# Epoch 6, Batch 700/938: Loss=0.1176
# Epoch 6, Batch 800/938: Loss=0.1345
# Epoch 6, Batch 900/938: Loss=0.0602
# Epoch 6 | Train Loss: 0.1654 | Test Accuracy: 98.89%
# Epoch 7, Batch 0/938: Loss=0.1496
# Epoch 7, Batch 100/938: Loss=0.2740
# Epoch 7, Batch 200/938: Loss=0.1265
# Epoch 7, Batch 300/938: Loss=0.0920
# Epoch 7, Batch 400/938: Loss=0.1065
# Epoch 7, Batch 500/938: Loss=0.1900
# Epoch 7, Batch 600/938: Loss=0.1419
# Epoch 7, Batch 700/938: Loss=0.1190
# Epoch 7, Batch 800/938: Loss=0.0568
# Epoch 7, Batch 900/938: Loss=0.0696
# Epoch 7 | Train Loss: 0.1594 | Test Accuracy: 99.01%
# Epoch 8, Batch 0/938: Loss=0.0324
# Epoch 8, Batch 100/938: Loss=0.1387
# Epoch 8, Batch 200/938: Loss=0.0748
# Epoch 8, Batch 300/938: Loss=0.1784
# Epoch 8, Batch 400/938: Loss=0.5030
# Epoch 8, Batch 500/938: Loss=0.0727
# Epoch 8, Batch 600/938: Loss=0.0537
# Epoch 8, Batch 700/938: Loss=0.3500
# Epoch 8, Batch 800/938: Loss=0.1284
# Epoch 8, Batch 900/938: Loss=0.1163
# Epoch 8 | Train Loss: 0.1351 | Test Accuracy: 98.76%
# Epoch 9, Batch 0/938: Loss=0.1313
# Epoch 9, Batch 100/938: Loss=0.0940
# Epoch 9, Batch 200/938: Loss=0.1140
# Epoch 9, Batch 300/938: Loss=0.0859
# Epoch 9, Batch 400/938: Loss=0.0499
# Epoch 9, Batch 500/938: Loss=0.0359
# Epoch 9, Batch 600/938: Loss=0.0659
# Epoch 9, Batch 700/938: Loss=0.1298
# Epoch 9, Batch 800/938: Loss=0.1587
# Epoch 9, Batch 900/938: Loss=0.1516
# Epoch 9 | Train Loss: 0.1250 | Test Accuracy: 98.94%
# Final Test Accuracy: 98.94%
# Training plots saved as 'mnist_resnet50_fisher_training.png'

# %%
import torch, torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# Dataset parameters
NUM_CLASSES = 10
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

K_PROBES = 4
EPSILON = 0.1

# Device setup for CUDA
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Load MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST mean and std
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

class MNISTClassifier(nn.Module):
    def __init__(self, num_classes, k_probes, epsilon):
        super().__init__()
        self.epsilon = epsilon
        self.k_probes = k_probes
        self.num_classes = num_classes

        v = torch.randn(k_probes, 2)  # 2D probe directions
        v = v / torch.norm(v, dim=1, keepdim=True)
        self.register_buffer('probes', v)

        # ResNet101 backbone
        resnet_model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet101', pretrained=False)
        self.intro = nn.Sequential(
            resnet_model.conv1,
            resnet_model.bn1,
            resnet_model.relu,
            resnet_model.maxpool
        )
        self.layer1 = resnet_model.layer1
        self.layer2 = resnet_model.layer2
        self.layer3 = resnet_model.layer3
        self.layer4 = resnet_model.layer4
        self.averagepool = resnet_model.avgpool

        # Classification head (2048 + O0/O1/O2 + 4 fisher terms = 2055)
        self.classifier = nn.Sequential(
            nn.Linear(2048 + 3 + 4, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def compute_score(self, x):
        if not x.requires_grad:
            x.requires_grad_(True)

        energy = x.mean()
        grads = torch.autograd.grad(
            outputs=energy,
            inputs=x,
            create_graph=True,
            retain_graph=True
        )[0]

        grads_flat = grads.view(grads.size(0), -1)
        if grads_flat.size(1) >= 2:
            grads_2d = grads_flat[:, :2]
        else:
            grads_2d = grads_flat

        scores = -torch.matmul(grads_2d, self.probes.T)
        return scores

    def compute_local_fisher(self, x):
        scores = self.compute_score(x)
        fisher_info = (scores ** 2).mean(dim=1, keepdim=True)
        return fisher_info

    def forward(self, x):
        if x.size(1) == 1:
            x = x.repeat(1, 3, 1, 1)

        x_resized = F.interpolate(x, size=(224, 224), mode='bilinear', align_corners=False)

        with torch.set_grad_enabled(True):
            if not x_resized.requires_grad:
                x_resized.requires_grad_(True)

            O0 = self.compute_local_fisher(x_resized)

            perturbation = torch.randn_like(x_resized) * self.epsilon
            x_pos = x_resized + perturbation
            x_neg = x_resized - perturbation

            I_pos = self.compute_local_fisher(x_pos)
            I_neg = self.compute_local_fisher(x_neg)

            O1 = (I_pos - I_neg) / (2 * self.epsilon)
            O2 = (I_pos - 2 * O0 + I_neg) / (self.epsilon ** 2)

        h = self.intro(x_resized)

        h = self.layer1(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer1 = self.compute_local_fisher(h)

        h = self.layer2(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer2 = self.compute_local_fisher(h)

        h = self.layer3(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer3 = self.compute_local_fisher(h)

        h = self.layer4(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer4 = self.compute_local_fisher(h)

        h_pooled = self.averagepool(h)
        h_flat = h_pooled.flatten(1)

        fish_concat = torch.cat([fish_layer1, fish_layer2, fish_layer3, fish_layer4], dim=1)
        features = torch.cat([h_flat, O0, O1, O2, fish_concat], dim=1)

        logits = self.classifier(features)
        return logits

def run_experiment(model, opt):
    model = model.to(device)
    optimizer = opt
    criterion = nn.CrossEntropyLoss()

    train_losses = []
    test_accuracies = []

    print("Starting MNIST Training...")
    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

            if batch_idx % 100 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")

        avg_loss = epoch_loss / len(train_loader)
        train_losses.append(avg_loss)

        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()

        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.Adam(model.parameters(), lr=LR)
train_losses_resnet101_fisher_adam, test_accuracies_resnet101_fisher_adam = run_experiment(model, opt)

model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.SGD(model.parameters(), lr=LR)
train_losses_resnet101_fisher_sgd, test_accuracies_resnet101_fisher_sgd = run_experiment(model, opt)

model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.RMSprop(model.parameters(), lr=LR)
train_losses_resnet101_fisher_rmsprop, test_accuracies_resnet101_fisher_rmsprop = run_experiment(model, opt)

epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_resnet101_fisher_adam, 'Adam', 'o', 'blue'),
    (train_losses_resnet101_fisher_sgd, 'SGD', 's', 'orange'),
    (train_losses_resnet101_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_resnet101_fisher_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_resnet101_fisher_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_resnet101_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ResNet101_Fisher Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ResNet101_Fisher Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_resnet101_fisher_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_resnet101_fisher_training.png'")
plt.show()
# Out:
# Using device: cuda
# Train samples: 60000, Test samples: 10000
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.3226
# Epoch 0, Batch 100/938: Loss=1.0338
# Epoch 0, Batch 200/938: Loss=0.7888
# Epoch 0, Batch 300/938: Loss=0.4324
# Epoch 0, Batch 400/938: Loss=0.4379
# Epoch 0, Batch 500/938: Loss=0.3890
# Epoch 0, Batch 600/938: Loss=0.5625
# Epoch 0, Batch 700/938: Loss=0.5830
# Epoch 0, Batch 800/938: Loss=0.3447
# Epoch 0, Batch 900/938: Loss=0.3217
# Epoch 0 | Train Loss: 0.6383 | Test Accuracy: 96.58%
# Epoch 1, Batch 0/938: Loss=0.3128
# Epoch 1, Batch 100/938: Loss=0.2507
# Epoch 1, Batch 200/938: Loss=0.2027
# Epoch 1, Batch 300/938: Loss=0.3356
# Epoch 1, Batch 400/938: Loss=0.3675
# Epoch 1, Batch 500/938: Loss=0.1056
# Epoch 1, Batch 600/938: Loss=0.2811
# Epoch 1, Batch 700/938: Loss=0.2377
# Epoch 1, Batch 800/938: Loss=0.2691
# Epoch 1, Batch 900/938: Loss=0.2216
# Epoch 1 | Train Loss: 0.3323 | Test Accuracy: 98.15%
# Epoch 2, Batch 0/938: Loss=0.3084
# Epoch 2, Batch 100/938: Loss=0.2170
# Epoch 2, Batch 200/938: Loss=0.2995
# Epoch 2, Batch 300/938: Loss=0.3019
# Epoch 2, Batch 400/938: Loss=0.1979
# Epoch 2, Batch 500/938: Loss=0.2826
# Epoch 2, Batch 600/938: Loss=0.2583
# Epoch 2, Batch 700/938: Loss=0.3311
# Epoch 2, Batch 800/938: Loss=0.2875
# Epoch 2, Batch 900/938: Loss=0.1306
# Epoch 2 | Train Loss: 0.2780 | Test Accuracy: 98.48%
# Epoch 3, Batch 0/938: Loss=0.1147
# Epoch 3, Batch 100/938: Loss=0.2119
# Epoch 3, Batch 200/938: Loss=0.7297
# Epoch 3, Batch 300/938: Loss=0.1020
# Epoch 3, Batch 400/938: Loss=0.5721
# Epoch 3, Batch 500/938: Loss=0.1869
# Epoch 3, Batch 600/938: Loss=0.1521
# Epoch 3, Batch 700/938: Loss=0.2927
# Epoch 3, Batch 800/938: Loss=0.0993
# Epoch 3, Batch 900/938: Loss=0.8327
# Epoch 3 | Train Loss: 0.2528 | Test Accuracy: 98.66%
# Epoch 4, Batch 0/938: Loss=0.1972
# Epoch 4, Batch 100/938: Loss=0.2062
# Epoch 4, Batch 200/938: Loss=0.2500
# Epoch 4, Batch 300/938: Loss=0.1589
# Epoch 4, Batch 400/938: Loss=0.2547
# Epoch 4, Batch 500/938: Loss=0.3235
# Epoch 4, Batch 600/938: Loss=0.1361
# Epoch 4, Batch 700/938: Loss=0.1570
# Epoch 4, Batch 800/938: Loss=0.2109
# Epoch 4, Batch 900/938: Loss=0.1231
# Epoch 4 | Train Loss: 0.2249 | Test Accuracy: 98.85%
# Epoch 5, Batch 0/938: Loss=0.1371
# Epoch 5, Batch 100/938: Loss=0.1420
# Epoch 5, Batch 200/938: Loss=0.1061
# Epoch 5, Batch 300/938: Loss=0.5407
# Epoch 5, Batch 400/938: Loss=0.1433
# Epoch 5, Batch 500/938: Loss=0.1494
# Epoch 5, Batch 600/938: Loss=0.0675
# Epoch 5, Batch 700/938: Loss=0.2974
# Epoch 5, Batch 800/938: Loss=0.0991
# Epoch 5, Batch 900/938: Loss=0.1462
# Epoch 5 | Train Loss: 0.2107 | Test Accuracy: 98.74%
# Epoch 6, Batch 0/938: Loss=0.1561
# Epoch 6, Batch 100/938: Loss=0.1420
# Epoch 6, Batch 200/938: Loss=0.2334
# Epoch 6, Batch 300/938: Loss=0.1659
# Epoch 6, Batch 400/938: Loss=0.2035
# Epoch 6, Batch 500/938: Loss=0.1219
# Epoch 6, Batch 600/938: Loss=0.1701
# Epoch 6, Batch 700/938: Loss=0.1068
# Epoch 6, Batch 800/938: Loss=0.0768
# Epoch 6, Batch 900/938: Loss=0.2582
# Epoch 6 | Train Loss: 0.2021 | Test Accuracy: 99.06%
# Epoch 7, Batch 0/938: Loss=0.1726
# Epoch 7, Batch 100/938: Loss=0.2057
# Epoch 7, Batch 200/938: Loss=0.1401
# Epoch 7, Batch 300/938: Loss=0.1225
# Epoch 7, Batch 400/938: Loss=0.2009
# Epoch 7, Batch 500/938: Loss=0.1753
# Epoch 7, Batch 600/938: Loss=1.2787
# Epoch 7, Batch 700/938: Loss=0.1307
# Epoch 7, Batch 800/938: Loss=0.2371
# Epoch 7, Batch 900/938: Loss=0.0658
# Epoch 7 | Train Loss: 0.1898 | Test Accuracy: 98.99%
# Epoch 8, Batch 0/938: Loss=0.1628
# Epoch 8, Batch 100/938: Loss=0.1564
# Epoch 8, Batch 200/938: Loss=0.1069
# Epoch 8, Batch 300/938: Loss=0.1701
# Epoch 8, Batch 400/938: Loss=0.1759
# Epoch 8, Batch 500/938: Loss=0.1473
# Epoch 8, Batch 600/938: Loss=0.1615
# Epoch 8, Batch 700/938: Loss=0.0412
# Epoch 8, Batch 800/938: Loss=0.1602
# Epoch 8, Batch 900/938: Loss=0.1333
# Epoch 8 | Train Loss: 0.1713 | Test Accuracy: 98.87%
# Epoch 9, Batch 0/938: Loss=0.3384
# Epoch 9, Batch 100/938: Loss=0.1594
# Epoch 9, Batch 200/938: Loss=0.1656
# Epoch 9, Batch 300/938: Loss=0.3368
# Epoch 9, Batch 400/938: Loss=0.3689
# Epoch 9, Batch 500/938: Loss=0.2407
# Epoch 9, Batch 600/938: Loss=0.1950
# Epoch 9, Batch 700/938: Loss=0.2616
# Epoch 9, Batch 800/938: Loss=0.1734
# Epoch 9, Batch 900/938: Loss=0.0956
# Epoch 9 | Train Loss: 0.1716 | Test Accuracy: 99.24%
# Final Test Accuracy: 99.24%
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.3154
# Epoch 0, Batch 100/938: Loss=2.3085
# Epoch 0, Batch 200/938: Loss=2.3007
# Epoch 0, Batch 300/938: Loss=2.2306
# Epoch 0, Batch 400/938: Loss=2.1934
# Epoch 0, Batch 500/938: Loss=2.1873
# Epoch 0, Batch 600/938: Loss=2.1905
# Epoch 0, Batch 700/938: Loss=2.1135
# Epoch 0, Batch 800/938: Loss=2.1371
# Epoch 0, Batch 900/938: Loss=2.1124
# Epoch 0 | Train Loss: 2.1860 | Test Accuracy: 22.76%
# Epoch 1, Batch 0/938: Loss=2.0078
# Epoch 1, Batch 100/938: Loss=2.1137
# Epoch 1, Batch 200/938: Loss=2.0426
# Epoch 1, Batch 300/938: Loss=1.9664
# Epoch 1, Batch 400/938: Loss=1.9165
# Epoch 1, Batch 500/938: Loss=1.8475
# Epoch 1, Batch 600/938: Loss=1.9988
# Epoch 1, Batch 700/938: Loss=1.9920
# Epoch 1, Batch 800/938: Loss=1.8771
# Epoch 1, Batch 900/938: Loss=2.1020
# Epoch 1 | Train Loss: 1.9720 | Test Accuracy: 28.75%
# Epoch 2, Batch 0/938: Loss=1.9857
# Epoch 2, Batch 100/938: Loss=1.7571
# Epoch 2, Batch 200/938: Loss=1.9594
# Epoch 2, Batch 300/938: Loss=1.8193
# Epoch 2, Batch 400/938: Loss=1.7560
# Epoch 2, Batch 500/938: Loss=1.7110
# Epoch 2, Batch 600/938: Loss=1.8035
# Epoch 2, Batch 700/938: Loss=1.7082
# Epoch 2, Batch 800/938: Loss=1.6872
# Epoch 2, Batch 900/938: Loss=1.6542
# Epoch 2 | Train Loss: 1.8246 | Test Accuracy: 29.66%
# Epoch 3, Batch 0/938: Loss=1.6930
# Epoch 3, Batch 100/938: Loss=1.7277
# Epoch 3, Batch 200/938: Loss=1.5813
# Epoch 3, Batch 300/938: Loss=1.5924
# Epoch 3, Batch 400/938: Loss=1.5252
# Epoch 3, Batch 500/938: Loss=1.8773
# Epoch 3, Batch 600/938: Loss=1.6265
# Epoch 3, Batch 700/938: Loss=1.5671
# Epoch 3, Batch 800/938: Loss=1.5540
# Epoch 3, Batch 900/938: Loss=1.6655
# Epoch 3 | Train Loss: 1.7053 | Test Accuracy: 41.06%
# Epoch 4, Batch 0/938: Loss=1.5840
# Epoch 4, Batch 100/938: Loss=1.5747
# Epoch 4, Batch 200/938: Loss=1.6513
# Epoch 4, Batch 300/938: Loss=1.5934
# Epoch 4, Batch 400/938: Loss=1.7052
# Epoch 4, Batch 500/938: Loss=1.6622
# Epoch 4, Batch 600/938: Loss=1.5827
# Epoch 4, Batch 700/938: Loss=1.7628
# Epoch 4, Batch 800/938: Loss=1.5559
# Epoch 4, Batch 900/938: Loss=1.4591
# Epoch 4 | Train Loss: 1.5990 | Test Accuracy: 26.37%
# Epoch 5, Batch 0/938: Loss=1.6538
# Epoch 5, Batch 100/938: Loss=1.6971
# Epoch 5, Batch 200/938: Loss=1.4448
# Epoch 5, Batch 300/938: Loss=1.7466
# Epoch 5, Batch 400/938: Loss=1.3918
# Epoch 5, Batch 500/938: Loss=1.4636
# Epoch 5, Batch 600/938: Loss=1.4866
# Epoch 5, Batch 700/938: Loss=1.4853
# Epoch 5, Batch 800/938: Loss=1.3203
# Epoch 5, Batch 900/938: Loss=1.6832
# Epoch 5 | Train Loss: 1.4583 | Test Accuracy: 34.82%
# Epoch 6, Batch 0/938: Loss=1.4007
# Epoch 6, Batch 100/938: Loss=1.3897
# Epoch 6, Batch 200/938: Loss=1.3292
# Epoch 6, Batch 300/938: Loss=1.3890
# Epoch 6, Batch 400/938: Loss=1.3321
# Epoch 6, Batch 500/938: Loss=1.2668
# Epoch 6, Batch 600/938: Loss=1.3898
# Epoch 6, Batch 700/938: Loss=1.2709
# Epoch 6, Batch 800/938: Loss=1.1927
# Epoch 6, Batch 900/938: Loss=1.0983
# Epoch 6 | Train Loss: 1.3350 | Test Accuracy: 56.67%
# Epoch 7, Batch 0/938: Loss=1.3441
# Epoch 7, Batch 100/938: Loss=1.2595
# Epoch 7, Batch 200/938: Loss=1.2720
# Epoch 7, Batch 300/938: Loss=1.0514
# Epoch 7, Batch 400/938: Loss=1.2661
# Epoch 7, Batch 500/938: Loss=1.3100
# Epoch 7, Batch 600/938: Loss=1.3218
# Epoch 7, Batch 700/938: Loss=1.2146
# Epoch 7, Batch 800/938: Loss=1.2453
# Epoch 7, Batch 900/938: Loss=1.2758
# Epoch 7 | Train Loss: 1.2263 | Test Accuracy: 62.39%
# Epoch 8, Batch 0/938: Loss=1.1943
# Epoch 8, Batch 100/938: Loss=1.0867
# Epoch 8, Batch 200/938: Loss=1.0609
# Epoch 8, Batch 300/938: Loss=1.2752
# Epoch 8, Batch 400/938: Loss=1.1132
# Epoch 8, Batch 500/938: Loss=1.0171
# Epoch 8, Batch 600/938: Loss=1.0297
# Epoch 8, Batch 700/938: Loss=1.0219
# Epoch 8, Batch 800/938: Loss=1.2725
# Epoch 8, Batch 900/938: Loss=1.0495
# Epoch 8 | Train Loss: 1.1263 | Test Accuracy: 68.93%
# Epoch 9, Batch 0/938: Loss=1.0386
# Epoch 9, Batch 100/938: Loss=1.0704
# Epoch 9, Batch 200/938: Loss=0.9161
# Epoch 9, Batch 300/938: Loss=1.2379
# Epoch 9, Batch 400/938: Loss=1.0303
# Epoch 9, Batch 500/938: Loss=1.0575
# Epoch 9, Batch 600/938: Loss=1.0420
# Epoch 9, Batch 700/938: Loss=1.2989
# Epoch 9, Batch 800/938: Loss=0.9209
# Epoch 9, Batch 900/938: Loss=1.0463
# Epoch 9 | Train Loss: 1.0400 | Test Accuracy: 71.53%
# Final Test Accuracy: 71.53%
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.4187
# Epoch 0, Batch 100/938: Loss=1.1120
# Epoch 0, Batch 200/938: Loss=0.8333
# Epoch 0, Batch 300/938: Loss=0.2527
# Epoch 0, Batch 400/938: Loss=0.6971
# Epoch 0, Batch 500/938: Loss=0.5458
# Epoch 0, Batch 600/938: Loss=0.2434
# Epoch 0, Batch 700/938: Loss=0.2475
# Epoch 0, Batch 800/938: Loss=0.4390
# Epoch 0, Batch 900/938: Loss=0.5214
# Epoch 0 | Train Loss: 0.6579 | Test Accuracy: 83.32%
# Epoch 1, Batch 0/938: Loss=0.5559
# Epoch 1, Batch 100/938: Loss=0.4965
# Epoch 1, Batch 200/938: Loss=0.6779
# Epoch 1, Batch 300/938: Loss=0.3189
# Epoch 1, Batch 400/938: Loss=0.2033
# Epoch 1, Batch 500/938: Loss=0.1013
# Epoch 1, Batch 600/938: Loss=0.1830
# Epoch 1, Batch 700/938: Loss=0.3323
# Epoch 1, Batch 800/938: Loss=0.1535
# Epoch 1, Batch 900/938: Loss=0.1231
# Epoch 1 | Train Loss: 0.2107 | Test Accuracy: 97.81%
# Epoch 2, Batch 0/938: Loss=0.1248
# Epoch 2, Batch 100/938: Loss=0.2341
# Epoch 2, Batch 200/938: Loss=0.1426
# Epoch 2, Batch 300/938: Loss=0.0762
# Epoch 2, Batch 400/938: Loss=0.1511
# Epoch 2, Batch 500/938: Loss=0.1091
# Epoch 2, Batch 600/938: Loss=0.1871
# Epoch 2, Batch 700/938: Loss=0.1019
# Epoch 2, Batch 800/938: Loss=0.2033
# Epoch 2, Batch 900/938: Loss=0.0517
# Epoch 2 | Train Loss: 0.1512 | Test Accuracy: 97.68%
# Epoch 3, Batch 0/938: Loss=0.1723
# Epoch 3, Batch 100/938: Loss=0.6853
# Epoch 3, Batch 200/938: Loss=0.0327
# Epoch 3, Batch 300/938: Loss=0.1877
# Epoch 3, Batch 400/938: Loss=0.0972
# Epoch 3, Batch 500/938: Loss=0.0313
# Epoch 3, Batch 600/938: Loss=0.1977
# Epoch 3, Batch 700/938: Loss=0.1649
# Epoch 3, Batch 800/938: Loss=0.0481
# Epoch 3, Batch 900/938: Loss=0.1058
# Epoch 3 | Train Loss: 0.1240 | Test Accuracy: 98.44%
# Epoch 4, Batch 0/938: Loss=0.2199
# Epoch 4, Batch 100/938: Loss=0.1232
# Epoch 4, Batch 200/938: Loss=0.1371
# Epoch 4, Batch 300/938: Loss=0.0648
# Epoch 4, Batch 400/938: Loss=0.0355
# Epoch 4, Batch 500/938: Loss=0.1583
# Epoch 4, Batch 600/938: Loss=0.1279
# Epoch 4, Batch 700/938: Loss=0.1354
# Epoch 4, Batch 800/938: Loss=0.0587
# Epoch 4, Batch 900/938: Loss=0.0351
# Epoch 4 | Train Loss: 0.1032 | Test Accuracy: 98.60%
# Epoch 5, Batch 0/938: Loss=0.0791
# Epoch 5, Batch 100/938: Loss=0.0677
# Epoch 5, Batch 200/938: Loss=0.0336
# Epoch 5, Batch 300/938: Loss=0.0306
# Epoch 5, Batch 400/938: Loss=0.0092
# Epoch 5, Batch 500/938: Loss=0.0607
# Epoch 5, Batch 600/938: Loss=0.1618
# Epoch 5, Batch 700/938: Loss=0.0799
# Epoch 5, Batch 800/938: Loss=0.0114
# Epoch 5, Batch 900/938: Loss=0.1157
# Epoch 5 | Train Loss: 0.0953 | Test Accuracy: 99.26%
# Epoch 6, Batch 0/938: Loss=0.0431
# Epoch 6, Batch 100/938: Loss=0.4438
# Epoch 6, Batch 200/938: Loss=0.0183
# Epoch 6, Batch 300/938: Loss=0.1476
# Epoch 6, Batch 400/938: Loss=0.0328
# Epoch 6, Batch 500/938: Loss=0.1109
# Epoch 6, Batch 600/938: Loss=0.0354
# Epoch 6, Batch 700/938: Loss=0.0393
# Epoch 6, Batch 800/938: Loss=0.0414
# Epoch 6, Batch 900/938: Loss=0.0662
# Epoch 6 | Train Loss: 0.0868 | Test Accuracy: 98.80%
# Epoch 7, Batch 0/938: Loss=0.0342
# Epoch 7, Batch 100/938: Loss=0.1141
# Epoch 7, Batch 200/938: Loss=0.0413
# Epoch 7, Batch 300/938: Loss=0.0310
# Epoch 7, Batch 400/938: Loss=0.1750
# Epoch 7, Batch 500/938: Loss=0.2556
# Epoch 7, Batch 600/938: Loss=0.0233
# Epoch 7, Batch 700/938: Loss=0.0769
# Epoch 7, Batch 800/938: Loss=0.0357
# Epoch 7, Batch 900/938: Loss=0.0227
# Epoch 7 | Train Loss: 0.0770 | Test Accuracy: 99.08%
# Epoch 8, Batch 0/938: Loss=0.2069
# Epoch 8, Batch 100/938: Loss=0.0102
# Epoch 8, Batch 200/938: Loss=0.0137
# Epoch 8, Batch 300/938: Loss=0.1437
# Epoch 8, Batch 400/938: Loss=0.1033
# Epoch 8, Batch 500/938: Loss=0.0982
# Epoch 8, Batch 600/938: Loss=0.1060
# Epoch 8, Batch 700/938: Loss=0.0795
# Epoch 8, Batch 800/938: Loss=0.0118
# Epoch 8, Batch 900/938: Loss=0.0577
# Epoch 8 | Train Loss: 0.0715 | Test Accuracy: 99.34%
# Epoch 9, Batch 0/938: Loss=0.0005
# Epoch 9, Batch 100/938: Loss=0.0423
# Epoch 9, Batch 200/938: Loss=0.0259
# Epoch 9, Batch 300/938: Loss=0.0158
# Epoch 9, Batch 400/938: Loss=0.0495
# Epoch 9, Batch 500/938: Loss=0.0430
# Epoch 9, Batch 600/938: Loss=0.0396
# Epoch 9, Batch 700/938: Loss=0.0621
# Epoch 9, Batch 800/938: Loss=0.2006
# Epoch 9, Batch 900/938: Loss=0.0286
# Epoch 9 | Train Loss: 0.0619 | Test Accuracy: 99.29%
# Final Test Accuracy: 99.29%
# Training plots saved as 'mnist_resnet101_fisher_training.png'

# %%
import copy
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt

# Setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Hyperparameters
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

# Download and prepare MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST mean and std
])

print("Downloading MNIST dataset...")
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

# Download ResNet50 (not pretrained)
print("Downloading ResNet50 model...")
base_resnet50 = models.resnet50(weights=None)

# Modify first layer to accept 1-channel input (MNIST is grayscale)
base_resnet50.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)

# Modify output layer for 10 classes
num_ftrs = base_resnet50.fc.in_features
base_resnet50.fc = nn.Linear(num_ftrs, 10)

def make_resnet50():
    return copy.deepcopy(base_resnet50)

def run_experiment(model, optimizer):
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()

    print(f"Starting Training for {EPOCHS} epochs...")
    train_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0.0
        batch_count = 0
        
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            batch_count += 1
            
            if batch_idx % 150 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")
        
        avg_loss = epoch_loss / batch_count
        train_losses.append(avg_loss)
        
        # Evaluation phase
        model.eval()
        correct = 0
        total = 0
        
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()
        
        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print("\nTraining Complete!")
    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

# For each model, create the model, create an optimizer bound to that model, then pass optimizer into run_experiment
model = make_resnet50()
optimizer = optim.Adam(model.parameters(), lr=LR)
train_losses_resnet50_baseline_adam, test_accuracies_resnet50_baseline_adam = run_experiment(model, optimizer)

model = make_resnet50()
optimizer = optim.SGD(model.parameters(), lr=LR)
train_losses_resnet50_baseline_sgd, test_accuracies_resnet50_baseline_sgd = run_experiment(model, optimizer)

model = make_resnet50()
optimizer = optim.RMSprop(model.parameters(), lr=LR)
train_losses_resnet50_baseline_rmsprop, test_accuracies_resnet50_baseline_rmsprop = run_experiment(model, optimizer)

# Plot training results
epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_resnet50_baseline_adam, 'Adam', 'o', 'blue'),
    (train_losses_resnet50_baseline_sgd, 'SGD', 's', 'orange'),
    (train_losses_resnet50_baseline_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_resnet50_baseline_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_resnet50_baseline_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_resnet50_baseline_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ResNet50_baseline Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ResNet50_baseline Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_resnet50_baseline_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_resnet50_baseline_training.png'")
plt.show()
# Out:
# Using device: cuda
# Downloading MNIST dataset...
# Train samples: 60000, Test samples: 10000
# Downloading ResNet50 model...
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.5055
# Epoch 0, Batch 150/938: Loss=0.2569
# Epoch 0, Batch 300/938: Loss=0.3386
# Epoch 0, Batch 450/938: Loss=0.2272
# Epoch 0, Batch 600/938: Loss=0.1726
# Epoch 0, Batch 750/938: Loss=0.1441
# Epoch 0, Batch 900/938: Loss=0.2261
# Epoch 0 | Train Loss: 0.2542 | Test Accuracy: 97.36%
# Epoch 1, Batch 0/938: Loss=0.2513
# Epoch 1, Batch 150/938: Loss=0.1761
# Epoch 1, Batch 300/938: Loss=0.0363
# Epoch 1, Batch 450/938: Loss=0.2869
# Epoch 1, Batch 600/938: Loss=0.0384
# Epoch 1, Batch 750/938: Loss=0.0415
# Epoch 1, Batch 900/938: Loss=0.0091
# Epoch 1 | Train Loss: 0.0771 | Test Accuracy: 98.35%
# Epoch 2, Batch 0/938: Loss=0.1294
# Epoch 2, Batch 150/938: Loss=0.0279
# Epoch 2, Batch 300/938: Loss=0.0129
# Epoch 2, Batch 450/938: Loss=0.0902
# Epoch 2, Batch 600/938: Loss=0.0286
# Epoch 2, Batch 750/938: Loss=0.1053
# Epoch 2, Batch 900/938: Loss=0.1627
# Epoch 2 | Train Loss: 0.1487 | Test Accuracy: 98.08%
# Epoch 3, Batch 0/938: Loss=0.0326
# Epoch 3, Batch 150/938: Loss=0.0318
# Epoch 3, Batch 300/938: Loss=0.0267
# Epoch 3, Batch 450/938: Loss=0.2489
# Epoch 3, Batch 600/938: Loss=0.0135
# Epoch 3, Batch 750/938: Loss=0.0114
# Epoch 3, Batch 900/938: Loss=0.0815
# Epoch 3 | Train Loss: 0.0684 | Test Accuracy: 98.19%
# Epoch 4, Batch 0/938: Loss=0.0212
# Epoch 4, Batch 150/938: Loss=0.1846
# Epoch 4, Batch 300/938: Loss=0.1774
# Epoch 4, Batch 450/938: Loss=0.0529
# Epoch 4, Batch 600/938: Loss=0.0105
# Epoch 4, Batch 750/938: Loss=0.0622
# Epoch 4, Batch 900/938: Loss=0.0326
# Epoch 4 | Train Loss: 0.0799 | Test Accuracy: 98.47%
# Epoch 5, Batch 0/938: Loss=0.0866
# Epoch 5, Batch 150/938: Loss=0.0023
# Epoch 5, Batch 300/938: Loss=0.0117
# Epoch 5, Batch 450/938: Loss=0.0098
# Epoch 5, Batch 600/938: Loss=0.1567
# Epoch 5, Batch 750/938: Loss=0.0719
# Epoch 5, Batch 900/938: Loss=0.0989
# Epoch 5 | Train Loss: 0.1057 | Test Accuracy: 98.44%
# Epoch 6, Batch 0/938: Loss=0.0369
# Epoch 6, Batch 150/938: Loss=0.0335
# Epoch 6, Batch 300/938: Loss=0.1338
# Epoch 6, Batch 450/938: Loss=0.0265
# Epoch 6, Batch 600/938: Loss=0.0444
# Epoch 6, Batch 750/938: Loss=0.0252
# Epoch 6, Batch 900/938: Loss=0.0297
# Epoch 6 | Train Loss: 0.0829 | Test Accuracy: 98.80%
# Epoch 7, Batch 0/938: Loss=0.1051
# Epoch 7, Batch 150/938: Loss=0.0109
# Epoch 7, Batch 300/938: Loss=0.0035
# Epoch 7, Batch 450/938: Loss=0.0307
# Epoch 7, Batch 600/938: Loss=0.0561
# Epoch 7, Batch 750/938: Loss=0.0369
# Epoch 7, Batch 900/938: Loss=0.1233
# Epoch 7 | Train Loss: 0.0462 | Test Accuracy: 98.79%
# Epoch 8, Batch 0/938: Loss=0.0063
# Epoch 8, Batch 150/938: Loss=0.0508
# Epoch 8, Batch 300/938: Loss=0.0060
# Epoch 8, Batch 450/938: Loss=0.0171
# Epoch 8, Batch 600/938: Loss=0.0971
# Epoch 8, Batch 750/938: Loss=0.0045
# Epoch 8, Batch 900/938: Loss=0.0345
# Epoch 8 | Train Loss: 0.0347 | Test Accuracy: 98.60%
# Epoch 9, Batch 0/938: Loss=0.0888
# Epoch 9, Batch 150/938: Loss=0.0080
# Epoch 9, Batch 300/938: Loss=0.0608
# Epoch 9, Batch 450/938: Loss=0.0258
# Epoch 9, Batch 600/938: Loss=0.0043
# Epoch 9, Batch 750/938: Loss=0.0789
# Epoch 9, Batch 900/938: Loss=0.0151
# Epoch 9 | Train Loss: 0.0341 | Test Accuracy: 98.22%
#
# Training Complete!
# Final Test Accuracy: 98.22%
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.4688
# Epoch 0, Batch 150/938: Loss=2.2904
# Epoch 0, Batch 300/938: Loss=1.8088
# Epoch 0, Batch 450/938: Loss=1.5871
# Epoch 0, Batch 600/938: Loss=1.0894
# Epoch 0, Batch 750/938: Loss=1.1055
# Epoch 0, Batch 900/938: Loss=0.6971
# Epoch 0 | Train Loss: 1.5040 | Test Accuracy: 82.66%
# Epoch 1, Batch 0/938: Loss=0.5436
# Epoch 1, Batch 150/938: Loss=0.6122
# Epoch 1, Batch 300/938: Loss=0.5231
# Epoch 1, Batch 450/938: Loss=0.6275
# Epoch 1, Batch 600/938: Loss=0.2539
# Epoch 1, Batch 750/938: Loss=0.1888
# Epoch 1, Batch 900/938: Loss=0.2587
# Epoch 1 | Train Loss: 0.4055 | Test Accuracy: 92.43%
# Epoch 2, Batch 0/938: Loss=0.3811
# Epoch 2, Batch 150/938: Loss=0.2973
# Epoch 2, Batch 300/938: Loss=0.3202
# Epoch 2, Batch 450/938: Loss=0.3592
# Epoch 2, Batch 600/938: Loss=0.1655
# Epoch 2, Batch 750/938: Loss=0.1574
# Epoch 2, Batch 900/938: Loss=0.3169
# Epoch 2 | Train Loss: 0.2311 | Test Accuracy: 94.84%
# Epoch 3, Batch 0/938: Loss=0.3484
# Epoch 3, Batch 150/938: Loss=0.1551
# Epoch 3, Batch 300/938: Loss=0.2010
# Epoch 3, Batch 450/938: Loss=0.1916
# Epoch 3, Batch 600/938: Loss=0.2087
# Epoch 3, Batch 750/938: Loss=0.1261
# Epoch 3, Batch 900/938: Loss=0.1785
# Epoch 3 | Train Loss: 0.1656 | Test Accuracy: 95.86%
# Epoch 4, Batch 0/938: Loss=0.1157
# Epoch 4, Batch 150/938: Loss=0.0961
# Epoch 4, Batch 300/938: Loss=0.0883
# Epoch 4, Batch 450/938: Loss=0.1020
# Epoch 4, Batch 600/938: Loss=0.0301
# Epoch 4, Batch 750/938: Loss=0.1302
# Epoch 4, Batch 900/938: Loss=0.0465
# Epoch 4 | Train Loss: 0.1287 | Test Accuracy: 96.25%
# Epoch 5, Batch 0/938: Loss=0.0343
# Epoch 5, Batch 150/938: Loss=0.0888
# Epoch 5, Batch 300/938: Loss=0.1011
# Epoch 5, Batch 450/938: Loss=0.0392
# Epoch 5, Batch 600/938: Loss=0.0403
# Epoch 5, Batch 750/938: Loss=0.0302
# Epoch 5, Batch 900/938: Loss=0.0452
# Epoch 5 | Train Loss: 0.1035 | Test Accuracy: 96.76%
# Epoch 6, Batch 0/938: Loss=0.1282
# Epoch 6, Batch 150/938: Loss=0.0581
# Epoch 6, Batch 300/938: Loss=0.0666
# Epoch 6, Batch 450/938: Loss=0.0506
# Epoch 6, Batch 600/938: Loss=0.0952
# Epoch 6, Batch 750/938: Loss=0.0136
# Epoch 6, Batch 900/938: Loss=0.0829
# Epoch 6 | Train Loss: 0.0852 | Test Accuracy: 96.95%
# Epoch 7, Batch 0/938: Loss=0.0120
# Epoch 7, Batch 150/938: Loss=0.1055
# Epoch 7, Batch 300/938: Loss=0.0546
# Epoch 7, Batch 450/938: Loss=0.0326
# Epoch 7, Batch 600/938: Loss=0.0985
# Epoch 7, Batch 750/938: Loss=0.1648
# Epoch 7, Batch 900/938: Loss=0.0376
# Epoch 7 | Train Loss: 0.0691 | Test Accuracy: 97.18%
# Epoch 8, Batch 0/938: Loss=0.0368
# Epoch 8, Batch 150/938: Loss=0.0117
# Epoch 8, Batch 300/938: Loss=0.1062
# Epoch 8, Batch 450/938: Loss=0.0300
# Epoch 8, Batch 600/938: Loss=0.0411
# Epoch 8, Batch 750/938: Loss=0.1160
# Epoch 8, Batch 900/938: Loss=0.0603
# Epoch 8 | Train Loss: 0.0566 | Test Accuracy: 97.24%
# Epoch 9, Batch 0/938: Loss=0.1030
# Epoch 9, Batch 150/938: Loss=0.0337
# Epoch 9, Batch 300/938: Loss=0.0515
# Epoch 9, Batch 450/938: Loss=0.0647
# Epoch 9, Batch 600/938: Loss=0.0360
# Epoch 9, Batch 750/938: Loss=0.0405
# Epoch 9, Batch 900/938: Loss=0.0402
# Epoch 9 | Train Loss: 0.0466 | Test Accuracy: 97.34%
#
# Training Complete!
# Final Test Accuracy: 97.34%
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.6017
# Epoch 0, Batch 150/938: Loss=0.1615
# Epoch 0, Batch 300/938: Loss=0.1206
# Epoch 0, Batch 450/938: Loss=0.1038
# Epoch 0, Batch 600/938: Loss=0.1399
# Epoch 0, Batch 750/938: Loss=0.0957
# Epoch 0, Batch 900/938: Loss=0.1932
# Epoch 0 | Train Loss: 0.4425 | Test Accuracy: 96.62%
# Epoch 1, Batch 0/938: Loss=0.1533
# Epoch 1, Batch 150/938: Loss=0.0175
# Epoch 1, Batch 300/938: Loss=0.0809
# Epoch 1, Batch 450/938: Loss=0.0679
# Epoch 1, Batch 600/938: Loss=0.2221
# Epoch 1, Batch 750/938: Loss=0.2295
# Epoch 1, Batch 900/938: Loss=0.1417
# Epoch 1 | Train Loss: 0.1782 | Test Accuracy: 97.82%
# Epoch 2, Batch 0/938: Loss=0.0806
# Epoch 2, Batch 150/938: Loss=0.0363
# Epoch 2, Batch 300/938: Loss=0.0332
# Epoch 2, Batch 450/938: Loss=0.0782
# Epoch 2, Batch 600/938: Loss=0.1348
# Epoch 2, Batch 750/938: Loss=0.1183
# Epoch 2, Batch 900/938: Loss=0.0737
# Epoch 2 | Train Loss: 0.1182 | Test Accuracy: 98.13%
# Epoch 3, Batch 0/938: Loss=0.1157
# Epoch 3, Batch 150/938: Loss=0.0669
# Epoch 3, Batch 300/938: Loss=0.0017
# Epoch 3, Batch 450/938: Loss=0.0852
# Epoch 3, Batch 600/938: Loss=0.0632
# Epoch 3, Batch 750/938: Loss=0.0486
# Epoch 3, Batch 900/938: Loss=0.0787
# Epoch 3 | Train Loss: 0.0839 | Test Accuracy: 98.73%
# Epoch 4, Batch 0/938: Loss=0.0360
# Epoch 4, Batch 150/938: Loss=0.1163
# Epoch 4, Batch 300/938: Loss=0.1911
# Epoch 4, Batch 450/938: Loss=0.0553
# Epoch 4, Batch 600/938: Loss=0.0703
# Epoch 4, Batch 750/938: Loss=0.1281
# Epoch 4, Batch 900/938: Loss=0.0179
# Epoch 4 | Train Loss: 0.0736 | Test Accuracy: 98.27%
# Epoch 5, Batch 0/938: Loss=0.0386
# Epoch 5, Batch 150/938: Loss=0.0754
# Epoch 5, Batch 300/938: Loss=0.0056
# Epoch 5, Batch 450/938: Loss=0.0810
# Epoch 5, Batch 600/938: Loss=0.0190
# Epoch 5, Batch 750/938: Loss=0.0048
# Epoch 5, Batch 900/938: Loss=0.0157
# Epoch 5 | Train Loss: 0.0600 | Test Accuracy: 99.08%
# Epoch 6, Batch 0/938: Loss=0.0114
# Epoch 6, Batch 150/938: Loss=0.0025
# Epoch 6, Batch 300/938: Loss=0.0163
# Epoch 6, Batch 450/938: Loss=0.1172
# Epoch 6, Batch 600/938: Loss=0.1100
# Epoch 6, Batch 750/938: Loss=0.0041
# Epoch 6, Batch 900/938: Loss=0.0371
# Epoch 6 | Train Loss: 0.0464 | Test Accuracy: 98.73%
# Epoch 7, Batch 0/938: Loss=0.0051
# Epoch 7, Batch 150/938: Loss=0.0002
# Epoch 7, Batch 300/938: Loss=0.0622
# Epoch 7, Batch 450/938: Loss=0.0059
# Epoch 7, Batch 600/938: Loss=0.0032
# Epoch 7, Batch 750/938: Loss=0.0476
# Epoch 7, Batch 900/938: Loss=0.1027
# Epoch 7 | Train Loss: 0.0418 | Test Accuracy: 97.92%
# Epoch 8, Batch 0/938: Loss=0.0913
# Epoch 8, Batch 150/938: Loss=0.0255
# Epoch 8, Batch 300/938: Loss=0.1061
# Epoch 8, Batch 450/938: Loss=0.0005
# Epoch 8, Batch 600/938: Loss=0.0060
# Epoch 8, Batch 750/938: Loss=0.0107
# Epoch 8, Batch 900/938: Loss=0.0021
# Epoch 8 | Train Loss: 0.0312 | Test Accuracy: 96.84%
# Epoch 9, Batch 0/938: Loss=0.1094
# Epoch 9, Batch 150/938: Loss=0.0009
# Epoch 9, Batch 300/938: Loss=0.0353
# Epoch 9, Batch 450/938: Loss=0.0047
# Epoch 9, Batch 600/938: Loss=0.0006
# Epoch 9, Batch 750/938: Loss=0.0107
# Epoch 9, Batch 900/938: Loss=0.0819
# Epoch 9 | Train Loss: 0.0305 | Test Accuracy: 99.23%
#
# Training Complete!
# Final Test Accuracy: 99.23%
# Training plots saved as 'mnist_resnet50_baseline_training.png'

# %%
import copy
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt

# Setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Hyperparameters
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

# Download and prepare MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST mean and std
])

print("Downloading MNIST dataset...")
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

# Download ResNet101 (not pretrained)
print("Downloading ResNet101 model...")
base_resnet101 = models.resnet101(weights=None)

# Modify first layer to accept 1-channel input (MNIST is grayscale)
base_resnet101.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)

# Modify output layer for 10 classes
num_ftrs = base_resnet101.fc.in_features
base_resnet101.fc = nn.Linear(num_ftrs, 10)

def make_resnet101():
    return copy.deepcopy(base_resnet101)

def run_experiment(model, optimizer):
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()

    print(f"Starting Training for {EPOCHS} epochs...")
    train_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0.0
        batch_count = 0
        
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            batch_count += 1
            
            if batch_idx % 150 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")
        
        avg_loss = epoch_loss / batch_count
        train_losses.append(avg_loss)
        
        # Evaluation phase
        model.eval()
        correct = 0
        total = 0
        
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()
        
        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print("\nTraining Complete!")
    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

# For each model, create the model, create an optimizer bound to that model, then pass optimizer into run_experiment
model = make_resnet101()
optimizer = optim.Adam(model.parameters(), lr=LR)
train_losses_resnet101_baseline_adam, test_accuracies_resnet101_baseline_adam = run_experiment(model, optimizer)

model = make_resnet101()
optimizer = optim.SGD(model.parameters(), lr=LR)
train_losses_resnet101_baseline_sgd, test_accuracies_resnet101_baseline_sgd = run_experiment(model, optimizer)

model = make_resnet101()
optimizer = optim.RMSprop(model.parameters(), lr=LR)
train_losses_resnet101_baseline_rmsprop, test_accuracies_resnet101_baseline_rmsprop = run_experiment(model, optimizer)

# Plot training results
epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_resnet101_baseline_adam, 'Adam', 'o', 'blue'),
    (train_losses_resnet101_baseline_sgd, 'SGD', 's', 'orange'),
    (train_losses_resnet101_baseline_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_resnet101_baseline_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_resnet101_baseline_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_resnet101_baseline_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ResNet101_baseline Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ResNet101_baseline Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_resnet101_baseline_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_resnet101_baseline_training.png'")
plt.show()
# Out:
# Using device: cuda
# Downloading MNIST dataset...
# Train samples: 60000, Test samples: 10000
# Downloading ResNet101 model...
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.7844
# Epoch 0, Batch 150/938: Loss=0.3010
# Epoch 0, Batch 300/938: Loss=0.2004
# Epoch 0, Batch 450/938: Loss=0.2144
# Epoch 0, Batch 600/938: Loss=0.3257
# Epoch 0, Batch 750/938: Loss=0.1327
# Epoch 0, Batch 900/938: Loss=0.2063
# Epoch 0 | Train Loss: 0.3044 | Test Accuracy: 97.38%
# Epoch 1, Batch 0/938: Loss=0.0692
# Epoch 1, Batch 150/938: Loss=0.1308
# Epoch 1, Batch 300/938: Loss=0.0046
# Epoch 1, Batch 450/938: Loss=0.1179
# Epoch 1, Batch 600/938: Loss=0.2691
# Epoch 1, Batch 750/938: Loss=0.0428
# Epoch 1, Batch 900/938: Loss=0.0079
# Epoch 1 | Train Loss: 0.1073 | Test Accuracy: 97.68%
# Epoch 2, Batch 0/938: Loss=0.0084
# Epoch 2, Batch 150/938: Loss=0.2708
# Epoch 2, Batch 300/938: Loss=0.1889
# Epoch 2, Batch 450/938: Loss=0.0146
# Epoch 2, Batch 600/938: Loss=0.0477
# Epoch 2, Batch 750/938: Loss=0.0069
# Epoch 2, Batch 900/938: Loss=0.0133
# Epoch 2 | Train Loss: 0.1353 | Test Accuracy: 98.11%
# Epoch 3, Batch 0/938: Loss=0.0099
# Epoch 3, Batch 150/938: Loss=0.0272
# Epoch 3, Batch 300/938: Loss=0.1381
# Epoch 3, Batch 450/938: Loss=0.0456
# Epoch 3, Batch 600/938: Loss=0.0440
# Epoch 3, Batch 750/938: Loss=0.0104
# Epoch 3, Batch 900/938: Loss=0.0968
# Epoch 3 | Train Loss: 0.0522 | Test Accuracy: 98.60%
# Epoch 4, Batch 0/938: Loss=0.1210
# Epoch 4, Batch 150/938: Loss=0.0421
# Epoch 4, Batch 300/938: Loss=0.0143
# Epoch 4, Batch 450/938: Loss=0.0392
# Epoch 4, Batch 600/938: Loss=0.0190
# Epoch 4, Batch 750/938: Loss=0.0226
# Epoch 4, Batch 900/938: Loss=0.0568
# Epoch 4 | Train Loss: 0.0437 | Test Accuracy: 97.64%
# Epoch 5, Batch 0/938: Loss=0.0588
# Epoch 5, Batch 150/938: Loss=0.0537
# Epoch 5, Batch 300/938: Loss=0.1028
# Epoch 5, Batch 450/938: Loss=0.0108
# Epoch 5, Batch 600/938: Loss=0.0313
# Epoch 5, Batch 750/938: Loss=0.0271
# Epoch 5, Batch 900/938: Loss=0.0139
# Epoch 5 | Train Loss: 0.0733 | Test Accuracy: 98.01%
# Epoch 6, Batch 0/938: Loss=0.1185
# Epoch 6, Batch 150/938: Loss=0.0032
# Epoch 6, Batch 300/938: Loss=0.0316
# Epoch 6, Batch 450/938: Loss=0.0330
# Epoch 6, Batch 600/938: Loss=0.0185
# Epoch 6, Batch 750/938: Loss=0.1186
# Epoch 6, Batch 900/938: Loss=0.0072
# Epoch 6 | Train Loss: 0.0609 | Test Accuracy: 98.48%
# Epoch 7, Batch 0/938: Loss=0.0163
# Epoch 7, Batch 150/938: Loss=0.0172
# Epoch 7, Batch 300/938: Loss=0.1147
# Epoch 7, Batch 450/938: Loss=0.0238
# Epoch 7, Batch 600/938: Loss=0.0346
# Epoch 7, Batch 750/938: Loss=1.2081
# Epoch 7, Batch 900/938: Loss=0.1924
# Epoch 7 | Train Loss: 0.1310 | Test Accuracy: 97.28%
# Epoch 8, Batch 0/938: Loss=0.4249
# Epoch 8, Batch 150/938: Loss=0.0102
# Epoch 8, Batch 300/938: Loss=0.0719
# Epoch 8, Batch 450/938: Loss=0.1154
# Epoch 8, Batch 600/938: Loss=0.0032
# Epoch 8, Batch 750/938: Loss=0.0281
# Epoch 8, Batch 900/938: Loss=0.0383
# Epoch 8 | Train Loss: 0.0633 | Test Accuracy: 98.68%
# Epoch 9, Batch 0/938: Loss=0.0076
# Epoch 9, Batch 150/938: Loss=0.0630
# Epoch 9, Batch 300/938: Loss=0.0296
# Epoch 9, Batch 450/938: Loss=0.2424
# Epoch 9, Batch 600/938: Loss=0.0139
# Epoch 9, Batch 750/938: Loss=0.0732
# Epoch 9, Batch 900/938: Loss=0.0077
# Epoch 9 | Train Loss: 0.0442 | Test Accuracy: 98.61%
#
# Training Complete!
# Final Test Accuracy: 98.61%
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.6359
# Epoch 0, Batch 150/938: Loss=2.3077
# Epoch 0, Batch 300/938: Loss=1.9799
# Epoch 0, Batch 450/938: Loss=1.7239
# Epoch 0, Batch 600/938: Loss=1.3252
# Epoch 0, Batch 750/938: Loss=0.8690
# Epoch 0, Batch 900/938: Loss=0.7004
# Epoch 0 | Train Loss: 1.6304 | Test Accuracy: 77.68%
# Epoch 1, Batch 0/938: Loss=0.7226
# Epoch 1, Batch 150/938: Loss=0.4926
# Epoch 1, Batch 300/938: Loss=0.7721
# Epoch 1, Batch 450/938: Loss=0.6164
# Epoch 1, Batch 600/938: Loss=0.7325
# Epoch 1, Batch 750/938: Loss=0.4209
# Epoch 1, Batch 900/938: Loss=0.3813
# Epoch 1 | Train Loss: 0.5159 | Test Accuracy: 90.18%
# Epoch 2, Batch 0/938: Loss=0.3943
# Epoch 2, Batch 150/938: Loss=0.3511
# Epoch 2, Batch 300/938: Loss=0.3655
# Epoch 2, Batch 450/938: Loss=0.3453
# Epoch 2, Batch 600/938: Loss=0.1808
# Epoch 2, Batch 750/938: Loss=0.2536
# Epoch 2, Batch 900/938: Loss=0.3650
# Epoch 2 | Train Loss: 0.2968 | Test Accuracy: 93.38%
# Epoch 3, Batch 0/938: Loss=0.0592
# Epoch 3, Batch 150/938: Loss=0.2068
# Epoch 3, Batch 300/938: Loss=0.2914
# Epoch 3, Batch 450/938: Loss=0.1304
# Epoch 3, Batch 600/938: Loss=0.1360
# Epoch 3, Batch 750/938: Loss=0.1308
# Epoch 3, Batch 900/938: Loss=0.1784
# Epoch 3 | Train Loss: 0.2096 | Test Accuracy: 94.90%
# Epoch 4, Batch 0/938: Loss=0.1672
# Epoch 4, Batch 150/938: Loss=0.1397
# Epoch 4, Batch 300/938: Loss=0.0730
# Epoch 4, Batch 450/938: Loss=0.0621
# Epoch 4, Batch 600/938: Loss=0.2725
# Epoch 4, Batch 750/938: Loss=0.2896
# Epoch 4, Batch 900/938: Loss=0.1212
# Epoch 4 | Train Loss: 0.1689 | Test Accuracy: 95.70%
# Epoch 5, Batch 0/938: Loss=0.1268
# Epoch 5, Batch 150/938: Loss=0.0489
# Epoch 5, Batch 300/938: Loss=0.0945
# Epoch 5, Batch 450/938: Loss=0.2063
# Epoch 5, Batch 600/938: Loss=0.0421
# Epoch 5, Batch 750/938: Loss=0.0788
# Epoch 5, Batch 900/938: Loss=0.1123
# Epoch 5 | Train Loss: 0.1376 | Test Accuracy: 95.91%
# Epoch 6, Batch 0/938: Loss=0.0410
# Epoch 6, Batch 150/938: Loss=0.1120
# Epoch 6, Batch 300/938: Loss=0.2155
# Epoch 6, Batch 450/938: Loss=0.1643
# Epoch 6, Batch 600/938: Loss=0.1923
# Epoch 6, Batch 750/938: Loss=0.0635
# Epoch 6, Batch 900/938: Loss=0.0139
# Epoch 6 | Train Loss: 0.1183 | Test Accuracy: 96.59%
# Epoch 7, Batch 0/938: Loss=0.0346
# Epoch 7, Batch 150/938: Loss=0.0430
# Epoch 7, Batch 300/938: Loss=0.0821
# Epoch 7, Batch 450/938: Loss=0.0881
# Epoch 7, Batch 600/938: Loss=0.0859
# Epoch 7, Batch 750/938: Loss=0.1720
# Epoch 7, Batch 900/938: Loss=0.1047
# Epoch 7 | Train Loss: 0.1013 | Test Accuracy: 96.67%
# Epoch 8, Batch 0/938: Loss=0.0451
# Epoch 8, Batch 150/938: Loss=0.0641
# Epoch 8, Batch 300/938: Loss=0.0598
# Epoch 8, Batch 450/938: Loss=0.1220
# Epoch 8, Batch 600/938: Loss=0.2103
# Epoch 8, Batch 750/938: Loss=0.1664
# Epoch 8, Batch 900/938: Loss=0.1000
# Epoch 8 | Train Loss: 0.0880 | Test Accuracy: 96.86%
# Epoch 9, Batch 0/938: Loss=0.1351
# Epoch 9, Batch 150/938: Loss=0.0683
# Epoch 9, Batch 300/938: Loss=0.1205
# Epoch 9, Batch 450/938: Loss=0.0254
# Epoch 9, Batch 600/938: Loss=0.1192
# Epoch 9, Batch 750/938: Loss=0.0155
# Epoch 9, Batch 900/938: Loss=0.0481
# Epoch 9 | Train Loss: 0.0744 | Test Accuracy: 97.26%
#
# Training Complete!
# Final Test Accuracy: 97.26%
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.9160
# Epoch 0, Batch 150/938: Loss=0.6638
# Epoch 0, Batch 300/938: Loss=0.4369
# Epoch 0, Batch 450/938: Loss=0.2003
# Epoch 0, Batch 600/938: Loss=0.2526
# Epoch 0, Batch 750/938: Loss=0.2433
# Epoch 0, Batch 900/938: Loss=0.3227
# Epoch 0 | Train Loss: 0.5922 | Test Accuracy: 85.87%
# Epoch 1, Batch 0/938: Loss=0.1370
# Epoch 1, Batch 150/938: Loss=0.0604
# Epoch 1, Batch 300/938: Loss=0.0909
# Epoch 1, Batch 450/938: Loss=0.0163
# Epoch 1, Batch 600/938: Loss=0.1767
# Epoch 1, Batch 750/938: Loss=0.1815
# Epoch 1, Batch 900/938: Loss=0.0287
# Epoch 1 | Train Loss: 0.2446 | Test Accuracy: 49.74%
# Epoch 2, Batch 0/938: Loss=1.0584
# Epoch 2, Batch 150/938: Loss=0.0167
# Epoch 2, Batch 300/938: Loss=0.1328
# Epoch 2, Batch 450/938: Loss=0.0481
# Epoch 2, Batch 600/938: Loss=0.0087
# Epoch 2, Batch 750/938: Loss=0.0889
# Epoch 2, Batch 900/938: Loss=0.1892
# Epoch 2 | Train Loss: 0.0855 | Test Accuracy: 97.51%
# Epoch 3, Batch 0/938: Loss=0.1772
# Epoch 3, Batch 150/938: Loss=0.0333
# Epoch 3, Batch 300/938: Loss=0.1273
# Epoch 3, Batch 450/938: Loss=0.0717
# Epoch 3, Batch 600/938: Loss=0.0513
# Epoch 3, Batch 750/938: Loss=0.0310
# Epoch 3, Batch 900/938: Loss=0.0050
# Epoch 3 | Train Loss: 0.0895 | Test Accuracy: 98.50%
# Epoch 4, Batch 0/938: Loss=0.1144
# Epoch 4, Batch 150/938: Loss=0.1832
# Epoch 4, Batch 300/938: Loss=0.0098
# Epoch 4, Batch 450/938: Loss=0.0317
# Epoch 4, Batch 600/938: Loss=0.0641
# Epoch 4, Batch 750/938: Loss=0.0064
# Epoch 4, Batch 900/938: Loss=0.0013
# Epoch 4 | Train Loss: 0.0805 | Test Accuracy: 98.16%
# Epoch 5, Batch 0/938: Loss=0.0221
# Epoch 5, Batch 150/938: Loss=0.0274
# Epoch 5, Batch 300/938: Loss=0.0324
# Epoch 5, Batch 450/938: Loss=0.0281
# Epoch 5, Batch 600/938: Loss=0.0278
# Epoch 5, Batch 750/938: Loss=0.0018
# Epoch 5, Batch 900/938: Loss=0.1558
# Epoch 5 | Train Loss: 0.0783 | Test Accuracy: 98.70%
# Epoch 6, Batch 0/938: Loss=0.0371
# Epoch 6, Batch 150/938: Loss=0.1753
# Epoch 6, Batch 300/938: Loss=0.0003
# Epoch 6, Batch 450/938: Loss=0.0085
# Epoch 6, Batch 600/938: Loss=0.0690
# Epoch 6, Batch 750/938: Loss=0.0038
# Epoch 6, Batch 900/938: Loss=0.0047
# Epoch 6 | Train Loss: 0.0531 | Test Accuracy: 99.09%
# Epoch 7, Batch 0/938: Loss=0.0005
# Epoch 7, Batch 150/938: Loss=0.0186
# Epoch 7, Batch 300/938: Loss=0.0268
# Epoch 7, Batch 450/938: Loss=0.0188
# Epoch 7, Batch 600/938: Loss=0.0076
# Epoch 7, Batch 750/938: Loss=0.0122
# Epoch 7, Batch 900/938: Loss=0.0060
# Epoch 7 | Train Loss: 0.0442 | Test Accuracy: 99.06%
# Epoch 8, Batch 0/938: Loss=0.0017
# Epoch 8, Batch 150/938: Loss=0.0061
# Epoch 8, Batch 300/938: Loss=0.0501
# Epoch 8, Batch 450/938: Loss=0.0143
# Epoch 8, Batch 600/938: Loss=0.0045
# Epoch 8, Batch 750/938: Loss=0.0021
# Epoch 8, Batch 900/938: Loss=0.0025
# Epoch 8 | Train Loss: 0.0307 | Test Accuracy: 95.90%
# Epoch 9, Batch 0/938: Loss=0.0621
# Epoch 9, Batch 150/938: Loss=0.0541
# Epoch 9, Batch 300/938: Loss=0.0037
# Epoch 9, Batch 450/938: Loss=0.0069
# Epoch 9, Batch 600/938: Loss=0.0085
# Epoch 9, Batch 750/938: Loss=0.0017
# Epoch 9, Batch 900/938: Loss=0.0035
# Epoch 9 | Train Loss: 0.0432 | Test Accuracy: 98.92%
#
# Training Complete!
# Final Test Accuracy: 98.92%
# Training plots saved as 'mnist_resnet101_baseline_training.png'

# %%
import torch, torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# Dataset parameters
NUM_CLASSES = 10
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

K_PROBES = 4
EPSILON = 0.1

# Device setup for CUDA
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Load MNIST dataset
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
 ])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

class MNISTClassifier(nn.Module):
    def __init__(self, num_classes, k_probes, epsilon):
        super().__init__()
        self.epsilon = epsilon
        self.k_probes = k_probes
        self.num_classes = num_classes

        v = torch.randn(k_probes, 2)
        v = v / torch.norm(v, dim=1, keepdim=True)
        self.register_buffer('probes', v)

        self.vit = torchvision.models.vit_b_16(weights=None)
        self.vit.conv_proj = nn.Conv2d(1, 768, kernel_size=16, stride=16, padding=0, bias=False)

        self.classifier = nn.Sequential(
            nn.Linear(768 + 3 + 4, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def compute_score(self, x):
        if not x.requires_grad:
            x.requires_grad_(True)

        energy = x.mean()
        grads = torch.autograd.grad(
            outputs=energy,
            inputs=x,
            create_graph=True,
            retain_graph=True
        )[0]

        grads_flat = grads.view(grads.size(0), -1)
        if grads_flat.size(1) >= 2:
            grads_2d = grads_flat[:, :2]
        else:
            grads_2d = grads_flat

        scores = -torch.matmul(grads_2d, self.probes.T)
        return scores

    def compute_local_fisher(self, x):
        scores = self.compute_score(x)
        fisher_info = (scores ** 2).mean(dim=1, keepdim=True)
        return fisher_info

    def forward(self, x):
        with torch.set_grad_enabled(True):
            if not x.requires_grad:
                x.requires_grad_(True)

            O0 = self.compute_local_fisher(x)

            perturbation = torch.randn_like(x) * self.epsilon
            I_pos = self.compute_local_fisher(x + perturbation)
            I_neg = self.compute_local_fisher(x - perturbation)

            O1 = (I_pos - I_neg) / (2 * self.epsilon)
            O2 = (I_pos - 2 * O0 + I_neg) / (self.epsilon ** 2)

        n = x.shape[0]
        h = self.vit._process_input(x)
        batch_class_token = self.vit.class_token.expand(n, -1, -1)
        h = torch.cat([batch_class_token, h], dim=1)
        h = h + self.vit.encoder.pos_embedding
        h = self.vit.encoder.dropout(h)

        fisher_terms = []
        for layer_idx, layer in enumerate(self.vit.encoder.layers):
            h = layer(h)
            if layer_idx in (2, 5, 8, 11):
                with torch.set_grad_enabled(True):
                    if not h.requires_grad:
                        h.requires_grad_(True)
                    fisher_terms.append(self.compute_local_fisher(h))

        h = self.vit.encoder.ln(h)
        cls_feature = h[:, 0]
        fish_concat = torch.cat(fisher_terms, dim=1)
        features = torch.cat([cls_feature, O0, O1, O2, fish_concat], dim=1)

        logits = self.classifier(features)
        return logits

def run_experiment(model, opt):
    model = model.to(device)
    optimizer = opt
    criterion = nn.CrossEntropyLoss()

    train_losses = []
    test_accuracies = []

    print("Starting MNIST Training...")
    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

            if batch_idx % 100 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")

        avg_loss = epoch_loss / len(train_loader)
        train_losses.append(avg_loss)

        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()

        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.Adam(model.parameters(), lr=LR)
train_losses_vit_fisher_adam, test_accuracies_vit_fisher_adam = run_experiment(model, opt)

model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.SGD(model.parameters(), lr=LR)
train_losses_vit_fisher_sgd, test_accuracies_vit_fisher_sgd = run_experiment(model, opt)

model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.RMSprop(model.parameters(), lr=LR)
train_losses_vit_fisher_rmsprop, test_accuracies_vit_fisher_rmsprop = run_experiment(model, opt)

epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_vit_fisher_adam, 'Adam', 'o', 'blue'),
    (train_losses_vit_fisher_sgd, 'SGD', 's', 'orange'),
    (train_losses_vit_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_vit_fisher_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_vit_fisher_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_vit_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ViT_b_16_Fisher Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ViT_b_16_Fisher Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_vit_b_16_fisher_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_vit_b_16_fisher_training.png'")
plt.show()
# Out:
# Using device: cuda
# Train samples: 60000, Test samples: 10000
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.3648
# Epoch 0, Batch 100/938: Loss=2.3011
# Epoch 0, Batch 200/938: Loss=2.2998
# Epoch 0, Batch 300/938: Loss=2.2952
# Epoch 0, Batch 400/938: Loss=2.3024
# Epoch 0, Batch 500/938: Loss=2.3011
# Epoch 0, Batch 600/938: Loss=2.2990
# Epoch 0, Batch 700/938: Loss=2.3019
# Epoch 0, Batch 800/938: Loss=2.2960
# Epoch 0, Batch 900/938: Loss=2.3059
# Epoch 0 | Train Loss: 2.3032 | Test Accuracy: 11.35%
# Epoch 1, Batch 0/938: Loss=2.2952
# Epoch 1, Batch 100/938: Loss=2.2953
# Epoch 1, Batch 200/938: Loss=2.3049
# Epoch 1, Batch 300/938: Loss=2.3073
# Epoch 1, Batch 400/938: Loss=2.3171
# Epoch 1, Batch 500/938: Loss=2.3004
# Epoch 1, Batch 600/938: Loss=2.3144
# Epoch 1, Batch 700/938: Loss=2.3032
# Epoch 1, Batch 800/938: Loss=2.2979
# Epoch 1, Batch 900/938: Loss=2.3093
# Epoch 1 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 2, Batch 0/938: Loss=2.2997
# Epoch 2, Batch 100/938: Loss=2.3057
# Epoch 2, Batch 200/938: Loss=2.3042
# Epoch 2, Batch 300/938: Loss=2.2848
# Epoch 2, Batch 400/938: Loss=2.3012
# Epoch 2, Batch 500/938: Loss=2.2936
# Epoch 2, Batch 600/938: Loss=2.2935
# Epoch 2, Batch 700/938: Loss=2.3119
# Epoch 2, Batch 800/938: Loss=2.3041
# Epoch 2, Batch 900/938: Loss=2.3081
# Epoch 2 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 3, Batch 0/938: Loss=2.3005
# Epoch 3, Batch 100/938: Loss=2.3019
# Epoch 3, Batch 200/938: Loss=2.2924
# Epoch 3, Batch 300/938: Loss=2.2886
# Epoch 3, Batch 400/938: Loss=2.2925
# Epoch 3, Batch 500/938: Loss=2.3095
# Epoch 3, Batch 600/938: Loss=2.3046
# Epoch 3, Batch 700/938: Loss=2.2994
# Epoch 3, Batch 800/938: Loss=2.3016
# Epoch 3, Batch 900/938: Loss=2.2939
# Epoch 3 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 4, Batch 0/938: Loss=2.3018
# Epoch 4, Batch 100/938: Loss=2.3079
# Epoch 4, Batch 200/938: Loss=2.2929
# Epoch 4, Batch 300/938: Loss=2.2943
# Epoch 4, Batch 400/938: Loss=2.3047
# Epoch 4, Batch 500/938: Loss=2.3096
# Epoch 4, Batch 600/938: Loss=2.3107
# Epoch 4, Batch 700/938: Loss=2.2956
# Epoch 4, Batch 800/938: Loss=2.3033
# Epoch 4, Batch 900/938: Loss=2.2958
# Epoch 4 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 5, Batch 0/938: Loss=2.2980
# Epoch 5, Batch 100/938: Loss=2.2999
# Epoch 5, Batch 200/938: Loss=2.3021
# Epoch 5, Batch 300/938: Loss=2.2941
# Epoch 5, Batch 400/938: Loss=2.3133
# Epoch 5, Batch 500/938: Loss=2.3028
# Epoch 5, Batch 600/938: Loss=2.3041
# Epoch 5, Batch 700/938: Loss=2.3089
# Epoch 5, Batch 800/938: Loss=2.3043
# Epoch 5, Batch 900/938: Loss=2.3113
# Epoch 5 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 6, Batch 0/938: Loss=2.2974
# Epoch 6, Batch 100/938: Loss=2.3109
# Epoch 6, Batch 200/938: Loss=2.3111
# Epoch 6, Batch 300/938: Loss=2.3241
# Epoch 6, Batch 400/938: Loss=2.3096
# Epoch 6, Batch 500/938: Loss=2.2959
# Epoch 6, Batch 600/938: Loss=2.3056
# Epoch 6, Batch 700/938: Loss=2.3008
# Epoch 6, Batch 800/938: Loss=2.2925
# Epoch 6, Batch 900/938: Loss=2.2997
# Epoch 6 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 7, Batch 0/938: Loss=2.3029
# Epoch 7, Batch 100/938: Loss=2.2986
# Epoch 7, Batch 200/938: Loss=2.2805
# Epoch 7, Batch 300/938: Loss=2.3044
# Epoch 7, Batch 400/938: Loss=2.2979
# Epoch 7, Batch 500/938: Loss=2.3069
# Epoch 7, Batch 600/938: Loss=2.2969
# Epoch 7, Batch 700/938: Loss=2.2879
# Epoch 7, Batch 800/938: Loss=2.3144
# Epoch 7, Batch 900/938: Loss=2.3000
# Epoch 7 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 8, Batch 0/938: Loss=2.3084
# Epoch 8, Batch 100/938: Loss=2.2962
# Epoch 8, Batch 200/938: Loss=2.3018
# Epoch 8, Batch 300/938: Loss=2.3063
# Epoch 8, Batch 400/938: Loss=2.2980
# Epoch 8, Batch 500/938: Loss=2.3069
# Epoch 8, Batch 600/938: Loss=2.2957
# Epoch 8, Batch 700/938: Loss=2.3008
# Epoch 8, Batch 800/938: Loss=2.2971
# Epoch 8, Batch 900/938: Loss=2.2990
# Epoch 8 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 9, Batch 0/938: Loss=2.3035
# Epoch 9, Batch 100/938: Loss=2.3046
# Epoch 9, Batch 200/938: Loss=2.3121
# Epoch 9, Batch 300/938: Loss=2.3108
# Epoch 9, Batch 400/938: Loss=2.2959
# Epoch 9, Batch 500/938: Loss=2.3083
# Epoch 9, Batch 600/938: Loss=2.3030
# Epoch 9, Batch 700/938: Loss=2.3127
# Epoch 9, Batch 800/938: Loss=2.3020
# Epoch 9, Batch 900/938: Loss=2.3173
# Epoch 9 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Final Test Accuracy: 11.35%
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.3443
# Epoch 0, Batch 100/938: Loss=2.1380
# Epoch 0, Batch 200/938: Loss=2.0168
# Epoch 0, Batch 300/938: Loss=1.9238
# Epoch 0, Batch 400/938: Loss=1.9350
# Epoch 0, Batch 500/938: Loss=1.8090
# Epoch 0, Batch 600/938: Loss=1.7136
# Epoch 0, Batch 700/938: Loss=1.9097
# Epoch 0, Batch 800/938: Loss=1.4557
# Epoch 0, Batch 900/938: Loss=1.5002
# Epoch 0 | Train Loss: 1.8639 | Test Accuracy: 42.30%
# Epoch 1, Batch 0/938: Loss=1.7324
# Epoch 1, Batch 100/938: Loss=1.2923
# Epoch 1, Batch 200/938: Loss=1.5887
# Epoch 1, Batch 300/938: Loss=1.3670
# Epoch 1, Batch 400/938: Loss=1.3533
# Epoch 1, Batch 500/938: Loss=1.3092
# Epoch 1, Batch 600/938: Loss=1.6017
# Epoch 1, Batch 700/938: Loss=1.3553
# Epoch 1, Batch 800/938: Loss=1.2830
# Epoch 1, Batch 900/938: Loss=1.3793
# Epoch 1 | Train Loss: 1.4450 | Test Accuracy: 59.37%
# Epoch 2, Batch 0/938: Loss=1.4229
# Epoch 2, Batch 100/938: Loss=1.7518
# Epoch 2, Batch 200/938: Loss=1.1864
# Epoch 2, Batch 300/938: Loss=1.0919
# Epoch 2, Batch 400/938: Loss=1.3232
# Epoch 2, Batch 500/938: Loss=0.8778
# Epoch 2, Batch 600/938: Loss=1.3763
# Epoch 2, Batch 700/938: Loss=1.1223
# Epoch 2, Batch 800/938: Loss=0.9639
# Epoch 2, Batch 900/938: Loss=0.9775
# Epoch 2 | Train Loss: 1.1870 | Test Accuracy: 63.79%
# Epoch 3, Batch 0/938: Loss=1.1618
# Epoch 3, Batch 100/938: Loss=0.9000
# Epoch 3, Batch 200/938: Loss=1.0946
# Epoch 3, Batch 300/938: Loss=0.9277
# Epoch 3, Batch 400/938: Loss=0.8293
# Epoch 3, Batch 500/938: Loss=0.8595
# Epoch 3, Batch 600/938: Loss=0.7166
# Epoch 3, Batch 700/938: Loss=0.7335
# Epoch 3, Batch 800/938: Loss=0.9787
# Epoch 3, Batch 900/938: Loss=0.8367
# Epoch 3 | Train Loss: 0.9802 | Test Accuracy: 72.43%
# Epoch 4, Batch 0/938: Loss=1.0085
# Epoch 4, Batch 100/938: Loss=0.6230
# Epoch 4, Batch 200/938: Loss=0.8316
# Epoch 4, Batch 300/938: Loss=0.7915
# Epoch 4, Batch 400/938: Loss=0.6378
# Epoch 4, Batch 500/938: Loss=0.6189
# Epoch 4, Batch 600/938: Loss=0.7485
# Epoch 4, Batch 700/938: Loss=0.8427
# Epoch 4, Batch 800/938: Loss=0.6666
# Epoch 4, Batch 900/938: Loss=0.5128
# Epoch 4 | Train Loss: 0.7753 | Test Accuracy: 81.09%
# Epoch 5, Batch 0/938: Loss=0.5972
# Epoch 5, Batch 100/938: Loss=0.4553
# Epoch 5, Batch 200/938: Loss=0.5317
# Epoch 5, Batch 300/938: Loss=0.4025
# Epoch 5, Batch 400/938: Loss=0.6405
# Epoch 5, Batch 500/938: Loss=0.8304
# Epoch 5, Batch 600/938: Loss=0.5690
# Epoch 5, Batch 700/938: Loss=0.7084
# Epoch 5, Batch 800/938: Loss=0.5401
# Epoch 5, Batch 900/938: Loss=0.4521
# Epoch 5 | Train Loss: 0.5986 | Test Accuracy: 67.34%
# Epoch 6, Batch 0/938: Loss=0.9342
# Epoch 6, Batch 100/938: Loss=0.5027
# Epoch 6, Batch 200/938: Loss=0.4300
# Epoch 6, Batch 300/938: Loss=0.9516
# Epoch 6, Batch 400/938: Loss=0.6052
# Epoch 6, Batch 500/938: Loss=0.3501
# Epoch 6, Batch 600/938: Loss=0.5547
# Epoch 6, Batch 700/938: Loss=0.4082
# Epoch 6, Batch 800/938: Loss=0.3443
# Epoch 6, Batch 900/938: Loss=0.2705
# Epoch 6 | Train Loss: 0.4770 | Test Accuracy: 84.70%
# Epoch 7, Batch 0/938: Loss=0.3137
# Epoch 7, Batch 100/938: Loss=0.2543
# Epoch 7, Batch 200/938: Loss=0.4003
# Epoch 7, Batch 300/938: Loss=0.3714
# Epoch 7, Batch 400/938: Loss=0.4732
# Epoch 7, Batch 500/938: Loss=0.2921
# Epoch 7, Batch 600/938: Loss=0.5305
# Epoch 7, Batch 700/938: Loss=0.3624
# Epoch 7, Batch 800/938: Loss=0.2992
# Epoch 7, Batch 900/938: Loss=0.4084
# Epoch 7 | Train Loss: 0.3933 | Test Accuracy: 89.86%
# Epoch 8, Batch 0/938: Loss=0.4962
# Epoch 8, Batch 100/938: Loss=0.4202
# Epoch 8, Batch 200/938: Loss=0.4370
# Epoch 8, Batch 300/938: Loss=0.2602
# Epoch 8, Batch 400/938: Loss=0.4093
# Epoch 8, Batch 500/938: Loss=0.1862
# Epoch 8, Batch 600/938: Loss=0.3860
# Epoch 8, Batch 700/938: Loss=0.4372
# Epoch 8, Batch 800/938: Loss=0.4977
# Epoch 8, Batch 900/938: Loss=0.4877
# Epoch 8 | Train Loss: 0.3251 | Test Accuracy: 90.24%
# Epoch 9, Batch 0/938: Loss=0.3352
# Epoch 9, Batch 100/938: Loss=0.1278
# Epoch 9, Batch 200/938: Loss=0.1996
# Epoch 9, Batch 300/938: Loss=0.3561
# Epoch 9, Batch 400/938: Loss=0.4007
# Epoch 9, Batch 500/938: Loss=0.1605
# Epoch 9, Batch 600/938: Loss=0.3082
# Epoch 9, Batch 700/938: Loss=0.3517
# Epoch 9, Batch 800/938: Loss=0.4110
# Epoch 9, Batch 900/938: Loss=0.4706
# Epoch 9 | Train Loss: 0.2834 | Test Accuracy: 85.68%
# Final Test Accuracy: 85.68%
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=2.3304
# Epoch 0, Batch 100/938: Loss=2.3027
# Epoch 0, Batch 200/938: Loss=2.2960
# Epoch 0, Batch 300/938: Loss=2.3045
# Epoch 0, Batch 400/938: Loss=2.3020
# Epoch 0, Batch 500/938: Loss=2.2997
# Epoch 0, Batch 600/938: Loss=2.2974
# Epoch 0, Batch 700/938: Loss=2.2935
# Epoch 0, Batch 800/938: Loss=2.2941
# Epoch 0, Batch 900/938: Loss=2.3027
# Epoch 0 | Train Loss: 2.3112 | Test Accuracy: 11.35%
# Epoch 1, Batch 0/938: Loss=2.3132
# Epoch 1, Batch 100/938: Loss=2.3038
# Epoch 1, Batch 200/938: Loss=2.3007
# Epoch 1, Batch 300/938: Loss=2.2933
# Epoch 1, Batch 400/938: Loss=2.2955
# Epoch 1, Batch 500/938: Loss=2.3095
# Epoch 1, Batch 600/938: Loss=2.3103
# Epoch 1, Batch 700/938: Loss=2.3074
# Epoch 1, Batch 800/938: Loss=2.2948
# Epoch 1, Batch 900/938: Loss=2.3004
# Epoch 1 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 2, Batch 0/938: Loss=2.3077
# Epoch 2, Batch 100/938: Loss=2.3097
# Epoch 2, Batch 200/938: Loss=2.3128
# Epoch 2, Batch 300/938: Loss=2.3038
# Epoch 2, Batch 400/938: Loss=2.3039
# Epoch 2, Batch 500/938: Loss=2.2948
# Epoch 2, Batch 600/938: Loss=2.3018
# Epoch 2, Batch 700/938: Loss=2.3130
# Epoch 2, Batch 800/938: Loss=2.2972
# Epoch 2, Batch 900/938: Loss=2.2996
# Epoch 2 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 3, Batch 0/938: Loss=2.2958
# Epoch 3, Batch 100/938: Loss=2.2981
# Epoch 3, Batch 200/938: Loss=2.3012
# Epoch 3, Batch 300/938: Loss=2.3005
# Epoch 3, Batch 400/938: Loss=2.2977
# Epoch 3, Batch 500/938: Loss=2.3068
# Epoch 3, Batch 600/938: Loss=2.3056
# Epoch 3, Batch 700/938: Loss=2.3007
# Epoch 3, Batch 800/938: Loss=2.3071
# Epoch 3, Batch 900/938: Loss=2.2935
# Epoch 3 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 4, Batch 0/938: Loss=2.3024
# Epoch 4, Batch 100/938: Loss=2.3042
# Epoch 4, Batch 200/938: Loss=2.3005
# Epoch 4, Batch 300/938: Loss=2.2996
# Epoch 4, Batch 400/938: Loss=2.3036
# Epoch 4, Batch 500/938: Loss=2.3081
# Epoch 4, Batch 600/938: Loss=2.2985
# Epoch 4, Batch 700/938: Loss=2.3090
# Epoch 4, Batch 800/938: Loss=2.2975
# Epoch 4, Batch 900/938: Loss=2.3135
# Epoch 4 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 5, Batch 0/938: Loss=2.2932
# Epoch 5, Batch 100/938: Loss=2.3151
# Epoch 5, Batch 200/938: Loss=2.3175
# Epoch 5, Batch 300/938: Loss=2.2971
# Epoch 5, Batch 400/938: Loss=2.2967
# Epoch 5, Batch 500/938: Loss=2.3129
# Epoch 5, Batch 600/938: Loss=2.2980
# Epoch 5, Batch 700/938: Loss=2.3080
# Epoch 5, Batch 800/938: Loss=2.2978
# Epoch 5, Batch 900/938: Loss=2.2943
# Epoch 5 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 6, Batch 0/938: Loss=2.3071
# Epoch 6, Batch 100/938: Loss=2.2902
# Epoch 6, Batch 200/938: Loss=2.2968
# Epoch 6, Batch 300/938: Loss=2.3050
# Epoch 6, Batch 400/938: Loss=2.3109
# Epoch 6, Batch 500/938: Loss=2.3042
# Epoch 6, Batch 600/938: Loss=2.3091
# Epoch 6, Batch 700/938: Loss=2.2985
# Epoch 6, Batch 800/938: Loss=2.2968
# Epoch 6, Batch 900/938: Loss=2.2991
# Epoch 6 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 7, Batch 0/938: Loss=2.2997
# Epoch 7, Batch 100/938: Loss=2.2963
# Epoch 7, Batch 200/938: Loss=2.3124
# Epoch 7, Batch 300/938: Loss=2.3066
# Epoch 7, Batch 400/938: Loss=2.2935
# Epoch 7, Batch 500/938: Loss=2.3098
# Epoch 7, Batch 600/938: Loss=2.3047
# Epoch 7, Batch 700/938: Loss=2.2989
# Epoch 7, Batch 800/938: Loss=2.2947
# Epoch 7, Batch 900/938: Loss=2.3040
# Epoch 7 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 8, Batch 0/938: Loss=2.3028
# Epoch 8, Batch 100/938: Loss=2.2926
# Epoch 8, Batch 200/938: Loss=2.2983
# Epoch 8, Batch 300/938: Loss=2.3048
# Epoch 8, Batch 400/938: Loss=2.3047
# Epoch 8, Batch 500/938: Loss=2.2955
# Epoch 8, Batch 600/938: Loss=2.2862
# Epoch 8, Batch 700/938: Loss=2.3015
# Epoch 8, Batch 800/938: Loss=2.3078
# Epoch 8, Batch 900/938: Loss=2.2890
# Epoch 8 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 9, Batch 0/938: Loss=2.2999
# Epoch 9, Batch 100/938: Loss=2.2986
# Epoch 9, Batch 200/938: Loss=2.3045
# Epoch 9, Batch 300/938: Loss=2.3121
# Epoch 9, Batch 400/938: Loss=2.3002
# Epoch 9, Batch 500/938: Loss=2.3141
# Epoch 9, Batch 600/938: Loss=2.3077
# Epoch 9, Batch 700/938: Loss=2.2962
# Epoch 9, Batch 800/938: Loss=2.3097
# Epoch 9, Batch 900/938: Loss=2.2992
# Epoch 9 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Final Test Accuracy: 11.35%
# Training plots saved as 'mnist_vit_b_16_fisher_training.png'

# %%
import copy
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt

# Setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Hyperparameters
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

# Download and prepare MNIST dataset
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # ViT expects 224x224 input
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST mean and std
])

print("Downloading MNIST dataset...")
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

# Download ViT (not pretrained)
print("Downloading ViT model...")
base_vit = models.vit_b_16(weights=None)

# Modify first layer to accept 1-channel input (MNIST is grayscale)
base_vit.conv_proj = nn.Conv2d(1, 768, kernel_size=16, stride=16, padding=0, bias=False)

# Modify output layer for 10 classes
num_ftrs = base_vit.heads.head.in_features
base_vit.heads.head = nn.Linear(num_ftrs, 10)

def make_vit():
    return copy.deepcopy(base_vit)

def run_experiment(model, optimizer):
    model = model.to(device)
    criterion = nn.CrossEntropyLoss()

    print(f"Starting Training for {EPOCHS} epochs...")
    train_losses = []
    test_accuracies = []

    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0.0
        batch_count = 0
        
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            epoch_loss += loss.item()
            batch_count += 1
            
            if batch_idx % 150 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")
        
        avg_loss = epoch_loss / batch_count
        train_losses.append(avg_loss)
        
        # Evaluation phase
        model.eval()
        correct = 0
        total = 0
        
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()
        
        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print("\nTraining Complete!")
    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

# For each model, create the model, create an optimizer bound to that model, then pass optimizer into run_experiment
model = make_vit()
optimizer = optim.Adam(model.parameters(), lr=LR)
train_losses_vit_baseline_adam, test_accuracies_vit_baseline_adam = run_experiment(model, optimizer)

model = make_vit()
optimizer = optim.SGD(model.parameters(), lr=LR)
train_losses_vit_baseline_sgd, test_accuracies_vit_baseline_sgd = run_experiment(model, optimizer)

model = make_vit()
optimizer = optim.RMSprop(model.parameters(), lr=LR)
train_losses_vit_baseline_rmsprop, test_accuracies_vit_baseline_rmsprop = run_experiment(model, optimizer)

# Plot training results
epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_vit_baseline_adam, 'Adam', 'o', 'blue'),
    (train_losses_vit_baseline_sgd, 'SGD', 's', 'orange'),
    (train_losses_vit_baseline_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_vit_baseline_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_vit_baseline_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_vit_baseline_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ViT_b_16_baseline Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ViT_b_16_baseline Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_vit_b_16_baseline_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_vit_b_16_baseline_training.png'")
plt.show()
# Out:
# Using device: cuda
# Downloading MNIST dataset...
# Train samples: 60000, Test samples: 10000
# Downloading ViT model...
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.3660
# Epoch 0, Batch 150/938: Loss=1.8683
# Epoch 0, Batch 300/938: Loss=2.0974
# Epoch 0, Batch 450/938: Loss=2.0740
# Epoch 0, Batch 600/938: Loss=2.2567
# Epoch 0, Batch 750/938: Loss=2.3052
# Epoch 0, Batch 900/938: Loss=2.3067
# Epoch 0 | Train Loss: 2.2028 | Test Accuracy: 19.90%
# Epoch 1, Batch 0/938: Loss=2.0984
# Epoch 1, Batch 150/938: Loss=1.9365
# Epoch 1, Batch 300/938: Loss=2.0436
# Epoch 1, Batch 450/938: Loss=2.0197
# Epoch 1, Batch 600/938: Loss=1.8846
# Epoch 1, Batch 750/938: Loss=2.0521
# Epoch 1, Batch 900/938: Loss=2.2053
# Epoch 1 | Train Loss: 1.9804 | Test Accuracy: 25.96%
# Epoch 2, Batch 0/938: Loss=1.9476
# Epoch 2, Batch 150/938: Loss=2.0856
# Epoch 2, Batch 300/938: Loss=2.1042
# Epoch 2, Batch 450/938: Loss=2.0091
# Epoch 2, Batch 600/938: Loss=1.9715
# Epoch 2, Batch 750/938: Loss=2.0193
# Epoch 2, Batch 900/938: Loss=1.8693
# Epoch 2 | Train Loss: 1.9828 | Test Accuracy: 25.29%
# Epoch 3, Batch 0/938: Loss=1.8694
# Epoch 3, Batch 150/938: Loss=1.9518
# Epoch 3, Batch 300/938: Loss=2.0635
# Epoch 3, Batch 450/938: Loss=2.0436
# Epoch 3, Batch 600/938: Loss=2.3442
# Epoch 3, Batch 750/938: Loss=1.8710
# Epoch 3, Batch 900/938: Loss=1.8666
# Epoch 3 | Train Loss: 1.9508 | Test Accuracy: 27.63%
# Epoch 4, Batch 0/938: Loss=1.9122
# Epoch 4, Batch 150/938: Loss=2.0296
# Epoch 4, Batch 300/938: Loss=1.7414
# Epoch 4, Batch 450/938: Loss=1.8891
# Epoch 4, Batch 600/938: Loss=1.9402
# Epoch 4, Batch 750/938: Loss=1.8604
# Epoch 4, Batch 900/938: Loss=1.9113
# Epoch 4 | Train Loss: 1.9049 | Test Accuracy: 28.14%
# Epoch 5, Batch 0/938: Loss=1.8087
# Epoch 5, Batch 150/938: Loss=1.8951
# Epoch 5, Batch 300/938: Loss=1.6081
# Epoch 5, Batch 450/938: Loss=2.0048
# Epoch 5, Batch 600/938: Loss=1.7561
# Epoch 5, Batch 750/938: Loss=1.7241
# Epoch 5, Batch 900/938: Loss=1.9535
# Epoch 5 | Train Loss: 1.8395 | Test Accuracy: 19.49%
# Epoch 6, Batch 0/938: Loss=2.0473
# Epoch 6, Batch 150/938: Loss=2.2751
# Epoch 6, Batch 300/938: Loss=2.2486
# Epoch 6, Batch 450/938: Loss=2.0489
# Epoch 6, Batch 600/938: Loss=1.9831
# Epoch 6, Batch 750/938: Loss=2.1539
# Epoch 6, Batch 900/938: Loss=2.2063
# Epoch 6 | Train Loss: 2.1873 | Test Accuracy: 22.79%
# Epoch 7, Batch 0/938: Loss=2.0246
# Epoch 7, Batch 150/938: Loss=2.1066
# Epoch 7, Batch 300/938: Loss=2.1981
# Epoch 7, Batch 450/938: Loss=2.0417
# Epoch 7, Batch 600/938: Loss=2.0983
# Epoch 7, Batch 750/938: Loss=2.0648
# Epoch 7, Batch 900/938: Loss=1.9918
# Epoch 7 | Train Loss: 2.0981 | Test Accuracy: 23.00%
# Epoch 8, Batch 0/938: Loss=2.1132
# Epoch 8, Batch 150/938: Loss=2.0703
# Epoch 8, Batch 300/938: Loss=3.5735
# Epoch 8, Batch 450/938: Loss=2.1490
# Epoch 8, Batch 600/938: Loss=2.2803
# Epoch 8, Batch 750/938: Loss=2.2567
# Epoch 8, Batch 900/938: Loss=2.1262
# Epoch 8 | Train Loss: 2.1201 | Test Accuracy: 22.38%
# Epoch 9, Batch 0/938: Loss=1.9372
# Epoch 9, Batch 150/938: Loss=2.0638
# Epoch 9, Batch 300/938: Loss=1.9526
# Epoch 9, Batch 450/938: Loss=1.9335
# Epoch 9, Batch 600/938: Loss=1.9203
# Epoch 9, Batch 750/938: Loss=1.8890
# Epoch 9, Batch 900/938: Loss=2.1495
# Epoch 9 | Train Loss: 2.0525 | Test Accuracy: 21.45%
#
# Training Complete!
# Final Test Accuracy: 21.45%
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.4586
# Epoch 0, Batch 150/938: Loss=1.8154
# Epoch 0, Batch 300/938: Loss=1.6165
# Epoch 0, Batch 450/938: Loss=1.6286
# Epoch 0, Batch 600/938: Loss=1.2629
# Epoch 0, Batch 750/938: Loss=1.3323
# Epoch 0, Batch 900/938: Loss=1.0708
# Epoch 0 | Train Loss: 1.5663 | Test Accuracy: 56.00%
# Epoch 1, Batch 0/938: Loss=1.1855
# Epoch 1, Batch 150/938: Loss=1.2947
# Epoch 1, Batch 300/938: Loss=1.2965
# Epoch 1, Batch 450/938: Loss=1.1494
# Epoch 1, Batch 600/938: Loss=1.2240
# Epoch 1, Batch 750/938: Loss=1.1067
# Epoch 1, Batch 900/938: Loss=0.9039
# Epoch 1 | Train Loss: 1.0728 | Test Accuracy: 68.60%
# Epoch 2, Batch 0/938: Loss=0.6230
# Epoch 2, Batch 150/938: Loss=1.0766
# Epoch 2, Batch 300/938: Loss=0.7351
# Epoch 2, Batch 450/938: Loss=1.1707
# Epoch 2, Batch 600/938: Loss=0.5910
# Epoch 2, Batch 750/938: Loss=0.5999
# Epoch 2, Batch 900/938: Loss=0.4433
# Epoch 2 | Train Loss: 0.7747 | Test Accuracy: 71.61%
# Epoch 3, Batch 0/938: Loss=0.4779
# Epoch 3, Batch 150/938: Loss=0.7106
# Epoch 3, Batch 300/938: Loss=0.4866
# Epoch 3, Batch 450/938: Loss=0.6497
# Epoch 3, Batch 600/938: Loss=0.4865
# Epoch 3, Batch 750/938: Loss=0.5790
# Epoch 3, Batch 900/938: Loss=0.5262
# Epoch 3 | Train Loss: 0.5650 | Test Accuracy: 72.48%
# Epoch 4, Batch 0/938: Loss=0.7129
# Epoch 4, Batch 150/938: Loss=0.4199
# Epoch 4, Batch 300/938: Loss=0.5090
# Epoch 4, Batch 450/938: Loss=0.3373
# Epoch 4, Batch 600/938: Loss=0.4661
# Epoch 4, Batch 750/938: Loss=0.3908
# Epoch 4, Batch 900/938: Loss=0.5368
# Epoch 4 | Train Loss: 0.4191 | Test Accuracy: 79.40%
# Epoch 5, Batch 0/938: Loss=0.4361
# Epoch 5, Batch 150/938: Loss=0.4312
# Epoch 5, Batch 300/938: Loss=0.3832
# Epoch 5, Batch 450/938: Loss=0.2359
# Epoch 5, Batch 600/938: Loss=0.2722
# Epoch 5, Batch 750/938: Loss=0.3791
# Epoch 5, Batch 900/938: Loss=0.4362
# Epoch 5 | Train Loss: 0.3295 | Test Accuracy: 86.75%
# Epoch 6, Batch 0/938: Loss=0.3374
# Epoch 6, Batch 150/938: Loss=0.1819
# Epoch 6, Batch 300/938: Loss=0.2617
# Epoch 6, Batch 450/938: Loss=0.2020
# Epoch 6, Batch 600/938: Loss=0.2931
# Epoch 6, Batch 750/938: Loss=0.2371
# Epoch 6, Batch 900/938: Loss=0.2582
# Epoch 6 | Train Loss: 0.2581 | Test Accuracy: 93.29%
# Epoch 7, Batch 0/938: Loss=0.1828
# Epoch 7, Batch 150/938: Loss=0.2317
# Epoch 7, Batch 300/938: Loss=0.2988
# Epoch 7, Batch 450/938: Loss=0.1886
# Epoch 7, Batch 600/938: Loss=0.1252
# Epoch 7, Batch 750/938: Loss=0.3270
# Epoch 7, Batch 900/938: Loss=0.1326
# Epoch 7 | Train Loss: 0.2138 | Test Accuracy: 93.69%
# Epoch 8, Batch 0/938: Loss=0.1412
# Epoch 8, Batch 150/938: Loss=0.1199
# Epoch 8, Batch 300/938: Loss=0.1823
# Epoch 8, Batch 450/938: Loss=0.0591
# Epoch 8, Batch 600/938: Loss=0.0667
# Epoch 8, Batch 750/938: Loss=0.1692
# Epoch 8, Batch 900/938: Loss=0.1492
# Epoch 8 | Train Loss: 0.1783 | Test Accuracy: 94.11%
# Epoch 9, Batch 0/938: Loss=0.1128
# Epoch 9, Batch 150/938: Loss=0.0730
# Epoch 9, Batch 300/938: Loss=0.1297
# Epoch 9, Batch 450/938: Loss=0.1128
# Epoch 9, Batch 600/938: Loss=0.1639
# Epoch 9, Batch 750/938: Loss=0.0955
# Epoch 9, Batch 900/938: Loss=0.2809
# Epoch 9 | Train Loss: 0.1557 | Test Accuracy: 91.88%
#
# Training Complete!
# Final Test Accuracy: 91.88%
# Starting Training for 10 epochs...
# Epoch 0, Batch 0/938: Loss=2.3845
# Epoch 0, Batch 150/938: Loss=2.5723
# Epoch 0, Batch 300/938: Loss=2.6480
# Epoch 0, Batch 450/938: Loss=2.1484
# Epoch 0, Batch 600/938: Loss=2.9359
# Epoch 0, Batch 750/938: Loss=2.0245
# Epoch 0, Batch 900/938: Loss=1.9709
# Epoch 0 | Train Loss: 2.2942 | Test Accuracy: 22.94%
# Epoch 1, Batch 0/938: Loss=1.9203
# Epoch 1, Batch 150/938: Loss=1.9929
# Epoch 1, Batch 300/938: Loss=2.2141
# Epoch 1, Batch 450/938: Loss=1.8917
# Epoch 1, Batch 600/938: Loss=2.0315
# Epoch 1, Batch 750/938: Loss=1.9045
# Epoch 1, Batch 900/938: Loss=1.8422
# Epoch 1 | Train Loss: 2.0391 | Test Accuracy: 23.14%
# Epoch 2, Batch 0/938: Loss=1.9197
# Epoch 2, Batch 150/938: Loss=2.0371
# Epoch 2, Batch 300/938: Loss=1.8243
# Epoch 2, Batch 450/938: Loss=2.1004
# Epoch 2, Batch 600/938: Loss=2.1372
# Epoch 2, Batch 750/938: Loss=2.0356
# Epoch 2, Batch 900/938: Loss=1.9500
# Epoch 2 | Train Loss: 2.0623 | Test Accuracy: 23.79%
# Epoch 3, Batch 0/938: Loss=2.0775
# Epoch 3, Batch 150/938: Loss=1.9032
# Epoch 3, Batch 300/938: Loss=2.1528
# Epoch 3, Batch 450/938: Loss=1.9710
# Epoch 3, Batch 600/938: Loss=2.0726
# Epoch 3, Batch 750/938: Loss=1.8954
# Epoch 3, Batch 900/938: Loss=2.3245
# Epoch 3 | Train Loss: 2.0453 | Test Accuracy: 19.03%
# Epoch 4, Batch 0/938: Loss=2.1985
# Epoch 4, Batch 150/938: Loss=1.8607
# Epoch 4, Batch 300/938: Loss=2.0615
# Epoch 4, Batch 450/938: Loss=2.0816
# Epoch 4, Batch 600/938: Loss=1.8507
# Epoch 4, Batch 750/938: Loss=1.8595
# Epoch 4, Batch 900/938: Loss=2.0453
# Epoch 4 | Train Loss: 2.0597 | Test Accuracy: 22.91%
# Epoch 5, Batch 0/938: Loss=2.1063
# Epoch 5, Batch 150/938: Loss=2.2358
# Epoch 5, Batch 300/938: Loss=1.9122
# Epoch 5, Batch 450/938: Loss=1.9388
# Epoch 5, Batch 600/938: Loss=2.0291
# Epoch 5, Batch 750/938: Loss=1.8306
# Epoch 5, Batch 900/938: Loss=1.9919
# Epoch 5 | Train Loss: 2.0119 | Test Accuracy: 21.77%
# Epoch 6, Batch 0/938: Loss=2.1733
# Epoch 6, Batch 150/938: Loss=1.9845
# Epoch 6, Batch 300/938: Loss=2.4094
# Epoch 6, Batch 450/938: Loss=1.9930
# Epoch 6, Batch 600/938: Loss=2.2314
# Epoch 6, Batch 750/938: Loss=1.9957
# Epoch 6, Batch 900/938: Loss=2.0912
# Epoch 6 | Train Loss: 2.0717 | Test Accuracy: 20.55%
# Epoch 7, Batch 0/938: Loss=2.0814
# Epoch 7, Batch 150/938: Loss=2.0146
# Epoch 7, Batch 300/938: Loss=2.1723
# Epoch 7, Batch 450/938: Loss=1.9081
# Epoch 7, Batch 600/938: Loss=2.0348
# Epoch 7, Batch 750/938: Loss=1.9999
# Epoch 7, Batch 900/938: Loss=2.0252
# Epoch 7 | Train Loss: 2.0575 | Test Accuracy: 21.00%
# Epoch 8, Batch 0/938: Loss=2.0347
# Epoch 8, Batch 150/938: Loss=1.9379
# Epoch 8, Batch 300/938: Loss=2.1489
# Epoch 8, Batch 450/938: Loss=2.1904
# Epoch 8, Batch 600/938: Loss=2.0972
# Epoch 8, Batch 750/938: Loss=2.0041
# Epoch 8, Batch 900/938: Loss=1.9302
# Epoch 8 | Train Loss: 2.0702 | Test Accuracy: 21.70%
# Epoch 9, Batch 0/938: Loss=2.0058
# Epoch 9, Batch 150/938: Loss=2.0545
# Epoch 9, Batch 300/938: Loss=2.1054
# Epoch 9, Batch 450/938: Loss=2.3389
# Epoch 9, Batch 600/938: Loss=2.1731
# Epoch 9, Batch 750/938: Loss=1.9340
# Epoch 9, Batch 900/938: Loss=2.0300
# Epoch 9 | Train Loss: 2.0857 | Test Accuracy: 15.25%
#
# Training Complete!
# Final Test Accuracy: 15.25%
# Training plots saved as 'mnist_vit_b_16_baseline_training.png'

# %%
import pandas as pd

rows = []

g = globals()
loss_keys = sorted([k for k in g.keys() if k.startswith('train_losses_')])

for loss_key in loss_keys:
    suffix = loss_key.replace('train_losses_', '', 1)
    acc_key = f'test_accuracies_{suffix}'

    losses = g.get(loss_key)
    accuracies = g.get(acc_key)

    if losses is None or accuracies is None:
        continue

    n_epochs = min(len(losses), len(accuracies))
    for epoch in range(n_epochs):
        rows.append({
            'experiment': suffix,
            'epoch': epoch,
            'train_loss': float(losses[epoch]),
            'test_accuracy': float(accuracies[epoch])
        })

if not rows:
    raise RuntimeError(
        "No training outputs found. Run Cells 1–8 first so train_losses_* and test_accuracies_* variables exist."
    )

output_df = pd.DataFrame(rows).sort_values(['experiment', 'epoch']).reset_index(drop=True)
output_path = 'test1_copycopy_output.csv'
output_df.to_csv(output_path, index=False)

print(f"Saved {len(output_df)} rows to {output_path}")
print(output_df.head())
# Out:
# Saved 240 rows to test1_copycopy_output.csv
#                 experiment  epoch  train_loss  test_accuracy
# 0  resnet101_baseline_adam      0    0.304443          97.38
# 1  resnet101_baseline_adam      1    0.107313          97.68
# 2  resnet101_baseline_adam      2    0.135338          98.11
# 3  resnet101_baseline_adam      3    0.052210          98.60
# 4  resnet101_baseline_adam      4    0.043684          97.64
