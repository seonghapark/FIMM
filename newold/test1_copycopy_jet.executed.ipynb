# %%
import torch, time
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# Dataset parameters
NUM_CLASSES = 10
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

K_PROBES = 4
EPSILON = 0.1
LAMBDA_JET = 0.1      # Weight for alignment in Jet Loss
ETA_JET = 0.5         # Weight of Jet Loss in total loss [cite: 82]

# Device setup for CUDA
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Load MNIST dataset
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize to ResNet input size
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST mean and std
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

class MNISTClassifier(nn.Module):
    def __init__(self, num_classes, k_probes, epsilon):
        super().__init__()
        self.epsilon = epsilon
        self.k_probes = k_probes
        self.num_classes = num_classes

        v = torch.randn(k_probes, 2)  # 2D probe directions
        v = v / torch.norm(v, dim=1, keepdim=True)
        self.register_buffer('probes', v)

        # ResNet18 backbone
        resnet_model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet18', pretrained=False)
        self.intro = nn.Sequential(
            resnet_model.conv1,
            resnet_model.bn1,
            resnet_model.relu,
            resnet_model.maxpool
        )
        self.layer1 = resnet_model.layer1
        self.layer2 = resnet_model.layer2
        self.layer3 = resnet_model.layer3
        self.layer4 = resnet_model.layer4
        self.averagepool = resnet_model.avgpool

        # Classification head (512 + O0/O1/O2 + 4 fisher terms = 519)
        self.classifier = nn.Sequential(
            nn.Linear(512 + 3 + 4, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def compute_score(self, x):
        if not x.requires_grad:
            x.requires_grad_(True)

        # Compute energy as mean of representation
        energy = x.mean()

        grads = torch.autograd.grad(
            outputs=energy,
            inputs=x,
            create_graph=True,
            retain_graph=True
        )[0]

        grads_flat = grads.view(grads.size(0), -1)

        # Use only first 2 dimensions or project to 2D space
        if grads_flat.size(1) >= 2:
            grads_2d = grads_flat[:, :2]
        else:
            grads_2d = grads_flat

        scores = -torch.matmul(grads_2d, self.probes.T)
        return scores

    def compute_local_fisher(self, x):
        scores = self.compute_score(x)
        fisher_info = (scores ** 2).mean(dim=1, keepdim=True)
        return fisher_info

    def forward(self, x):
        # Convert 1-channel to 3-channel (RGB) by repeating
        if x.size(1) == 1:
            x = x.repeat(1, 3, 1, 1)  # [batch, 3, 28, 28]

        with torch.set_grad_enabled(True):
            if not x.requires_grad:
                x.requires_grad_(True)

            # Compute derivatives with respect to input
            O0 = self.compute_local_fisher(x)

            # For image tensors, use small Gaussian perturbations instead of probe directions
            perturbation = torch.randn_like(x) * self.epsilon
            x_pos = x + perturbation
            x_neg = x - perturbation

            I_pos = self.compute_local_fisher(x_pos)
            I_neg = self.compute_local_fisher(x_neg)

            O1 = (I_pos - I_neg) / (2 * self.epsilon)
            O2 = (I_pos - 2 * O0 + I_neg) / (self.epsilon ** 2)

        # Forward through ResNet
        h = self.intro(x)

        # Apply layers and compute Fisher at each stage
        h = self.layer1(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer1 = self.compute_local_fisher(h)

        h = self.layer2(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer2 = self.compute_local_fisher(h)

        h = self.layer3(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer3 = self.compute_local_fisher(h)

        h = self.layer4(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer4 = self.compute_local_fisher(h)

        # Global average pool
        h_pooled = self.averagepool(h)
        h_flat = h_pooled.flatten(1)

        # Concatenate all features
        fish_concat = torch.cat([fish_layer1, fish_layer2, fish_layer3, fish_layer4], dim=1)
        features = torch.cat([h_flat, O0, O1, O2, fish_concat], dim=1)

        # Classify
        logits = self.classifier(features)
        return logits

def calc_jet_loss(model, x):
    perturbation = torch.randn_like(x) * EPSILON
    x_pos = x + perturbation
    x_neg = x - perturbation
    pred_pos = model(x_pos)
    pred_neg = model(x_neg)
    D_hat = (pred_pos - pred_neg) / (2 * EPSILON) # [cite: 75]
    score_proj = model.compute_score(x).mean(dim=1, keepdim=True) # average score over probes
    loss_jet = ((D_hat + LAMBDA_JET * score_proj)**2).mean() #
    return loss_jet

def run_experiment(model, opt):
    model = model.to(device)
    optimizer = opt
    criterion = nn.CrossEntropyLoss()

    train_losses = []
    test_accuracies = []

    print("Starting MNIST Training...")
    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)

            ### JET Regularization
            loss_jet = calc_jet_loss(model, data)
            loss += ETA_JET * loss_jet

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

            if batch_idx % 100 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")

        avg_loss = epoch_loss / len(train_loader)
        train_losses.append(avg_loss)

        # Evaluate on test set
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()

        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

# For each model, create the model, create an optimizer bound to that model, then pass optimizer into run_experiment
s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.Adam(model.parameters(), lr=LR)
train_losses_resnet18_fisher_adam, test_accuracies_resnet18_fisher_adam = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.SGD(model.parameters(), lr=LR)
train_losses_resnet18_fisher_sgd, test_accuracies_resnet18_fisher_sgd = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.RMSprop(model.parameters(), lr=LR)
train_losses_resnet18_fisher_rmsprop, test_accuracies_resnet18_fisher_rmsprop = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

# Plot training results
epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_resnet18_fisher_adam, 'Adam', 'o', 'blue'),
    (train_losses_resnet18_fisher_sgd, 'SGD', 's', 'orange'),
    (train_losses_resnet18_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_resnet18_fisher_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_resnet18_fisher_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_resnet18_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ResNet18_Fisher Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ResNet18_Fisher Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_resnet18_fisher_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_resnet18_fisher_training.png'")
plt.show()
# Out:
# Using device: cuda:1
# Train samples: 60000, Test samples: 10000
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.4030
# Epoch 0, Batch 100/938: Loss=2.3108
# Epoch 0, Batch 200/938: Loss=2.3044
# Epoch 0, Batch 300/938: Loss=2.2997
# Epoch 0, Batch 400/938: Loss=2.2983
# Epoch 0, Batch 500/938: Loss=2.2990
# Epoch 0, Batch 600/938: Loss=2.3061
# Epoch 0, Batch 700/938: Loss=2.2996
# Epoch 0, Batch 800/938: Loss=2.2944
# Epoch 0, Batch 900/938: Loss=2.3036
# Epoch 0 | Train Loss: 2.3015 | Test Accuracy: 11.35%
# Epoch 1, Batch 0/938: Loss=2.3094
# Epoch 1, Batch 100/938: Loss=2.3033
# Epoch 1, Batch 200/938: Loss=2.3181
# Epoch 1, Batch 300/938: Loss=2.2981
# Epoch 1, Batch 400/938: Loss=2.2956
# Epoch 1, Batch 500/938: Loss=2.2991
# Epoch 1, Batch 600/938: Loss=2.3081
# Epoch 1, Batch 700/938: Loss=2.2957
# Epoch 1, Batch 800/938: Loss=2.2967
# Epoch 1, Batch 900/938: Loss=2.2940
# Epoch 1 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 2, Batch 0/938: Loss=2.2916
# Epoch 2, Batch 100/938: Loss=2.3022
# Epoch 2, Batch 200/938: Loss=2.2984
# Epoch 2, Batch 300/938: Loss=2.3042
# Epoch 2, Batch 400/938: Loss=2.3030
# Epoch 2, Batch 500/938: Loss=2.3089
# Epoch 2, Batch 600/938: Loss=2.2914
# Epoch 2, Batch 700/938: Loss=2.2971
# Epoch 2, Batch 800/938: Loss=2.2892
# Epoch 2, Batch 900/938: Loss=2.2986
# Epoch 2 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 3, Batch 0/938: Loss=2.2987
# Epoch 3, Batch 100/938: Loss=2.3099
# Epoch 3, Batch 200/938: Loss=2.2956
# Epoch 3, Batch 300/938: Loss=2.2905
# Epoch 3, Batch 400/938: Loss=2.2865
# Epoch 3, Batch 500/938: Loss=2.2890
# Epoch 3, Batch 600/938: Loss=2.2980
# Epoch 3, Batch 700/938: Loss=2.2967
# Epoch 3, Batch 800/938: Loss=2.2995
# Epoch 3, Batch 900/938: Loss=2.3029
# Epoch 3 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 4, Batch 0/938: Loss=2.3016
# Epoch 4, Batch 100/938: Loss=2.2935
# Epoch 4, Batch 200/938: Loss=2.2989
# Epoch 4, Batch 300/938: Loss=2.2935
# Epoch 4, Batch 400/938: Loss=2.2933
# Epoch 4, Batch 500/938: Loss=2.2937
# Epoch 4, Batch 600/938: Loss=2.3009
# Epoch 4, Batch 700/938: Loss=2.2963
# Epoch 4, Batch 800/938: Loss=2.2947
# Epoch 4, Batch 900/938: Loss=2.2958
# Epoch 4 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 5, Batch 0/938: Loss=2.3068
# Epoch 5, Batch 100/938: Loss=2.3032
# Epoch 5, Batch 200/938: Loss=2.3121
# Epoch 5, Batch 300/938: Loss=2.3021
# Epoch 5, Batch 400/938: Loss=2.2964
# Epoch 5, Batch 500/938: Loss=2.2925
# Epoch 5, Batch 600/938: Loss=2.2875
# Epoch 5, Batch 700/938: Loss=2.2960
# Epoch 5, Batch 800/938: Loss=2.3034
# Epoch 5, Batch 900/938: Loss=2.3067
# Epoch 5 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 6, Batch 0/938: Loss=2.3016
# Epoch 6, Batch 100/938: Loss=2.3133
# Epoch 6, Batch 200/938: Loss=2.2982
# Epoch 6, Batch 300/938: Loss=2.3097
# Epoch 6, Batch 400/938: Loss=2.3076
# Epoch 6, Batch 500/938: Loss=2.2964
# Epoch 6, Batch 600/938: Loss=2.3164
# Epoch 6, Batch 700/938: Loss=2.2999
# Epoch 6, Batch 800/938: Loss=2.2917
# Epoch 6, Batch 900/938: Loss=2.3027
# Epoch 6 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 7, Batch 0/938: Loss=2.3023
# Epoch 7, Batch 100/938: Loss=2.2997
# Epoch 7, Batch 200/938: Loss=2.2899
# Epoch 7, Batch 300/938: Loss=2.3077
# Epoch 7, Batch 400/938: Loss=2.2921
# Epoch 7, Batch 500/938: Loss=2.2860
# Epoch 7, Batch 600/938: Loss=2.2980
# Epoch 7, Batch 700/938: Loss=2.2949
# Epoch 7, Batch 800/938: Loss=2.3023
# Epoch 7, Batch 900/938: Loss=2.2962
# Epoch 7 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 8, Batch 0/938: Loss=2.2861
# Epoch 8, Batch 100/938: Loss=2.3108
# Epoch 8, Batch 200/938: Loss=2.2999
# Epoch 8, Batch 300/938: Loss=2.2943
# Epoch 8, Batch 400/938: Loss=2.3059
# Epoch 8, Batch 500/938: Loss=2.3039
# Epoch 8, Batch 600/938: Loss=2.2967
# Epoch 8, Batch 700/938: Loss=2.3051
# Epoch 8, Batch 800/938: Loss=2.3021
# Epoch 8, Batch 900/938: Loss=2.3057
# Epoch 8 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 9, Batch 0/938: Loss=2.2996
# Epoch 9, Batch 100/938: Loss=2.3076
# Epoch 9, Batch 200/938: Loss=2.3021
# Epoch 9, Batch 300/938: Loss=2.3042
# Epoch 9, Batch 400/938: Loss=2.3058
# Epoch 9, Batch 500/938: Loss=2.3080
# Epoch 9, Batch 600/938: Loss=2.2987
# Epoch 9, Batch 700/938: Loss=2.2969
# Epoch 9, Batch 800/938: Loss=2.3050
# Epoch 9, Batch 900/938: Loss=2.3153
# Epoch 9 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Final Test Accuracy: 11.35%
# Total training time: 5068.15 seconds
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.2515
# Epoch 0, Batch 100/938: Loss=2.3072
# Epoch 0, Batch 200/938: Loss=2.3036
# Epoch 0, Batch 300/938: Loss=2.2859
# Epoch 0, Batch 400/938: Loss=2.2924
# Epoch 0, Batch 500/938: Loss=2.2954
# Epoch 0, Batch 600/938: Loss=2.2919
# Epoch 0, Batch 700/938: Loss=2.2885
# Epoch 0, Batch 800/938: Loss=2.2886
# Epoch 0, Batch 900/938: Loss=2.2937
# Epoch 0 | Train Loss: 2.3103 | Test Accuracy: 23.45%
# Epoch 1, Batch 0/938: Loss=2.2757
# Epoch 1, Batch 100/938: Loss=2.2673
# Epoch 1, Batch 200/938: Loss=2.2793
# Epoch 1, Batch 300/938: Loss=2.2883
# Epoch 1, Batch 400/938: Loss=2.2459
# Epoch 1, Batch 500/938: Loss=2.2751
# Epoch 1, Batch 600/938: Loss=2.2606
# Epoch 1, Batch 700/938: Loss=2.2798
# Epoch 1, Batch 800/938: Loss=2.2510
# Epoch 1, Batch 900/938: Loss=2.2391
# Epoch 1 | Train Loss: 2.2680 | Test Accuracy: 21.35%
# Epoch 2, Batch 0/938: Loss=2.2390
# Epoch 2, Batch 100/938: Loss=2.2563
# Epoch 2, Batch 200/938: Loss=2.2489
# Epoch 2, Batch 300/938: Loss=2.2509
# Epoch 2, Batch 400/938: Loss=2.1858
# Epoch 2, Batch 500/938: Loss=2.2292
# Epoch 2, Batch 600/938: Loss=2.1688
# Epoch 2, Batch 700/938: Loss=2.2058
# Epoch 2, Batch 800/938: Loss=2.0910
# Epoch 2, Batch 900/938: Loss=2.1767
# Epoch 2 | Train Loss: 2.2037 | Test Accuracy: 12.04%
# Epoch 3, Batch 0/938: Loss=2.1092
# Epoch 3, Batch 100/938: Loss=2.0606
# Epoch 3, Batch 200/938: Loss=2.0744
# Epoch 3, Batch 300/938: Loss=2.0215
# Epoch 3, Batch 400/938: Loss=2.1381
# Epoch 3, Batch 500/938: Loss=2.2022
# Epoch 3, Batch 600/938: Loss=2.0883
# Epoch 3, Batch 700/938: Loss=2.0322
# Epoch 3, Batch 800/938: Loss=2.1913
# Epoch 3, Batch 900/938: Loss=2.0998
# Epoch 3 | Train Loss: 2.0992 | Test Accuracy: 11.35%
# Epoch 4, Batch 0/938: Loss=2.0853
# Epoch 4, Batch 100/938: Loss=2.1455
# Epoch 4, Batch 200/938: Loss=2.1114
# Epoch 4, Batch 300/938: Loss=2.2314
# Epoch 4, Batch 400/938: Loss=2.1107
# Epoch 4, Batch 500/938: Loss=2.1462
# Epoch 4, Batch 600/938: Loss=1.9200
# Epoch 4, Batch 700/938: Loss=2.1299
# Epoch 4, Batch 800/938: Loss=1.9869
# Epoch 4, Batch 900/938: Loss=1.8255
# Epoch 4 | Train Loss: 2.0204 | Test Accuracy: 11.53%
# Epoch 5, Batch 0/938: Loss=1.8544
# Epoch 5, Batch 100/938: Loss=2.1968
# Epoch 5, Batch 200/938: Loss=1.8664
# Epoch 5, Batch 300/938: Loss=1.8878
# Epoch 5, Batch 400/938: Loss=1.7629
# Epoch 5, Batch 500/938: Loss=1.8324
# Epoch 5, Batch 600/938: Loss=1.9600
# Epoch 5, Batch 700/938: Loss=1.9846
# Epoch 5, Batch 800/938: Loss=2.0054
# Epoch 5, Batch 900/938: Loss=1.8497
# Epoch 5 | Train Loss: 1.9434 | Test Accuracy: 11.35%
# Epoch 6, Batch 0/938: Loss=1.9840
# Epoch 6, Batch 100/938: Loss=1.9913
# Epoch 6, Batch 200/938: Loss=1.6574
# Epoch 6, Batch 300/938: Loss=2.0114
# Epoch 6, Batch 400/938: Loss=1.7263
# Epoch 6, Batch 500/938: Loss=1.9316
# Epoch 6, Batch 600/938: Loss=1.7622
# Epoch 6, Batch 700/938: Loss=1.8649
# Epoch 6, Batch 800/938: Loss=1.9279
# Epoch 6, Batch 900/938: Loss=1.7401
# Epoch 6 | Train Loss: 1.8530 | Test Accuracy: 11.35%
# Epoch 7, Batch 0/938: Loss=1.8115
# Epoch 7, Batch 100/938: Loss=1.9663
# Epoch 7, Batch 200/938: Loss=1.7784
# Epoch 7, Batch 300/938: Loss=1.8505
# Epoch 7, Batch 400/938: Loss=1.9106
# Epoch 7, Batch 500/938: Loss=2.0012
# Epoch 7, Batch 600/938: Loss=1.9098
# Epoch 7, Batch 700/938: Loss=1.8751
# Epoch 7, Batch 800/938: Loss=1.8630
# Epoch 7, Batch 900/938: Loss=1.7833
# Epoch 7 | Train Loss: 1.8725 | Test Accuracy: 21.91%
# Epoch 8, Batch 0/938: Loss=1.8083
# Epoch 8, Batch 100/938: Loss=1.7327
# Epoch 8, Batch 200/938: Loss=1.6850
# Epoch 8, Batch 300/938: Loss=1.7805
# Epoch 8, Batch 400/938: Loss=1.7600
# Epoch 8, Batch 500/938: Loss=1.6262
# Epoch 8, Batch 600/938: Loss=1.7538
# Epoch 8, Batch 700/938: Loss=1.7959
# Epoch 8, Batch 800/938: Loss=1.6917
# Epoch 8, Batch 900/938: Loss=1.6698
# Epoch 8 | Train Loss: 1.8063 | Test Accuracy: 10.10%
# Epoch 9, Batch 0/938: Loss=1.9294
# Epoch 9, Batch 100/938: Loss=1.7658
# Epoch 9, Batch 200/938: Loss=1.7507
# Epoch 9, Batch 300/938: Loss=1.7030
# Epoch 9, Batch 400/938: Loss=1.9865
# Epoch 9, Batch 500/938: Loss=2.2184
# Epoch 9, Batch 600/938: Loss=1.7333
# Epoch 9, Batch 700/938: Loss=1.7002
# Epoch 9, Batch 800/938: Loss=1.7451
# Epoch 9, Batch 900/938: Loss=1.8189
# Epoch 9 | Train Loss: 1.8580 | Test Accuracy: 20.37%
# Final Test Accuracy: 20.37%
# Total training time: 4404.52 seconds
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.2487
# Epoch 0, Batch 100/938: Loss=2.3000
# Epoch 0, Batch 200/938: Loss=2.3071
# Epoch 0, Batch 300/938: Loss=2.3090
# Epoch 0, Batch 400/938: Loss=2.2982
# Epoch 0, Batch 500/938: Loss=2.3062
# Epoch 0, Batch 600/938: Loss=2.2977
# Epoch 0, Batch 700/938: Loss=2.2885
# Epoch 0, Batch 800/938: Loss=2.3045
# Epoch 0, Batch 900/938: Loss=2.2952
# Epoch 0 | Train Loss: 2.3216 | Test Accuracy: 11.35%
# Epoch 1, Batch 0/938: Loss=2.2958
# Epoch 1, Batch 100/938: Loss=2.2955
# Epoch 1, Batch 200/938: Loss=2.2739
# Epoch 1, Batch 300/938: Loss=2.3001
# Epoch 1, Batch 400/938: Loss=2.2897
# Epoch 1, Batch 500/938: Loss=2.2833
# Epoch 1, Batch 600/938: Loss=2.2867
# Epoch 1, Batch 700/938: Loss=2.2598
# Epoch 1, Batch 800/938: Loss=2.2560
# Epoch 1, Batch 900/938: Loss=2.3085
# Epoch 1 | Train Loss: 2.2828 | Test Accuracy: 20.75%
# Epoch 2, Batch 0/938: Loss=2.2703
# Epoch 2, Batch 100/938: Loss=2.2835
# Epoch 2, Batch 200/938: Loss=2.2984
# Epoch 2, Batch 300/938: Loss=2.2966
# Epoch 2, Batch 400/938: Loss=2.3058
# Epoch 2, Batch 500/938: Loss=2.2883
# Epoch 2, Batch 600/938: Loss=2.3003
# Epoch 2, Batch 700/938: Loss=2.3084
# Epoch 2, Batch 800/938: Loss=2.3008
# Epoch 2, Batch 900/938: Loss=2.2915
# Epoch 2 | Train Loss: 2.2941 | Test Accuracy: 11.35%
# Epoch 3, Batch 0/938: Loss=2.2852
# Epoch 3, Batch 100/938: Loss=2.3085
# Epoch 3, Batch 200/938: Loss=2.3029
# Epoch 3, Batch 300/938: Loss=2.3031
# Epoch 3, Batch 400/938: Loss=2.3085
# Epoch 3, Batch 500/938: Loss=2.2950
# Epoch 3, Batch 600/938: Loss=2.2989
# Epoch 3, Batch 700/938: Loss=2.2998
# Epoch 3, Batch 800/938: Loss=2.3046
# Epoch 3, Batch 900/938: Loss=2.2934
# Epoch 3 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 4, Batch 0/938: Loss=2.2980
# Epoch 4, Batch 100/938: Loss=2.2880
# Epoch 4, Batch 200/938: Loss=2.2989
# Epoch 4, Batch 300/938: Loss=2.2956
# Epoch 4, Batch 400/938: Loss=2.3147
# Epoch 4, Batch 500/938: Loss=2.2970
# Epoch 4, Batch 600/938: Loss=2.3032
# Epoch 4, Batch 700/938: Loss=2.2931
# Epoch 4, Batch 800/938: Loss=2.2976
# Epoch 4, Batch 900/938: Loss=2.3034
# Epoch 4 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 5, Batch 0/938: Loss=2.2916
# Epoch 5, Batch 100/938: Loss=2.2999
# Epoch 5, Batch 200/938: Loss=2.2981
# Epoch 5, Batch 300/938: Loss=2.3015
# Epoch 5, Batch 400/938: Loss=2.2996
# Epoch 5, Batch 500/938: Loss=2.2963
# Epoch 5, Batch 600/938: Loss=2.3150
# Epoch 5, Batch 700/938: Loss=2.3015
# Epoch 5, Batch 800/938: Loss=2.3045
# Epoch 5, Batch 900/938: Loss=2.2900
# Epoch 5 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 6, Batch 0/938: Loss=2.3024
# Epoch 6, Batch 100/938: Loss=2.3029
# Epoch 6, Batch 200/938: Loss=2.3059
# Epoch 6, Batch 300/938: Loss=2.2924
# Epoch 6, Batch 400/938: Loss=2.2956
# Epoch 6, Batch 500/938: Loss=2.3095
# Epoch 6, Batch 600/938: Loss=2.3030
# Epoch 6, Batch 700/938: Loss=2.3042
# Epoch 6, Batch 800/938: Loss=2.3013
# Epoch 6, Batch 900/938: Loss=2.3073
# Epoch 6 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 7, Batch 0/938: Loss=2.3081
# Epoch 7, Batch 100/938: Loss=2.2901
# Epoch 7, Batch 200/938: Loss=2.3093
# Epoch 7, Batch 300/938: Loss=2.3133
# Epoch 7, Batch 400/938: Loss=2.3002
# Epoch 7, Batch 500/938: Loss=2.3017
# Epoch 7, Batch 600/938: Loss=2.2929
# Epoch 7, Batch 700/938: Loss=2.3005
# Epoch 7, Batch 800/938: Loss=2.3013
# Epoch 7, Batch 900/938: Loss=2.3060
# Epoch 7 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 8, Batch 0/938: Loss=2.2891
# Epoch 8, Batch 100/938: Loss=2.3062
# Epoch 8, Batch 200/938: Loss=2.3014
# Epoch 8, Batch 300/938: Loss=2.2976
# Epoch 8, Batch 400/938: Loss=2.2898
# Epoch 8, Batch 500/938: Loss=2.2962
# Epoch 8, Batch 600/938: Loss=2.2977
# Epoch 8, Batch 700/938: Loss=2.3081
# Epoch 8, Batch 800/938: Loss=2.3091
# Epoch 8, Batch 900/938: Loss=2.3033
# Epoch 8 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 9, Batch 0/938: Loss=2.3021
# Epoch 9, Batch 100/938: Loss=2.3034
# Epoch 9, Batch 200/938: Loss=2.3129
# Epoch 9, Batch 300/938: Loss=2.2971
# Epoch 9, Batch 400/938: Loss=2.2938
# Epoch 9, Batch 500/938: Loss=2.3066
# Epoch 9, Batch 600/938: Loss=2.3089
# Epoch 9, Batch 700/938: Loss=2.2874
# Epoch 9, Batch 800/938: Loss=2.3000
# Epoch 9, Batch 900/938: Loss=2.2960
# Epoch 9 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Final Test Accuracy: 11.35%
# Total training time: 4403.83 seconds
# Training plots saved as 'mnist_resnet18_fisher_training.png'

# %%
import torch, torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# Dataset parameters
NUM_CLASSES = 10
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

K_PROBES = 4
EPSILON = 0.1

# Device setup for CUDA
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Load MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST mean and std
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

class MNISTClassifier(nn.Module):
    def __init__(self, num_classes, k_probes, epsilon):
        super().__init__()
        self.epsilon = epsilon
        self.k_probes = k_probes
        self.num_classes = num_classes

        v = torch.randn(k_probes, 2)  # 2D probe directions
        v = v / torch.norm(v, dim=1, keepdim=True)
        self.register_buffer('probes', v)

        # ResNet50 backbone
        resnet_model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet50', pretrained=False)
        self.intro = nn.Sequential(
            resnet_model.conv1,
            resnet_model.bn1,
            resnet_model.relu,
            resnet_model.maxpool
        )
        self.layer1 = resnet_model.layer1
        self.layer2 = resnet_model.layer2
        self.layer3 = resnet_model.layer3
        self.layer4 = resnet_model.layer4
        self.averagepool = resnet_model.avgpool

        # Classification head (2048 + O0/O1/O2 + 4 fisher terms = 2055)
        self.classifier = nn.Sequential(
            nn.Linear(2048 + 3 + 4, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def compute_score(self, x):
        if not x.requires_grad:
            x.requires_grad_(True)

        energy = x.mean()
        grads = torch.autograd.grad(
            outputs=energy,
            inputs=x,
            create_graph=True,
            retain_graph=True
        )[0]

        grads_flat = grads.view(grads.size(0), -1)
        if grads_flat.size(1) >= 2:
            grads_2d = grads_flat[:, :2]
        else:
            grads_2d = grads_flat

        scores = -torch.matmul(grads_2d, self.probes.T)
        return scores

    def compute_local_fisher(self, x):
        scores = self.compute_score(x)
        fisher_info = (scores ** 2).mean(dim=1, keepdim=True)
        return fisher_info

    def forward(self, x):
        if x.size(1) == 1:
            x = x.repeat(1, 3, 1, 1)

        x_resized = F.interpolate(x, size=(224, 224), mode='bilinear', align_corners=False)

        with torch.set_grad_enabled(True):
            if not x_resized.requires_grad:
                x_resized.requires_grad_(True)

            O0 = self.compute_local_fisher(x_resized)

            perturbation = torch.randn_like(x_resized) * self.epsilon
            x_pos = x_resized + perturbation
            x_neg = x_resized - perturbation

            I_pos = self.compute_local_fisher(x_pos)
            I_neg = self.compute_local_fisher(x_neg)

            O1 = (I_pos - I_neg) / (2 * self.epsilon)
            O2 = (I_pos - 2 * O0 + I_neg) / (self.epsilon ** 2)

        h = self.intro(x_resized)

        h = self.layer1(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer1 = self.compute_local_fisher(h)

        h = self.layer2(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer2 = self.compute_local_fisher(h)

        h = self.layer3(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer3 = self.compute_local_fisher(h)

        h = self.layer4(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer4 = self.compute_local_fisher(h)

        h_pooled = self.averagepool(h)
        h_flat = h_pooled.flatten(1)

        fish_concat = torch.cat([fish_layer1, fish_layer2, fish_layer3, fish_layer4], dim=1)
        features = torch.cat([h_flat, O0, O1, O2, fish_concat], dim=1)

        logits = self.classifier(features)
        return logits

def calc_jet_loss(model, x):
    perturbation = torch.randn_like(x) * EPSILON
    x_pos = x + perturbation
    x_neg = x - perturbation
    pred_pos = model(x_pos)
    pred_neg = model(x_neg)
    D_hat = (pred_pos - pred_neg) / (2 * EPSILON) # [cite: 75]
    score_proj = model.compute_score(x).mean(dim=1, keepdim=True) # average score over probes
    loss_jet = ((D_hat + LAMBDA_JET * score_proj)**2).mean() #
    return loss_jet

def run_experiment(model, opt):
    model = model.to(device)
    optimizer = opt
    criterion = nn.CrossEntropyLoss()

    train_losses = []
    test_accuracies = []

    print("Starting MNIST Training...")
    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)

            ### JET Regularization
            loss_jet = calc_jet_loss(model, data)
            loss += ETA_JET * loss_jet

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

            if batch_idx % 100 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")

        avg_loss = epoch_loss / len(train_loader)
        train_losses.append(avg_loss)

        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()

        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.Adam(model.parameters(), lr=LR)
train_losses_resnet50_fisher_adam, test_accuracies_resnet50_fisher_adam = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.SGD(model.parameters(), lr=LR)
train_losses_resnet50_fisher_sgd, test_accuracies_resnet50_fisher_sgd = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.RMSprop(model.parameters(), lr=LR)
train_losses_resnet50_fisher_rmsprop, test_accuracies_resnet50_fisher_rmsprop = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_resnet50_fisher_adam, 'Adam', 'o', 'blue'),
    (train_losses_resnet50_fisher_sgd, 'SGD', 's', 'orange'),
    (train_losses_resnet50_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_resnet50_fisher_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_resnet50_fisher_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_resnet50_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ResNet50_Fisher Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ResNet50_Fisher Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_resnet50_fisher_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_resnet50_fisher_training.png'")
plt.show()
# Out:
# Using device: cuda
# Train samples: 60000, Test samples: 10000
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.6686
# Epoch 0, Batch 100/938: Loss=2.3002
# Epoch 0, Batch 200/938: Loss=2.3058
# Epoch 0, Batch 300/938: Loss=2.3051
# Epoch 0, Batch 400/938: Loss=2.2959
# Epoch 0, Batch 500/938: Loss=2.3028
# Epoch 0, Batch 600/938: Loss=2.3012
# Epoch 0, Batch 700/938: Loss=2.3014
# Epoch 0, Batch 800/938: Loss=2.3110
# Epoch 0, Batch 900/938: Loss=2.2969
# Epoch 0 | Train Loss: 2.3080 | Test Accuracy: 11.35%
# Epoch 1, Batch 0/938: Loss=2.2946
# Epoch 1, Batch 100/938: Loss=2.3144
# Epoch 1, Batch 200/938: Loss=2.3016
# Epoch 1, Batch 300/938: Loss=2.3033
# Epoch 1, Batch 400/938: Loss=2.3018
# Epoch 1, Batch 500/938: Loss=2.3031
# Epoch 1, Batch 600/938: Loss=2.2888
# Epoch 1, Batch 700/938: Loss=2.3123
# Epoch 1, Batch 800/938: Loss=2.2915
# Epoch 1, Batch 900/938: Loss=2.3031
# Epoch 1 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 2, Batch 0/938: Loss=2.2970
# Epoch 2, Batch 100/938: Loss=2.3111
# Epoch 2, Batch 200/938: Loss=2.3135
# Epoch 2, Batch 300/938: Loss=2.2974
# Epoch 2, Batch 400/938: Loss=2.3123
# Epoch 2, Batch 500/938: Loss=2.3014
# Epoch 2, Batch 600/938: Loss=2.3078
# Epoch 2, Batch 700/938: Loss=2.3050
# Epoch 2, Batch 800/938: Loss=2.2959
# Epoch 2, Batch 900/938: Loss=2.3005
# Epoch 2 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 3, Batch 0/938: Loss=2.2926
# Epoch 3, Batch 100/938: Loss=2.2871
# Epoch 3, Batch 200/938: Loss=2.3091
# Epoch 3, Batch 300/938: Loss=2.2988
# Epoch 3, Batch 400/938: Loss=2.3018
# Epoch 3, Batch 500/938: Loss=2.3030
# Epoch 3, Batch 600/938: Loss=2.2926
# Epoch 3, Batch 700/938: Loss=2.2920
# Epoch 3, Batch 800/938: Loss=2.3035
# Epoch 3, Batch 900/938: Loss=2.3045
# Epoch 3 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 4, Batch 0/938: Loss=2.2805
# Epoch 4, Batch 100/938: Loss=2.3096
# Epoch 4, Batch 200/938: Loss=2.3007
# Epoch 4, Batch 300/938: Loss=2.3132
# Epoch 4, Batch 400/938: Loss=2.2923
# Epoch 4, Batch 500/938: Loss=2.2912
# Epoch 4, Batch 600/938: Loss=2.2906
# Epoch 4, Batch 700/938: Loss=2.3022
# Epoch 4, Batch 800/938: Loss=2.3015
# Epoch 4, Batch 900/938: Loss=2.3004
# Epoch 4 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 5, Batch 0/938: Loss=2.2983
# Epoch 5, Batch 100/938: Loss=2.3094
# Epoch 5, Batch 200/938: Loss=2.2980
# Epoch 5, Batch 300/938: Loss=2.3039
# Epoch 5, Batch 400/938: Loss=2.3015
# Epoch 5, Batch 500/938: Loss=2.3152
# Epoch 5, Batch 600/938: Loss=2.2913
# Epoch 5, Batch 700/938: Loss=2.3129
# Epoch 5, Batch 800/938: Loss=2.3088
# Epoch 5, Batch 900/938: Loss=2.3104
# Epoch 5 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 6, Batch 0/938: Loss=2.3003
# Epoch 6, Batch 100/938: Loss=2.3099
# Epoch 6, Batch 200/938: Loss=2.3110
# Epoch 6, Batch 300/938: Loss=2.2940
# Epoch 6, Batch 400/938: Loss=2.3031
# Epoch 6, Batch 500/938: Loss=2.2917
# Epoch 6, Batch 600/938: Loss=2.2986
# Epoch 6, Batch 700/938: Loss=2.2966
# Epoch 6, Batch 800/938: Loss=2.3066
# Epoch 6, Batch 900/938: Loss=2.2901
# Epoch 6 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 7, Batch 0/938: Loss=2.2973
# Epoch 7, Batch 100/938: Loss=2.3120
# Epoch 7, Batch 200/938: Loss=2.3026
# Epoch 7, Batch 300/938: Loss=2.2949
# Epoch 7, Batch 400/938: Loss=2.3117
# Epoch 7, Batch 500/938: Loss=2.3114
# Epoch 7, Batch 600/938: Loss=2.2935
# Epoch 7, Batch 700/938: Loss=2.3047
# Epoch 7, Batch 800/938: Loss=2.3046
# Epoch 7, Batch 900/938: Loss=2.2892
# Epoch 7 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 8, Batch 0/938: Loss=2.2939
# Epoch 8, Batch 100/938: Loss=2.3018
# Epoch 8, Batch 200/938: Loss=2.2992
# Epoch 8, Batch 300/938: Loss=2.3082
# Epoch 8, Batch 400/938: Loss=2.2968
# Epoch 8, Batch 500/938: Loss=2.2974
# Epoch 8, Batch 600/938: Loss=2.3054
# Epoch 8, Batch 700/938: Loss=2.2987
# Epoch 8, Batch 800/938: Loss=2.3030
# Epoch 8, Batch 900/938: Loss=2.3039
# Epoch 8 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 9, Batch 0/938: Loss=2.3132
# Epoch 9, Batch 100/938: Loss=2.2954
# Epoch 9, Batch 200/938: Loss=2.2952
# Epoch 9, Batch 300/938: Loss=2.2985
# Epoch 9, Batch 400/938: Loss=2.2815
# Epoch 9, Batch 500/938: Loss=2.3028
# Epoch 9, Batch 600/938: Loss=2.3058
# Epoch 9, Batch 700/938: Loss=2.3091
# Epoch 9, Batch 800/938: Loss=2.2903
# Epoch 9, Batch 900/938: Loss=2.3017
# Epoch 9 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Final Test Accuracy: 11.35%
# Total training time: 2798.37 seconds
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.7806
# Epoch 0, Batch 100/938: Loss=2.3031
# Epoch 0, Batch 200/938: Loss=2.3027
# Epoch 0, Batch 300/938: Loss=2.3025
# Epoch 0, Batch 400/938: Loss=2.3029
# Epoch 0, Batch 500/938: Loss=2.3013
# Epoch 0, Batch 600/938: Loss=2.3136
# Epoch 0, Batch 700/938: Loss=2.2930
# Epoch 0, Batch 800/938: Loss=2.2909
# Epoch 0, Batch 900/938: Loss=2.2926
# Epoch 0 | Train Loss: 2.3029 | Test Accuracy: 19.49%
# Epoch 1, Batch 0/938: Loss=2.2855
# Epoch 1, Batch 100/938: Loss=2.2857
# Epoch 1, Batch 200/938: Loss=2.2962
# Epoch 1, Batch 300/938: Loss=2.2986
# Epoch 1, Batch 400/938: Loss=2.2872
# Epoch 1, Batch 500/938: Loss=2.2814
# Epoch 1, Batch 600/938: Loss=2.2843
# Epoch 1, Batch 700/938: Loss=2.2760
# Epoch 1, Batch 800/938: Loss=2.2706
# Epoch 1, Batch 900/938: Loss=2.2816
# Epoch 1 | Train Loss: 2.2812 | Test Accuracy: 21.61%
# Epoch 2, Batch 0/938: Loss=2.2788
# Epoch 2, Batch 100/938: Loss=2.2930
# Epoch 2, Batch 200/938: Loss=2.2583
# Epoch 2, Batch 300/938: Loss=2.2636
# Epoch 2, Batch 400/938: Loss=2.2863
# Epoch 2, Batch 500/938: Loss=2.2476
# Epoch 2, Batch 600/938: Loss=2.1948
# Epoch 2, Batch 700/938: Loss=2.2391
# Epoch 2, Batch 800/938: Loss=2.2848
# Epoch 2, Batch 900/938: Loss=2.2955
# Epoch 2 | Train Loss: 2.2521 | Test Accuracy: 21.88%
# Epoch 3, Batch 0/938: Loss=2.2155
# Epoch 3, Batch 100/938: Loss=2.2443
# Epoch 3, Batch 200/938: Loss=2.2225
# Epoch 3, Batch 300/938: Loss=2.2355
# Epoch 3, Batch 400/938: Loss=2.1892
# Epoch 3, Batch 500/938: Loss=2.2125
# Epoch 3, Batch 600/938: Loss=2.1550
# Epoch 3, Batch 700/938: Loss=2.1741
# Epoch 3, Batch 800/938: Loss=2.1882
# Epoch 3, Batch 900/938: Loss=2.1861
# Epoch 3 | Train Loss: 2.2182 | Test Accuracy: 23.33%
# Epoch 4, Batch 0/938: Loss=2.1260
# Epoch 4, Batch 100/938: Loss=2.1152
# Epoch 4, Batch 200/938: Loss=2.1968
# Epoch 4, Batch 300/938: Loss=2.2022
# Epoch 4, Batch 400/938: Loss=2.2390
# Epoch 4, Batch 500/938: Loss=2.2134
# Epoch 4, Batch 600/938: Loss=2.0430
# Epoch 4, Batch 700/938: Loss=2.0524
# Epoch 4, Batch 800/938: Loss=2.1487
# Epoch 4, Batch 900/938: Loss=1.9178
# Epoch 4 | Train Loss: 2.1436 | Test Accuracy: 18.52%
# Epoch 5, Batch 0/938: Loss=2.0051
# Epoch 5, Batch 100/938: Loss=2.1727
# Epoch 5, Batch 200/938: Loss=2.0138
# Epoch 5, Batch 300/938: Loss=2.0808
# Epoch 5, Batch 400/938: Loss=2.0479
# Epoch 5, Batch 500/938: Loss=2.0382
# Epoch 5, Batch 600/938: Loss=2.0963
# Epoch 5, Batch 700/938: Loss=2.0608
# Epoch 5, Batch 800/938: Loss=2.1534
# Epoch 5, Batch 900/938: Loss=1.9910
# Epoch 5 | Train Loss: 2.0742 | Test Accuracy: 17.63%
# Epoch 6, Batch 0/938: Loss=2.0708
# Epoch 6, Batch 100/938: Loss=2.0357
# Epoch 6, Batch 200/938: Loss=1.9115
# Epoch 6, Batch 300/938: Loss=1.9056
# Epoch 6, Batch 400/938: Loss=2.2577
# Epoch 6, Batch 500/938: Loss=1.9353
# Epoch 6, Batch 600/938: Loss=1.9994
# Epoch 6, Batch 700/938: Loss=2.0695
# Epoch 6, Batch 800/938: Loss=1.9543
# Epoch 6, Batch 900/938: Loss=2.0393
# Epoch 6 | Train Loss: 2.0445 | Test Accuracy: 15.33%
# Epoch 7, Batch 0/938: Loss=2.0277
# Epoch 7, Batch 100/938: Loss=2.0775
# Epoch 7, Batch 200/938: Loss=2.0163
# Epoch 7, Batch 300/938: Loss=1.9454
# Epoch 7, Batch 400/938: Loss=1.9624
# Epoch 7, Batch 500/938: Loss=2.0329
# Epoch 7, Batch 600/938: Loss=2.1850
# Epoch 7, Batch 700/938: Loss=1.9705
# Epoch 7, Batch 800/938: Loss=2.0483
# Epoch 7, Batch 900/938: Loss=2.1138
# Epoch 7 | Train Loss: 2.0245 | Test Accuracy: 16.42%
# Epoch 8, Batch 0/938: Loss=2.1641
# Epoch 8, Batch 100/938: Loss=2.0401
# Epoch 8, Batch 200/938: Loss=2.1724
# Epoch 8, Batch 300/938: Loss=1.9861
# Epoch 8, Batch 400/938: Loss=1.9552
# Epoch 8, Batch 500/938: Loss=2.2389
# Epoch 8, Batch 600/938: Loss=2.0185
# Epoch 8, Batch 700/938: Loss=2.1779
# Epoch 8, Batch 800/938: Loss=1.8239
# Epoch 8, Batch 900/938: Loss=1.9702
# Epoch 8 | Train Loss: 2.0030 | Test Accuracy: 17.10%
# Epoch 9, Batch 0/938: Loss=2.1082
# Epoch 9, Batch 100/938: Loss=1.8990
# Epoch 9, Batch 200/938: Loss=1.8604
# Epoch 9, Batch 300/938: Loss=1.9776
# Epoch 9, Batch 400/938: Loss=2.0211
# Epoch 9, Batch 500/938: Loss=1.9728
# Epoch 9, Batch 600/938: Loss=2.0882
# Epoch 9, Batch 700/938: Loss=2.0280
# Epoch 9, Batch 800/938: Loss=2.0198
# Epoch 9, Batch 900/938: Loss=1.9780
# Epoch 9 | Train Loss: 1.9720 | Test Accuracy: 20.08%
# Final Test Accuracy: 20.08%
# Total training time: 2984.89 seconds
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.6263
# Epoch 0, Batch 100/938: Loss=2.2993
# Epoch 0, Batch 200/938: Loss=2.2983
# Epoch 0, Batch 300/938: Loss=2.3038
# Epoch 0, Batch 400/938: Loss=2.2999
# Epoch 0, Batch 500/938: Loss=2.3023
# Epoch 0, Batch 600/938: Loss=2.2973
# Epoch 0, Batch 700/938: Loss=2.3013
# Epoch 0, Batch 800/938: Loss=2.2984
# Epoch 0, Batch 900/938: Loss=2.3031
# Epoch 0 | Train Loss: 2.9758 | Test Accuracy: 11.35%
# Epoch 1, Batch 0/938: Loss=2.2989
# Epoch 1, Batch 100/938: Loss=2.3066
# Epoch 1, Batch 200/938: Loss=2.2822
# Epoch 1, Batch 300/938: Loss=2.2990
# Epoch 1, Batch 400/938: Loss=2.3019
# Epoch 1, Batch 500/938: Loss=2.3062
# Epoch 1, Batch 600/938: Loss=2.2964
# Epoch 1, Batch 700/938: Loss=2.2979
# Epoch 1, Batch 800/938: Loss=2.2928
# Epoch 1, Batch 900/938: Loss=2.3045
# Epoch 1 | Train Loss: 2.3014 | Test Accuracy: 11.35%
# Epoch 2, Batch 0/938: Loss=2.2918
# Epoch 2, Batch 100/938: Loss=2.3005
# Epoch 2, Batch 200/938: Loss=2.3005
# Epoch 2, Batch 300/938: Loss=2.3081
# Epoch 2, Batch 400/938: Loss=2.3099
# Epoch 2, Batch 500/938: Loss=2.2925
# Epoch 2, Batch 600/938: Loss=2.3034
# Epoch 2, Batch 700/938: Loss=2.2972
# Epoch 2, Batch 800/938: Loss=2.3053
# Epoch 2, Batch 900/938: Loss=2.2977
# Epoch 2 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 3, Batch 0/938: Loss=2.3136
# Epoch 3, Batch 100/938: Loss=2.2938
# Epoch 3, Batch 200/938: Loss=2.3005
# Epoch 3, Batch 300/938: Loss=2.3073
# Epoch 3, Batch 400/938: Loss=2.3066
# Epoch 3, Batch 500/938: Loss=2.3131
# Epoch 3, Batch 600/938: Loss=2.3089
# Epoch 3, Batch 700/938: Loss=2.3108
# Epoch 3, Batch 800/938: Loss=2.3089
# Epoch 3, Batch 900/938: Loss=2.3079
# Epoch 3 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 4, Batch 0/938: Loss=2.2974
# Epoch 4, Batch 100/938: Loss=2.2974
# Epoch 4, Batch 200/938: Loss=2.3133
# Epoch 4, Batch 300/938: Loss=2.3021
# Epoch 4, Batch 400/938: Loss=2.3068
# Epoch 4, Batch 500/938: Loss=2.2870
# Epoch 4, Batch 600/938: Loss=2.2988
# Epoch 4, Batch 700/938: Loss=2.3027
# Epoch 4, Batch 800/938: Loss=2.2969
# Epoch 4, Batch 900/938: Loss=2.2963
# Epoch 4 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 5, Batch 0/938: Loss=2.3036
# Epoch 5, Batch 100/938: Loss=2.2964
# Epoch 5, Batch 200/938: Loss=2.3162
# Epoch 5, Batch 300/938: Loss=2.3079
# Epoch 5, Batch 400/938: Loss=2.2983
# Epoch 5, Batch 500/938: Loss=2.2949
# Epoch 5, Batch 600/938: Loss=2.2970
# Epoch 5, Batch 700/938: Loss=2.3011
# Epoch 5, Batch 800/938: Loss=2.3139
# Epoch 5, Batch 900/938: Loss=2.2954
# Epoch 5 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 6, Batch 0/938: Loss=2.2941
# Epoch 6, Batch 100/938: Loss=2.3116
# Epoch 6, Batch 200/938: Loss=2.3121
# Epoch 6, Batch 300/938: Loss=2.3003
# Epoch 6, Batch 400/938: Loss=2.2946
# Epoch 6, Batch 500/938: Loss=2.2992
# Epoch 6, Batch 600/938: Loss=2.3011
# Epoch 6, Batch 700/938: Loss=2.3185
# Epoch 6, Batch 800/938: Loss=2.2891
# Epoch 6, Batch 900/938: Loss=2.2934
# Epoch 6 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 7, Batch 0/938: Loss=2.3084
# Epoch 7, Batch 100/938: Loss=2.3036
# Epoch 7, Batch 200/938: Loss=2.2936
# Epoch 7, Batch 300/938: Loss=2.3039
# Epoch 7, Batch 400/938: Loss=2.2933
# Epoch 7, Batch 500/938: Loss=2.2999
# Epoch 7, Batch 600/938: Loss=2.3016
# Epoch 7, Batch 700/938: Loss=2.2945
# Epoch 7, Batch 800/938: Loss=2.3078
# Epoch 7, Batch 900/938: Loss=2.3139
# Epoch 7 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 8, Batch 0/938: Loss=2.3058
# Epoch 8, Batch 100/938: Loss=2.3092
# Epoch 8, Batch 200/938: Loss=2.2892
# Epoch 8, Batch 300/938: Loss=2.3015
# Epoch 8, Batch 400/938: Loss=2.2960
# Epoch 8, Batch 500/938: Loss=2.3019
# Epoch 8, Batch 600/938: Loss=2.2974
# Epoch 8, Batch 700/938: Loss=2.3091
# Epoch 8, Batch 800/938: Loss=2.3058
# Epoch 8, Batch 900/938: Loss=2.2949
# Epoch 8 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 9, Batch 0/938: Loss=2.2929
# Epoch 9, Batch 100/938: Loss=2.3101
# Epoch 9, Batch 200/938: Loss=2.3024
# Epoch 9, Batch 300/938: Loss=2.3058
# Epoch 9, Batch 400/938: Loss=2.2827
# Epoch 9, Batch 500/938: Loss=2.2935
# Epoch 9, Batch 600/938: Loss=2.3028
# Epoch 9, Batch 700/938: Loss=2.3006
# Epoch 9, Batch 800/938: Loss=2.3054
# Epoch 9, Batch 900/938: Loss=2.3049
# Epoch 9 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Final Test Accuracy: 11.35%
# Total training time: 3002.41 seconds
# Training plots saved as 'mnist_resnet50_fisher_training.png'

# %%
import torch, torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# Dataset parameters
NUM_CLASSES = 10
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

K_PROBES = 4
EPSILON = 0.1

# Device setup for CUDA
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Load MNIST dataset
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST mean and std
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

class MNISTClassifier(nn.Module):
    def __init__(self, num_classes, k_probes, epsilon):
        super().__init__()
        self.epsilon = epsilon
        self.k_probes = k_probes
        self.num_classes = num_classes

        v = torch.randn(k_probes, 2)  # 2D probe directions
        v = v / torch.norm(v, dim=1, keepdim=True)
        self.register_buffer('probes', v)

        # ResNet101 backbone
        resnet_model = torch.hub.load('pytorch/vision:v0.10.0', 'resnet101', pretrained=False)
        self.intro = nn.Sequential(
            resnet_model.conv1,
            resnet_model.bn1,
            resnet_model.relu,
            resnet_model.maxpool
        )
        self.layer1 = resnet_model.layer1
        self.layer2 = resnet_model.layer2
        self.layer3 = resnet_model.layer3
        self.layer4 = resnet_model.layer4
        self.averagepool = resnet_model.avgpool

        # Classification head (2048 + O0/O1/O2 + 4 fisher terms = 2055)
        self.classifier = nn.Sequential(
            nn.Linear(2048 + 3 + 4, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def compute_score(self, x):
        if not x.requires_grad:
            x.requires_grad_(True)

        energy = x.mean()
        grads = torch.autograd.grad(
            outputs=energy,
            inputs=x,
            create_graph=True,
            retain_graph=True
        )[0]

        grads_flat = grads.view(grads.size(0), -1)
        if grads_flat.size(1) >= 2:
            grads_2d = grads_flat[:, :2]
        else:
            grads_2d = grads_flat

        scores = -torch.matmul(grads_2d, self.probes.T)
        return scores

    def compute_local_fisher(self, x):
        scores = self.compute_score(x)
        fisher_info = (scores ** 2).mean(dim=1, keepdim=True)
        return fisher_info

    def forward(self, x):
        if x.size(1) == 1:
            x = x.repeat(1, 3, 1, 1)

        x_resized = F.interpolate(x, size=(224, 224), mode='bilinear', align_corners=False)

        with torch.set_grad_enabled(True):
            if not x_resized.requires_grad:
                x_resized.requires_grad_(True)

            O0 = self.compute_local_fisher(x_resized)

            perturbation = torch.randn_like(x_resized) * self.epsilon
            x_pos = x_resized + perturbation
            x_neg = x_resized - perturbation

            I_pos = self.compute_local_fisher(x_pos)
            I_neg = self.compute_local_fisher(x_neg)

            O1 = (I_pos - I_neg) / (2 * self.epsilon)
            O2 = (I_pos - 2 * O0 + I_neg) / (self.epsilon ** 2)

        h = self.intro(x_resized)

        h = self.layer1(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer1 = self.compute_local_fisher(h)

        h = self.layer2(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer2 = self.compute_local_fisher(h)

        h = self.layer3(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer3 = self.compute_local_fisher(h)

        h = self.layer4(h)
        with torch.set_grad_enabled(True):
            if not h.requires_grad:
                h.requires_grad_(True)
            fish_layer4 = self.compute_local_fisher(h)

        h_pooled = self.averagepool(h)
        h_flat = h_pooled.flatten(1)

        fish_concat = torch.cat([fish_layer1, fish_layer2, fish_layer3, fish_layer4], dim=1)
        features = torch.cat([h_flat, O0, O1, O2, fish_concat], dim=1)

        logits = self.classifier(features)
        return logits

def calc_jet_loss(model, x):
    perturbation = torch.randn_like(x) * EPSILON
    x_pos = x + perturbation
    x_neg = x - perturbation
    pred_pos = model(x_pos)
    pred_neg = model(x_neg)
    D_hat = (pred_pos - pred_neg) / (2 * EPSILON) # [cite: 75]
    score_proj = model.compute_score(x).mean(dim=1, keepdim=True) # average score over probes
    loss_jet = ((D_hat + LAMBDA_JET * score_proj)**2).mean() #
    return loss_jet

def run_experiment(model, opt):
    model = model.to(device)
    optimizer = opt
    criterion = nn.CrossEntropyLoss()

    train_losses = []
    test_accuracies = []

    print("Starting MNIST Training...")
    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)

            ### JET Regularization
            loss_jet = calc_jet_loss(model, data)
            loss += ETA_JET * loss_jet

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

            if batch_idx % 100 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")

        avg_loss = epoch_loss / len(train_loader)
        train_losses.append(avg_loss)

        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()

        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.Adam(model.parameters(), lr=LR)
train_losses_resnet101_fisher_adam, test_accuracies_resnet101_fisher_adam = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.SGD(model.parameters(), lr=LR)
train_losses_resnet101_fisher_sgd, test_accuracies_resnet101_fisher_sgd = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.RMSprop(model.parameters(), lr=LR)
train_losses_resnet101_fisher_rmsprop, test_accuracies_resnet101_fisher_rmsprop = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_resnet101_fisher_adam, 'Adam', 'o', 'blue'),
    (train_losses_resnet101_fisher_sgd, 'SGD', 's', 'orange'),
    (train_losses_resnet101_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_resnet101_fisher_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_resnet101_fisher_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_resnet101_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ResNet101_Fisher Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ResNet101_Fisher Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_resnet101_fisher_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_resnet101_fisher_training.png'")
plt.show()
# Out:
# Using device: cuda
# Train samples: 60000, Test samples: 10000
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.8914
# Epoch 0, Batch 100/938: Loss=2.3004
# Epoch 0, Batch 200/938: Loss=2.3008
# Epoch 0, Batch 300/938: Loss=2.2971
# Epoch 0, Batch 400/938: Loss=2.2993
# Epoch 0, Batch 500/938: Loss=2.2985
# Epoch 0, Batch 600/938: Loss=2.3120
# Epoch 0, Batch 700/938: Loss=2.3031
# Epoch 0, Batch 800/938: Loss=2.3088
# Epoch 0, Batch 900/938: Loss=2.3044
# Epoch 0 | Train Loss: 2.3071 | Test Accuracy: 11.35%
# Epoch 1, Batch 0/938: Loss=2.2893
# Epoch 1, Batch 100/938: Loss=2.3043
# Epoch 1, Batch 200/938: Loss=2.3005
# Epoch 1, Batch 300/938: Loss=2.2973
# Epoch 1, Batch 400/938: Loss=2.2926
# Epoch 1, Batch 500/938: Loss=2.2992
# Epoch 1, Batch 600/938: Loss=2.3024
# Epoch 1, Batch 700/938: Loss=2.2998
# Epoch 1, Batch 800/938: Loss=2.2957
# Epoch 1, Batch 900/938: Loss=2.3168
# Epoch 1 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 2, Batch 0/938: Loss=2.2985
# Epoch 2, Batch 100/938: Loss=2.2998
# Epoch 2, Batch 200/938: Loss=2.2979
# Epoch 2, Batch 300/938: Loss=2.2955
# Epoch 2, Batch 400/938: Loss=2.2975
# Epoch 2, Batch 500/938: Loss=2.3006
# Epoch 2, Batch 600/938: Loss=2.3046
# Epoch 2, Batch 700/938: Loss=2.3103
# Epoch 2, Batch 800/938: Loss=2.3024
# Epoch 2, Batch 900/938: Loss=2.3093
# Epoch 2 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 3, Batch 0/938: Loss=2.3045
# Epoch 3, Batch 100/938: Loss=2.3012
# Epoch 3, Batch 200/938: Loss=2.3103
# Epoch 3, Batch 300/938: Loss=2.2970
# Epoch 3, Batch 400/938: Loss=2.3096
# Epoch 3, Batch 500/938: Loss=2.3121
# Epoch 3, Batch 600/938: Loss=2.3029
# Epoch 3, Batch 700/938: Loss=2.3023
# Epoch 3, Batch 800/938: Loss=2.2990
# Epoch 3, Batch 900/938: Loss=2.3043
# Epoch 3 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 4, Batch 0/938: Loss=2.3008
# Epoch 4, Batch 100/938: Loss=2.2966
# Epoch 4, Batch 200/938: Loss=2.3073
# Epoch 4, Batch 300/938: Loss=2.3113
# Epoch 4, Batch 400/938: Loss=2.3044
# Epoch 4, Batch 500/938: Loss=2.3053
# Epoch 4, Batch 600/938: Loss=2.3056
# Epoch 4, Batch 700/938: Loss=2.2964
# Epoch 4, Batch 800/938: Loss=2.3043
# Epoch 4, Batch 900/938: Loss=2.3018
# Epoch 4 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 5, Batch 0/938: Loss=2.2889
# Epoch 5, Batch 100/938: Loss=2.2901
# Epoch 5, Batch 200/938: Loss=2.2984
# Epoch 5, Batch 300/938: Loss=2.3056
# Epoch 5, Batch 400/938: Loss=2.3009
# Epoch 5, Batch 500/938: Loss=2.2936
# Epoch 5, Batch 600/938: Loss=2.3046
# Epoch 5, Batch 700/938: Loss=2.3018
# Epoch 5, Batch 800/938: Loss=2.3071
# Epoch 5, Batch 900/938: Loss=2.3076
# Epoch 5 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 6, Batch 0/938: Loss=2.2949
# Epoch 6, Batch 100/938: Loss=2.3049
# Epoch 6, Batch 200/938: Loss=2.2989
# Epoch 6, Batch 300/938: Loss=2.3019
# Epoch 6, Batch 400/938: Loss=2.2939
# Epoch 6, Batch 500/938: Loss=2.2956
# Epoch 6, Batch 600/938: Loss=2.2945
# Epoch 6, Batch 700/938: Loss=2.2832
# Epoch 6, Batch 800/938: Loss=2.3123
# Epoch 6, Batch 900/938: Loss=2.3034
# Epoch 6 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 7, Batch 0/938: Loss=2.2991
# Epoch 7, Batch 100/938: Loss=2.3034
# Epoch 7, Batch 200/938: Loss=2.3032
# Epoch 7, Batch 300/938: Loss=2.2992
# Epoch 7, Batch 400/938: Loss=2.3096
# Epoch 7, Batch 500/938: Loss=2.3059
# Epoch 7, Batch 600/938: Loss=2.3066
# Epoch 7, Batch 700/938: Loss=2.3038
# Epoch 7, Batch 800/938: Loss=2.3141
# Epoch 7, Batch 900/938: Loss=2.2910
# Epoch 7 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 8, Batch 0/938: Loss=2.3006
# Epoch 8, Batch 100/938: Loss=2.2853
# Epoch 8, Batch 200/938: Loss=2.3097
# Epoch 8, Batch 300/938: Loss=2.3028
# Epoch 8, Batch 400/938: Loss=2.2924
# Epoch 8, Batch 500/938: Loss=2.3037
# Epoch 8, Batch 600/938: Loss=2.2995
# Epoch 8, Batch 700/938: Loss=2.3037
# Epoch 8, Batch 800/938: Loss=2.2995
# Epoch 8, Batch 900/938: Loss=2.2986
# Epoch 8 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 9, Batch 0/938: Loss=2.3081
# Epoch 9, Batch 100/938: Loss=2.3109
# Epoch 9, Batch 200/938: Loss=2.2969
# Epoch 9, Batch 300/938: Loss=2.3016
# Epoch 9, Batch 400/938: Loss=2.2988
# Epoch 9, Batch 500/938: Loss=2.3032
# Epoch 9, Batch 600/938: Loss=2.3103
# Epoch 9, Batch 700/938: Loss=2.2992
# Epoch 9, Batch 800/938: Loss=2.3141
# Epoch 9, Batch 900/938: Loss=2.3021
# Epoch 9 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Final Test Accuracy: 11.35%
# Total training time: 4553.40 seconds
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.6327
# Epoch 0, Batch 100/938: Loss=2.3050
# Epoch 0, Batch 200/938: Loss=2.2937
# Epoch 0, Batch 300/938: Loss=2.3049
# Epoch 0, Batch 400/938: Loss=2.3002
# Epoch 0, Batch 500/938: Loss=2.2947
# Epoch 0, Batch 600/938: Loss=2.2878
# Epoch 0, Batch 700/938: Loss=2.2807
# Epoch 0, Batch 800/938: Loss=2.3097
# Epoch 0, Batch 900/938: Loss=2.2890
# Epoch 0 | Train Loss: 2.2977 | Test Accuracy: 20.67%
# Epoch 1, Batch 0/938: Loss=2.2751
# Epoch 1, Batch 100/938: Loss=2.2949
# Epoch 1, Batch 200/938: Loss=2.2809
# Epoch 1, Batch 300/938: Loss=2.2780
# Epoch 1, Batch 400/938: Loss=2.2662
# Epoch 1, Batch 500/938: Loss=2.2766
# Epoch 1, Batch 600/938: Loss=2.2839
# Epoch 1, Batch 700/938: Loss=2.2755
# Epoch 1, Batch 800/938: Loss=2.2658
# Epoch 1, Batch 900/938: Loss=2.3130
# Epoch 1 | Train Loss: 2.2754 | Test Accuracy: 21.54%
# Epoch 2, Batch 0/938: Loss=2.2911
# Epoch 2, Batch 100/938: Loss=2.2460
# Epoch 2, Batch 200/938: Loss=2.2712
# Epoch 2, Batch 300/938: Loss=2.2248
# Epoch 2, Batch 400/938: Loss=2.2567
# Epoch 2, Batch 500/938: Loss=2.2423
# Epoch 2, Batch 600/938: Loss=2.2221
# Epoch 2, Batch 700/938: Loss=2.2321
# Epoch 2, Batch 800/938: Loss=2.1710
# Epoch 2, Batch 900/938: Loss=2.2553
# Epoch 2 | Train Loss: 2.2541 | Test Accuracy: 21.89%
# Epoch 3, Batch 0/938: Loss=2.2035
# Epoch 3, Batch 100/938: Loss=2.2223
# Epoch 3, Batch 200/938: Loss=2.2072
# Epoch 3, Batch 300/938: Loss=2.2436
# Epoch 3, Batch 400/938: Loss=2.2071
# Epoch 3, Batch 500/938: Loss=2.2185
# Epoch 3, Batch 600/938: Loss=2.2379
# Epoch 3, Batch 700/938: Loss=2.1926
# Epoch 3, Batch 800/938: Loss=2.2617
# Epoch 3, Batch 900/938: Loss=2.2404
# Epoch 3 | Train Loss: 2.2316 | Test Accuracy: 22.30%
# Epoch 4, Batch 0/938: Loss=2.2087
# Epoch 4, Batch 100/938: Loss=2.2045
# Epoch 4, Batch 200/938: Loss=2.2288
# Epoch 4, Batch 300/938: Loss=2.2184
# Epoch 4, Batch 400/938: Loss=2.1884
# Epoch 4, Batch 500/938: Loss=2.2057
# Epoch 4, Batch 600/938: Loss=2.1909
# Epoch 4, Batch 700/938: Loss=2.1959
# Epoch 4, Batch 800/938: Loss=2.1258
# Epoch 4, Batch 900/938: Loss=2.1484
# Epoch 4 | Train Loss: 2.1930 | Test Accuracy: 23.47%
# Epoch 5, Batch 0/938: Loss=2.2422
# Epoch 5, Batch 100/938: Loss=2.2186
# Epoch 5, Batch 200/938: Loss=2.1213
# Epoch 5, Batch 300/938: Loss=2.2432
# Epoch 5, Batch 400/938: Loss=2.1486
# Epoch 5, Batch 500/938: Loss=2.2039
# Epoch 5, Batch 600/938: Loss=2.1448
# Epoch 5, Batch 700/938: Loss=2.0918
# Epoch 5, Batch 800/938: Loss=2.1105
# Epoch 5, Batch 900/938: Loss=2.2153
# Epoch 5 | Train Loss: 2.1229 | Test Accuracy: 17.09%
# Epoch 6, Batch 0/938: Loss=2.1352
# Epoch 6, Batch 100/938: Loss=2.0424
# Epoch 6, Batch 200/938: Loss=2.0696
# Epoch 6, Batch 300/938: Loss=1.9797
# Epoch 6, Batch 400/938: Loss=2.0890
# Epoch 6, Batch 500/938: Loss=2.1352
# Epoch 6, Batch 600/938: Loss=2.1895
# Epoch 6, Batch 700/938: Loss=2.0726
# Epoch 6, Batch 800/938: Loss=2.0312
# Epoch 6, Batch 900/938: Loss=2.0581
# Epoch 6 | Train Loss: 2.0672 | Test Accuracy: 25.85%
# Epoch 7, Batch 0/938: Loss=2.1140
# Epoch 7, Batch 100/938: Loss=2.0412
# Epoch 7, Batch 200/938: Loss=2.1697
# Epoch 7, Batch 300/938: Loss=2.0139
# Epoch 7, Batch 400/938: Loss=2.1224
# Epoch 7, Batch 500/938: Loss=2.1749
# Epoch 7, Batch 600/938: Loss=2.1974
# Epoch 7, Batch 700/938: Loss=2.0746
# Epoch 7, Batch 800/938: Loss=2.0616
# Epoch 7, Batch 900/938: Loss=1.9290
# Epoch 7 | Train Loss: 2.0482 | Test Accuracy: 15.66%
# Epoch 8, Batch 0/938: Loss=2.0028
# Epoch 8, Batch 100/938: Loss=1.8955
# Epoch 8, Batch 200/938: Loss=2.0727
# Epoch 8, Batch 300/938: Loss=2.1728
# Epoch 8, Batch 400/938: Loss=1.9650
# Epoch 8, Batch 500/938: Loss=2.1399
# Epoch 8, Batch 600/938: Loss=2.0167
# Epoch 8, Batch 700/938: Loss=2.0793
# Epoch 8, Batch 800/938: Loss=2.0955
# Epoch 8, Batch 900/938: Loss=1.9244
# Epoch 8 | Train Loss: 2.0348 | Test Accuracy: 18.76%
# Epoch 9, Batch 0/938: Loss=2.0217
# Epoch 9, Batch 100/938: Loss=2.0866
# Epoch 9, Batch 200/938: Loss=2.0060
# Epoch 9, Batch 300/938: Loss=2.1592
# Epoch 9, Batch 400/938: Loss=2.0103
# Epoch 9, Batch 500/938: Loss=2.1590
# Epoch 9, Batch 600/938: Loss=2.0097
# Epoch 9, Batch 700/938: Loss=2.0807
# Epoch 9, Batch 800/938: Loss=2.0277
# Epoch 9, Batch 900/938: Loss=1.9465
# Epoch 9 | Train Loss: 2.0207 | Test Accuracy: 28.68%
# Final Test Accuracy: 28.68%
# Total training time: 4605.74 seconds
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.6705
# Epoch 0, Batch 100/938: Loss=2.2975
# Epoch 0, Batch 200/938: Loss=2.3022
# Epoch 0, Batch 300/938: Loss=2.2873
# Epoch 0, Batch 400/938: Loss=2.2981
# Epoch 0, Batch 500/938: Loss=2.2698
# Epoch 0, Batch 600/938: Loss=2.2694
# Epoch 0, Batch 700/938: Loss=2.2409
# Epoch 0, Batch 800/938: Loss=2.2389
# Epoch 0, Batch 900/938: Loss=2.2960
# Epoch 0 | Train Loss: 3.1556 | Test Accuracy: 11.35%
# Epoch 1, Batch 0/938: Loss=2.2991
# Epoch 1, Batch 100/938: Loss=2.2990
# Epoch 1, Batch 200/938: Loss=2.3060
# Epoch 1, Batch 300/938: Loss=2.2942
# Epoch 1, Batch 400/938: Loss=2.2967
# Epoch 1, Batch 500/938: Loss=2.3042
# Epoch 1, Batch 600/938: Loss=2.3026
# Epoch 1, Batch 700/938: Loss=2.2910
# Epoch 1, Batch 800/938: Loss=2.2917
# Epoch 1, Batch 900/938: Loss=2.2974
# Epoch 1 | Train Loss: 2.3014 | Test Accuracy: 11.35%
# Epoch 2, Batch 0/938: Loss=2.3121
# Epoch 2, Batch 100/938: Loss=2.3107
# Epoch 2, Batch 200/938: Loss=2.3124
# Epoch 2, Batch 300/938: Loss=2.3003
# Epoch 2, Batch 400/938: Loss=2.2975
# Epoch 2, Batch 500/938: Loss=2.2981
# Epoch 2, Batch 600/938: Loss=2.2950
# Epoch 2, Batch 700/938: Loss=2.2903
# Epoch 2, Batch 800/938: Loss=2.2991
# Epoch 2, Batch 900/938: Loss=2.3040
# Epoch 2 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 3, Batch 0/938: Loss=2.2966
# Epoch 3, Batch 100/938: Loss=2.3043
# Epoch 3, Batch 200/938: Loss=2.2960
# Epoch 3, Batch 300/938: Loss=2.2865
# Epoch 3, Batch 400/938: Loss=2.3015
# Epoch 3, Batch 500/938: Loss=2.2938
# Epoch 3, Batch 600/938: Loss=2.3070
# Epoch 3, Batch 700/938: Loss=2.2992
# Epoch 3, Batch 800/938: Loss=2.3101
# Epoch 3, Batch 900/938: Loss=2.3019
# Epoch 3 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 4, Batch 0/938: Loss=2.3004
# Epoch 4, Batch 100/938: Loss=2.2964
# Epoch 4, Batch 200/938: Loss=2.3120
# Epoch 4, Batch 300/938: Loss=2.3139
# Epoch 4, Batch 400/938: Loss=2.2948
# Epoch 4, Batch 500/938: Loss=2.2917
# Epoch 4, Batch 600/938: Loss=2.3027
# Epoch 4, Batch 700/938: Loss=2.3100
# Epoch 4, Batch 800/938: Loss=2.2913
# Epoch 4, Batch 900/938: Loss=2.3010
# Epoch 4 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 5, Batch 0/938: Loss=2.3042
# Epoch 5, Batch 100/938: Loss=2.3046
# Epoch 5, Batch 200/938: Loss=2.3053
# Epoch 5, Batch 300/938: Loss=2.2958
# Epoch 5, Batch 400/938: Loss=2.3057
# Epoch 5, Batch 500/938: Loss=2.2869
# Epoch 5, Batch 600/938: Loss=2.2990
# Epoch 5, Batch 700/938: Loss=2.2983
# Epoch 5, Batch 800/938: Loss=2.2962
# Epoch 5, Batch 900/938: Loss=2.3008
# Epoch 5 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 6, Batch 0/938: Loss=2.2928
# Epoch 6, Batch 100/938: Loss=2.3046
# Epoch 6, Batch 200/938: Loss=2.2943
# Epoch 6, Batch 300/938: Loss=2.3063
# Epoch 6, Batch 400/938: Loss=2.2992
# Epoch 6, Batch 500/938: Loss=2.3029
# Epoch 6, Batch 600/938: Loss=2.3001
# Epoch 6, Batch 700/938: Loss=2.3026
# Epoch 6, Batch 800/938: Loss=2.3016
# Epoch 6, Batch 900/938: Loss=2.2938
# Epoch 6 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 7, Batch 0/938: Loss=2.3198
# Epoch 7, Batch 100/938: Loss=2.3061
# Epoch 7, Batch 200/938: Loss=2.2992
# Epoch 7, Batch 300/938: Loss=2.2943
# Epoch 7, Batch 400/938: Loss=2.3072
# Epoch 7, Batch 500/938: Loss=2.3023
# Epoch 7, Batch 600/938: Loss=2.3020
# Epoch 7, Batch 700/938: Loss=2.3099
# Epoch 7, Batch 800/938: Loss=2.3072
# Epoch 7, Batch 900/938: Loss=2.3028
# Epoch 7 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 8, Batch 0/938: Loss=2.3039
# Epoch 8, Batch 100/938: Loss=2.3072
# Epoch 8, Batch 200/938: Loss=2.3107
# Epoch 8, Batch 300/938: Loss=2.3011
# Epoch 8, Batch 400/938: Loss=2.2889
# Epoch 8, Batch 500/938: Loss=2.2992
# Epoch 8, Batch 600/938: Loss=2.2996
# Epoch 8, Batch 700/938: Loss=2.2979
# Epoch 8, Batch 800/938: Loss=2.2977
# Epoch 8, Batch 900/938: Loss=2.3024
# Epoch 8 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 9, Batch 0/938: Loss=2.3077
# Epoch 9, Batch 100/938: Loss=2.2928
# Epoch 9, Batch 200/938: Loss=2.3012
# Epoch 9, Batch 300/938: Loss=2.3146
# Epoch 9, Batch 400/938: Loss=2.2980
# Epoch 9, Batch 500/938: Loss=2.2974
# Epoch 9, Batch 600/938: Loss=2.3011
# Epoch 9, Batch 700/938: Loss=2.3020
# Epoch 9, Batch 800/938: Loss=2.3092
# Epoch 9, Batch 900/938: Loss=2.3051
# Epoch 9 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Final Test Accuracy: 11.35%
# Total training time: 4521.20 seconds
# Training plots saved as 'mnist_resnet101_fisher_training.png'

# %%
import torch, torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# Dataset parameters
NUM_CLASSES = 10
BATCH_SIZE = 64
EPOCHS = 10
LR = 0.001

K_PROBES = 4
EPSILON = 0.1

# Device setup for CUDA
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Load MNIST dataset
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
 ])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

print(f"Train samples: {len(train_dataset)}, Test samples: {len(test_dataset)}")

class MNISTClassifier(nn.Module):
    def __init__(self, num_classes, k_probes, epsilon):
        super().__init__()
        self.epsilon = epsilon
        self.k_probes = k_probes
        self.num_classes = num_classes

        v = torch.randn(k_probes, 2)
        v = v / torch.norm(v, dim=1, keepdim=True)
        self.register_buffer('probes', v)

        self.vit = torchvision.models.vit_b_16(weights=None)
        self.vit.conv_proj = nn.Conv2d(1, 768, kernel_size=16, stride=16, padding=0, bias=False)

        self.classifier = nn.Sequential(
            nn.Linear(768 + 3 + 4, 128),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(128, num_classes)
        )

    def compute_score(self, x):
        if not x.requires_grad:
            x.requires_grad_(True)

        energy = x.mean()
        grads = torch.autograd.grad(
            outputs=energy,
            inputs=x,
            create_graph=True,
            retain_graph=True
        )[0]

        grads_flat = grads.view(grads.size(0), -1)
        if grads_flat.size(1) >= 2:
            grads_2d = grads_flat[:, :2]
        else:
            grads_2d = grads_flat

        scores = -torch.matmul(grads_2d, self.probes.T)
        return scores

    def compute_local_fisher(self, x):
        scores = self.compute_score(x)
        fisher_info = (scores ** 2).mean(dim=1, keepdim=True)
        return fisher_info

    def forward(self, x):
        with torch.set_grad_enabled(True):
            if not x.requires_grad:
                x.requires_grad_(True)

            O0 = self.compute_local_fisher(x)

            perturbation = torch.randn_like(x) * self.epsilon
            I_pos = self.compute_local_fisher(x + perturbation)
            I_neg = self.compute_local_fisher(x - perturbation)

            O1 = (I_pos - I_neg) / (2 * self.epsilon)
            O2 = (I_pos - 2 * O0 + I_neg) / (self.epsilon ** 2)

        n = x.shape[0]
        h = self.vit._process_input(x)
        batch_class_token = self.vit.class_token.expand(n, -1, -1)
        h = torch.cat([batch_class_token, h], dim=1)
        h = h + self.vit.encoder.pos_embedding
        h = self.vit.encoder.dropout(h)

        fisher_terms = []
        for layer_idx, layer in enumerate(self.vit.encoder.layers):
            h = layer(h)
            if layer_idx in (2, 5, 8, 11):
                with torch.set_grad_enabled(True):
                    if not h.requires_grad:
                        h.requires_grad_(True)
                    fisher_terms.append(self.compute_local_fisher(h))

        h = self.vit.encoder.ln(h)
        cls_feature = h[:, 0]
        fish_concat = torch.cat(fisher_terms, dim=1)
        features = torch.cat([cls_feature, O0, O1, O2, fish_concat], dim=1)

        logits = self.classifier(features)
        return logits

def calc_jet_loss(model, x):
    perturbation = torch.randn_like(x) * EPSILON
    x_pos = x + perturbation
    x_neg = x - perturbation
    pred_pos = model(x_pos)
    pred_neg = model(x_neg)
    D_hat = (pred_pos - pred_neg) / (2 * EPSILON) # [cite: 75]
    score_proj = model.compute_score(x).mean(dim=1, keepdim=True) # average score over probes
    loss_jet = ((D_hat + LAMBDA_JET * score_proj)**2).mean() #
    return loss_jet

def run_experiment(model, opt):
    model = model.to(device)
    optimizer = opt
    criterion = nn.CrossEntropyLoss()

    train_losses = []
    test_accuracies = []

    print("Starting MNIST Training...")
    for epoch in range(EPOCHS):
        model.train()
        epoch_loss = 0
        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)

            ### JET Regularization
            loss_jet = calc_jet_loss(model, data)
            loss += ETA_JET * loss_jet

            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()

            if batch_idx % 100 == 0:
                print(f"Epoch {epoch}, Batch {batch_idx}/{len(train_loader)}: Loss={loss.item():.4f}")

        avg_loss = epoch_loss / len(train_loader)
        train_losses.append(avg_loss)

        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)
                output = model(data)
                _, predicted = torch.max(output.data, 1)
                total += target.size(0)
                correct += (predicted == target).sum().item()

        accuracy = 100 * correct / total
        test_accuracies.append(accuracy)
        print(f"Epoch {epoch} | Train Loss: {avg_loss:.4f} | Test Accuracy: {accuracy:.2f}%")

    print(f"Final Test Accuracy: {test_accuracies[-1]:.2f}%")
    return train_losses, test_accuracies

s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.Adam(model.parameters(), lr=LR)
train_losses_vit_fisher_adam, test_accuracies_vit_fisher_adam = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.SGD(model.parameters(), lr=LR)
train_losses_vit_fisher_sgd, test_accuracies_vit_fisher_sgd = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

s = time.time()
model = MNISTClassifier(NUM_CLASSES, K_PROBES, EPSILON)
opt = optim.RMSprop(model.parameters(), lr=LR)
train_losses_vit_fisher_rmsprop, test_accuracies_vit_fisher_rmsprop = run_experiment(model, opt)
print(f"Total training time: {time.time() - s:.2f} seconds")

epochs = list(range(EPOCHS))
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for loss, label, marker, color in [
    (train_losses_vit_fisher_adam, 'Adam', 'o', 'blue'),
    (train_losses_vit_fisher_sgd, 'SGD', 's', 'orange'),
    (train_losses_vit_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax1.plot(epochs, loss, marker=marker, linewidth=2, markersize=6, label=label, color=color)

for acc, label, marker, color in [
    (test_accuracies_vit_fisher_adam, 'Adam', 'o', 'blue'),
    (test_accuracies_vit_fisher_sgd, 'SGD', 's', 'orange'),
    (test_accuracies_vit_fisher_rmsprop, 'RMSprop', '^', 'red'),
]:
    ax2.plot(epochs, acc, marker=marker, linewidth=2, markersize=6, label=label, color=color)

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.set_title('MNIST + ViT_b_16_Fisher Training Loss')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('MNIST + ViT_b_16_Fisher Test Accuracy')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('mnist_vit_b_16_fisher_training.png', dpi=150, bbox_inches='tight')
print("Training plots saved as 'mnist_vit_b_16_fisher_training.png'")
plt.show()
# Out:
# Using device: cuda
# Train samples: 60000, Test samples: 10000
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.6802
# Epoch 0, Batch 100/938: Loss=2.3022
# Epoch 0, Batch 200/938: Loss=2.3000
# Epoch 0, Batch 300/938: Loss=2.2947
# Epoch 0, Batch 400/938: Loss=2.3023
# Epoch 0, Batch 500/938: Loss=2.3012
# Epoch 0, Batch 600/938: Loss=2.2990
# Epoch 0, Batch 700/938: Loss=2.3021
# Epoch 0, Batch 800/938: Loss=2.2961
# Epoch 0, Batch 900/938: Loss=2.3060
# Epoch 0 | Train Loss: 2.3050 | Test Accuracy: 11.35%
# Epoch 1, Batch 0/938: Loss=2.2951
# Epoch 1, Batch 100/938: Loss=2.2953
# Epoch 1, Batch 200/938: Loss=2.3050
# Epoch 1, Batch 300/938: Loss=2.3073
# Epoch 1, Batch 400/938: Loss=2.3171
# Epoch 1, Batch 500/938: Loss=2.3004
# Epoch 1, Batch 600/938: Loss=2.3144
# Epoch 1, Batch 700/938: Loss=2.3033
# Epoch 1, Batch 800/938: Loss=2.2979
# Epoch 1, Batch 900/938: Loss=2.3093
# Epoch 1 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 2, Batch 0/938: Loss=2.2997
# Epoch 2, Batch 100/938: Loss=2.3057
# Epoch 2, Batch 200/938: Loss=2.3042
# Epoch 2, Batch 300/938: Loss=2.2848
# Epoch 2, Batch 400/938: Loss=2.3012
# Epoch 2, Batch 500/938: Loss=2.2936
# Epoch 2, Batch 600/938: Loss=2.2935
# Epoch 2, Batch 700/938: Loss=2.3119
# Epoch 2, Batch 800/938: Loss=2.3041
# Epoch 2, Batch 900/938: Loss=2.3081
# Epoch 2 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 3, Batch 0/938: Loss=2.3005
# Epoch 3, Batch 100/938: Loss=2.3019
# Epoch 3, Batch 200/938: Loss=2.2924
# Epoch 3, Batch 300/938: Loss=2.2886
# Epoch 3, Batch 400/938: Loss=2.2925
# Epoch 3, Batch 500/938: Loss=2.3095
# Epoch 3, Batch 600/938: Loss=2.3046
# Epoch 3, Batch 700/938: Loss=2.2994
# Epoch 3, Batch 800/938: Loss=2.3016
# Epoch 3, Batch 900/938: Loss=2.2939
# Epoch 3 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 4, Batch 0/938: Loss=2.3018
# Epoch 4, Batch 100/938: Loss=2.3079
# Epoch 4, Batch 200/938: Loss=2.2929
# Epoch 4, Batch 300/938: Loss=2.2943
# Epoch 4, Batch 400/938: Loss=2.3047
# Epoch 4, Batch 500/938: Loss=2.3096
# Epoch 4, Batch 600/938: Loss=2.3107
# Epoch 4, Batch 700/938: Loss=2.2956
# Epoch 4, Batch 800/938: Loss=2.3033
# Epoch 4, Batch 900/938: Loss=2.2958
# Epoch 4 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 5, Batch 0/938: Loss=2.2980
# Epoch 5, Batch 100/938: Loss=2.2999
# Epoch 5, Batch 200/938: Loss=2.3021
# Epoch 5, Batch 300/938: Loss=2.2941
# Epoch 5, Batch 400/938: Loss=2.3133
# Epoch 5, Batch 500/938: Loss=2.3028
# Epoch 5, Batch 600/938: Loss=2.3041
# Epoch 5, Batch 700/938: Loss=2.3089
# Epoch 5, Batch 800/938: Loss=2.3043
# Epoch 5, Batch 900/938: Loss=2.3113
# Epoch 5 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 6, Batch 0/938: Loss=2.2974
# Epoch 6, Batch 100/938: Loss=2.3109
# Epoch 6, Batch 200/938: Loss=2.3111
# Epoch 6, Batch 300/938: Loss=2.3241
# Epoch 6, Batch 400/938: Loss=2.3096
# Epoch 6, Batch 500/938: Loss=2.2959
# Epoch 6, Batch 600/938: Loss=2.3056
# Epoch 6, Batch 700/938: Loss=2.3008
# Epoch 6, Batch 800/938: Loss=2.2925
# Epoch 6, Batch 900/938: Loss=2.2997
# Epoch 6 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 7, Batch 0/938: Loss=2.3029
# Epoch 7, Batch 100/938: Loss=2.2986
# Epoch 7, Batch 200/938: Loss=2.2805
# Epoch 7, Batch 300/938: Loss=2.3044
# Epoch 7, Batch 400/938: Loss=2.2979
# Epoch 7, Batch 500/938: Loss=2.3069
# Epoch 7, Batch 600/938: Loss=2.2969
# Epoch 7, Batch 700/938: Loss=2.2879
# Epoch 7, Batch 800/938: Loss=2.3144
# Epoch 7, Batch 900/938: Loss=2.3000
# Epoch 7 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 8, Batch 0/938: Loss=2.3084
# Epoch 8, Batch 100/938: Loss=2.2962
# Epoch 8, Batch 200/938: Loss=2.3018
# Epoch 8, Batch 300/938: Loss=2.3063
# Epoch 8, Batch 400/938: Loss=2.2980
# Epoch 8, Batch 500/938: Loss=2.3069
# Epoch 8, Batch 600/938: Loss=2.2957
# Epoch 8, Batch 700/938: Loss=2.3008
# Epoch 8, Batch 800/938: Loss=2.2971
# Epoch 8, Batch 900/938: Loss=2.2990
# Epoch 8 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 9, Batch 0/938: Loss=2.3035
# Epoch 9, Batch 100/938: Loss=2.3046
# Epoch 9, Batch 200/938: Loss=2.3121
# Epoch 9, Batch 300/938: Loss=2.3108
# Epoch 9, Batch 400/938: Loss=2.2959
# Epoch 9, Batch 500/938: Loss=2.3083
# Epoch 9, Batch 600/938: Loss=2.3030
# Epoch 9, Batch 700/938: Loss=2.3127
# Epoch 9, Batch 800/938: Loss=2.3020
# Epoch 9, Batch 900/938: Loss=2.3173
# Epoch 9 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Final Test Accuracy: 11.35%
# Total training time: 8041.81 seconds
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.8037
# Epoch 0, Batch 100/938: Loss=2.2988
# Epoch 0, Batch 200/938: Loss=2.2895
# Epoch 0, Batch 300/938: Loss=2.2765
# Epoch 0, Batch 400/938: Loss=2.3024
# Epoch 0, Batch 500/938: Loss=2.2954
# Epoch 0, Batch 600/938: Loss=2.2696
# Epoch 0, Batch 700/938: Loss=2.2764
# Epoch 0, Batch 800/938: Loss=2.2743
# Epoch 0, Batch 900/938: Loss=2.2745
# Epoch 0 | Train Loss: 2.2843 | Test Accuracy: 25.91%
# Epoch 1, Batch 0/938: Loss=2.2791
# Epoch 1, Batch 100/938: Loss=2.2542
# Epoch 1, Batch 200/938: Loss=2.2499
# Epoch 1, Batch 300/938: Loss=2.2519
# Epoch 1, Batch 400/938: Loss=2.2527
# Epoch 1, Batch 500/938: Loss=2.2033
# Epoch 1, Batch 600/938: Loss=2.2253
# Epoch 1, Batch 700/938: Loss=2.2321
# Epoch 1, Batch 800/938: Loss=2.2415
# Epoch 1, Batch 900/938: Loss=2.1967
# Epoch 1 | Train Loss: 2.2441 | Test Accuracy: 24.04%
# Epoch 2, Batch 0/938: Loss=2.3352
# Epoch 2, Batch 100/938: Loss=2.1632
# Epoch 2, Batch 200/938: Loss=2.1136
# Epoch 2, Batch 300/938: Loss=2.2845
# Epoch 2, Batch 400/938: Loss=2.2862
# Epoch 2, Batch 500/938: Loss=2.0812
# Epoch 2, Batch 600/938: Loss=2.2641
# Epoch 2, Batch 700/938: Loss=2.2754
# Epoch 2, Batch 800/938: Loss=2.2894
# Epoch 2, Batch 900/938: Loss=2.1289
# Epoch 2 | Train Loss: 2.2063 | Test Accuracy: 30.98%
# Epoch 3, Batch 0/938: Loss=2.1255
# Epoch 3, Batch 100/938: Loss=2.2886
# Epoch 3, Batch 200/938: Loss=2.1976
# Epoch 3, Batch 300/938: Loss=2.2818
# Epoch 3, Batch 400/938: Loss=2.2952
# Epoch 3, Batch 500/938: Loss=2.2294
# Epoch 3, Batch 600/938: Loss=2.0000
# Epoch 3, Batch 700/938: Loss=1.7175
# Epoch 3, Batch 800/938: Loss=1.9370
# Epoch 3, Batch 900/938: Loss=2.3013
# Epoch 3 | Train Loss: 2.1734 | Test Accuracy: 9.92%
# Epoch 4, Batch 0/938: Loss=2.3049
# Epoch 4, Batch 100/938: Loss=2.2997
# Epoch 4, Batch 200/938: Loss=2.3013
# Epoch 4, Batch 300/938: Loss=2.3036
# Epoch 4, Batch 400/938: Loss=2.2969
# Epoch 4, Batch 500/938: Loss=2.2935
# Epoch 4, Batch 600/938: Loss=2.3082
# Epoch 4, Batch 700/938: Loss=2.2972
# Epoch 4, Batch 800/938: Loss=2.3020
# Epoch 4, Batch 900/938: Loss=2.2317
# Epoch 4 | Train Loss: 2.2878 | Test Accuracy: 33.10%
# Epoch 5, Batch 0/938: Loss=2.0762
# Epoch 5, Batch 100/938: Loss=2.2951
# Epoch 5, Batch 200/938: Loss=2.2960
# Epoch 5, Batch 300/938: Loss=2.2993
# Epoch 5, Batch 400/938: Loss=2.3002
# Epoch 5, Batch 500/938: Loss=2.2935
# Epoch 5, Batch 600/938: Loss=2.2985
# Epoch 5, Batch 700/938: Loss=2.2860
# Epoch 5, Batch 800/938: Loss=2.2940
# Epoch 5, Batch 900/938: Loss=2.2921
# Epoch 5 | Train Loss: 2.2824 | Test Accuracy: 12.96%
# Epoch 6, Batch 0/938: Loss=2.2978
# Epoch 6, Batch 100/938: Loss=2.2889
# Epoch 6, Batch 200/938: Loss=2.2910
# Epoch 6, Batch 300/938: Loss=2.2669
# Epoch 6, Batch 400/938: Loss=2.2937
# Epoch 6, Batch 500/938: Loss=2.2497
# Epoch 6, Batch 600/938: Loss=2.2623
# Epoch 6, Batch 700/938: Loss=2.2784
# Epoch 6, Batch 800/938: Loss=2.1605
# Epoch 6, Batch 900/938: Loss=2.1021
# Epoch 6 | Train Loss: 2.2238 | Test Accuracy: 20.88%
# Epoch 7, Batch 0/938: Loss=2.2985
# Epoch 7, Batch 100/938: Loss=1.5169
# Epoch 7, Batch 200/938: Loss=2.3020
# Epoch 7, Batch 300/938: Loss=2.3020
# Epoch 7, Batch 400/938: Loss=2.2959
# Epoch 7, Batch 500/938: Loss=2.2970
# Epoch 7, Batch 600/938: Loss=2.2972
# Epoch 7, Batch 700/938: Loss=2.1884
# Epoch 7, Batch 800/938: Loss=2.2899
# Epoch 7, Batch 900/938: Loss=2.2836
# Epoch 7 | Train Loss: 2.2596 | Test Accuracy: 17.36%
# Epoch 8, Batch 0/938: Loss=2.2314
# Epoch 8, Batch 100/938: Loss=1.6062
# Epoch 8, Batch 200/938: Loss=2.1864
# Epoch 8, Batch 300/938: Loss=2.2990
# Epoch 8, Batch 400/938: Loss=2.2893
# Epoch 8, Batch 500/938: Loss=2.2972
# Epoch 8, Batch 600/938: Loss=2.2922
# Epoch 8, Batch 700/938: Loss=2.2847
# Epoch 8, Batch 800/938: Loss=1.6730
# Epoch 8, Batch 900/938: Loss=1.4798
# Epoch 8 | Train Loss: 2.0747 | Test Accuracy: 50.58%
# Epoch 9, Batch 0/938: Loss=1.4110
# Epoch 9, Batch 100/938: Loss=1.3508
# Epoch 9, Batch 200/938: Loss=1.5279
# Epoch 9, Batch 300/938: Loss=2.3084
# Epoch 9, Batch 400/938: Loss=2.2973
# Epoch 9, Batch 500/938: Loss=2.3040
# Epoch 9, Batch 600/938: Loss=2.3020
# Epoch 9, Batch 700/938: Loss=2.3021
# Epoch 9, Batch 800/938: Loss=2.3096
# Epoch 9, Batch 900/938: Loss=2.2923
# Epoch 9 | Train Loss: 2.0875 | Test Accuracy: 11.35%
# Final Test Accuracy: 11.35%
# Total training time: 7593.92 seconds
# Starting MNIST Training...
# Epoch 0, Batch 0/938: Loss=3.6012
# Epoch 0, Batch 100/938: Loss=2.3021
# Epoch 0, Batch 200/938: Loss=2.2933
# Epoch 0, Batch 300/938: Loss=2.3052
# Epoch 0, Batch 400/938: Loss=2.3028
# Epoch 0, Batch 500/938: Loss=2.2994
# Epoch 0, Batch 600/938: Loss=2.2976
# Epoch 0, Batch 700/938: Loss=2.2931
# Epoch 0, Batch 800/938: Loss=2.2940
# Epoch 0, Batch 900/938: Loss=2.3027
# Epoch 0 | Train Loss: 2.3974 | Test Accuracy: 11.35%
# Epoch 1, Batch 0/938: Loss=2.3135
# Epoch 1, Batch 100/938: Loss=2.3038
# Epoch 1, Batch 200/938: Loss=2.3006
# Epoch 1, Batch 300/938: Loss=2.2933
# Epoch 1, Batch 400/938: Loss=2.2954
# Epoch 1, Batch 500/938: Loss=2.3096
# Epoch 1, Batch 600/938: Loss=2.3103
# Epoch 1, Batch 700/938: Loss=2.3075
# Epoch 1, Batch 800/938: Loss=2.2948
# Epoch 1, Batch 900/938: Loss=2.3004
# Epoch 1 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 2, Batch 0/938: Loss=2.3077
# Epoch 2, Batch 100/938: Loss=2.3097
# Epoch 2, Batch 200/938: Loss=2.3128
# Epoch 2, Batch 300/938: Loss=2.3038
# Epoch 2, Batch 400/938: Loss=2.3039
# Epoch 2, Batch 500/938: Loss=2.2948
# Epoch 2, Batch 600/938: Loss=2.3018
# Epoch 2, Batch 700/938: Loss=2.3130
# Epoch 2, Batch 800/938: Loss=2.2972
# Epoch 2, Batch 900/938: Loss=2.2996
# Epoch 2 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 3, Batch 0/938: Loss=2.2958
# Epoch 3, Batch 100/938: Loss=2.2981
# Epoch 3, Batch 200/938: Loss=2.3012
# Epoch 3, Batch 300/938: Loss=2.3005
# Epoch 3, Batch 400/938: Loss=2.2977
# Epoch 3, Batch 500/938: Loss=2.3068
# Epoch 3, Batch 600/938: Loss=2.3056
# Epoch 3, Batch 700/938: Loss=2.3007
# Epoch 3, Batch 800/938: Loss=2.3071
# Epoch 3, Batch 900/938: Loss=2.2935
# Epoch 3 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 4, Batch 0/938: Loss=2.3024
# Epoch 4, Batch 100/938: Loss=2.3042
# Epoch 4, Batch 200/938: Loss=2.3005
# Epoch 4, Batch 300/938: Loss=2.2996
# Epoch 4, Batch 400/938: Loss=2.3036
# Epoch 4, Batch 500/938: Loss=2.3081
# Epoch 4, Batch 600/938: Loss=2.2985
# Epoch 4, Batch 700/938: Loss=2.3090
# Epoch 4, Batch 800/938: Loss=2.2975
# Epoch 4, Batch 900/938: Loss=2.3135
# Epoch 4 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 5, Batch 0/938: Loss=2.2932
# Epoch 5, Batch 100/938: Loss=2.3151
# Epoch 5, Batch 200/938: Loss=2.3175
# Epoch 5, Batch 300/938: Loss=2.2971
# Epoch 5, Batch 400/938: Loss=2.2967
# Epoch 5, Batch 500/938: Loss=2.3129
# Epoch 5, Batch 600/938: Loss=2.2980
# Epoch 5, Batch 700/938: Loss=2.3080
# Epoch 5, Batch 800/938: Loss=2.2978
# Epoch 5, Batch 900/938: Loss=2.2943
# Epoch 5 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 6, Batch 0/938: Loss=2.3071
# Epoch 6, Batch 100/938: Loss=2.2902
# Epoch 6, Batch 200/938: Loss=2.2968
# Epoch 6, Batch 300/938: Loss=2.3050
# Epoch 6, Batch 400/938: Loss=2.3109
# Epoch 6, Batch 500/938: Loss=2.3042
# Epoch 6, Batch 600/938: Loss=2.3091
# Epoch 6, Batch 700/938: Loss=2.2985
# Epoch 6, Batch 800/938: Loss=2.2968
# Epoch 6, Batch 900/938: Loss=2.2991
# Epoch 6 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 7, Batch 0/938: Loss=2.2997
# Epoch 7, Batch 100/938: Loss=2.2963
# Epoch 7, Batch 200/938: Loss=2.3124
# Epoch 7, Batch 300/938: Loss=2.3066
# Epoch 7, Batch 400/938: Loss=2.2935
# Epoch 7, Batch 500/938: Loss=2.3098
# Epoch 7, Batch 600/938: Loss=2.3047
# Epoch 7, Batch 700/938: Loss=2.2989
# Epoch 7, Batch 800/938: Loss=2.2947
# Epoch 7, Batch 900/938: Loss=2.3040
# Epoch 7 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 8, Batch 0/938: Loss=2.3028
# Epoch 8, Batch 100/938: Loss=2.2926
# Epoch 8, Batch 200/938: Loss=2.2983
# Epoch 8, Batch 300/938: Loss=2.3048
# Epoch 8, Batch 400/938: Loss=2.3047
# Epoch 8, Batch 500/938: Loss=2.2955
# Epoch 8, Batch 600/938: Loss=2.2862
# Epoch 8, Batch 700/938: Loss=2.3015
# Epoch 8, Batch 800/938: Loss=2.3078
# Epoch 8, Batch 900/938: Loss=2.2890
# Epoch 8 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Epoch 9, Batch 0/938: Loss=2.2999
# Epoch 9, Batch 100/938: Loss=2.2986
# Epoch 9, Batch 200/938: Loss=2.3045
# Epoch 9, Batch 300/938: Loss=2.3121
# Epoch 9, Batch 400/938: Loss=2.3002
# Epoch 9, Batch 500/938: Loss=2.3141
# Epoch 9, Batch 600/938: Loss=2.3077
# Epoch 9, Batch 700/938: Loss=2.2962
# Epoch 9, Batch 800/938: Loss=2.3097
# Epoch 9, Batch 900/938: Loss=2.2992
# Epoch 9 | Train Loss: 2.3013 | Test Accuracy: 11.35%
# Final Test Accuracy: 11.35%
# Total training time: 8605.34 seconds
# Training plots saved as 'mnist_vit_b_16_fisher_training.png'

# %%
import pandas as pd

rows = []

g = globals()
loss_keys = sorted([k for k in g.keys() if k.startswith('train_losses_')])

for loss_key in loss_keys:
    suffix = loss_key.replace('train_losses_', '', 1)
    acc_key = f'test_accuracies_{suffix}'

    losses = g.get(loss_key)
    accuracies = g.get(acc_key)

    if losses is None or accuracies is None:
        continue

    n_epochs = min(len(losses), len(accuracies))
    for epoch in range(n_epochs):
        rows.append({
            'experiment': suffix,
            'epoch': epoch,
            'train_loss': float(losses[epoch]),
            'test_accuracy': float(accuracies[epoch])
        })

if not rows:
    raise RuntimeError(
        "No training outputs found. Run Cells 1–8 first so train_losses_* and test_accuracies_* variables exist."
    )

output_df = pd.DataFrame(rows).sort_values(['experiment', 'epoch']).reset_index(drop=True)
output_path = 'test1_copycopy_jet_output.csv'
output_df.to_csv(output_path, index=False)

print(f"Saved {len(output_df)} rows to {output_path}")
print(output_df.head())
# Out:
# Saved 120 rows to test1_copycopy_jet_output.csv
#               experiment  epoch  train_loss  test_accuracy
# 0  resnet101_fisher_adam      0    2.307148          11.35
# 1  resnet101_fisher_adam      1    2.301286          11.35
# 2  resnet101_fisher_adam      2    2.301279          11.35
# 3  resnet101_fisher_adam      3    2.301317          11.35
# 4  resnet101_fisher_adam      4    2.301304          11.35
