# %%
import pandas as pd


fname = "test1_copycopy_output.csv"
try:
    df = pd.read_csv(fname)
    print(df.to_string(index=False))
except FileNotFoundError:
    print(f"File not found: {fname}")
except Exception as e:
    print("Error reading file:", e)
# Out:
#                 experiment  epoch  train_loss  test_accuracy
#    resnet101_baseline_adam      0    0.304443          97.38
#    resnet101_baseline_adam      1    0.107313          97.68
#    resnet101_baseline_adam      2    0.135338          98.11
#    resnet101_baseline_adam      3    0.052210          98.60
#    resnet101_baseline_adam      4    0.043684          97.64
#    resnet101_baseline_adam      5    0.073284          98.01
#    resnet101_baseline_adam      6    0.060899          98.48
#    resnet101_baseline_adam      7    0.131012          97.28
#    resnet101_baseline_adam      8    0.063255          98.68
#    resnet101_baseline_adam      9    0.044197          98.61
# resnet101_baseline_rmsprop      0    0.592181          85.87
# resnet101_baseline_rmsprop      1    0.244646          49.74
# resnet101_baseline_rmsprop      2    0.085499          97.51
# resnet101_baseline_rmsprop      3    0.089510          98.50
# resnet101_baseline_rmsprop      4    0.080522          98.16
# resnet101_baseline_rmsprop      5    0.078343          98.70
# resnet101_baseline_rmsprop      6    0.053083          99.09
# resnet101_baseline_rmsprop      7    0.044155          99.06
# resnet101_baseline_rmsprop      8    0.030653          95.90
# resnet101_baseline_rmsprop      9    0.043177          98.92
#     resnet101_baseline_sgd      0    1.630374          77.68
#     resnet101_baseline_sgd      1    0.515909          90.18
#     resnet101_baseline_sgd      2    0.296819          93.38
#     resnet101_baseline_sgd      3    0.209602          94.90
#     resnet101_baseline_sgd      4    0.168944          95.70
#     resnet101_baseline_sgd      5    0.137632          95.91
#     resnet101_baseline_sgd      6    0.118328          96.59
#     resnet101_baseline_sgd      7    0.101286          96.67
#     resnet101_baseline_sgd      8    0.088029          96.86
#     resnet101_baseline_sgd      9    0.074365          97.26
#      resnet101_fisher_adam      0    0.638275          96.58
#      resnet101_fisher_adam      1    0.332323          98.15
#      resnet101_fisher_adam      2    0.277976          98.48
#      resnet101_fisher_adam      3    0.252835          98.66
#      resnet101_fisher_adam      4    0.224897          98.85
#      resnet101_fisher_adam      5    0.210726          98.74
#      resnet101_fisher_adam      6    0.202139          99.06
#      resnet101_fisher_adam      7    0.189756          98.99
#      resnet101_fisher_adam      8    0.171306          98.87
#      resnet101_fisher_adam      9    0.171586          99.24
#   resnet101_fisher_rmsprop      0    0.657931          83.32
#   resnet101_fisher_rmsprop      1    0.210710          97.81
#   resnet101_fisher_rmsprop      2    0.151207          97.68
#   resnet101_fisher_rmsprop      3    0.123988          98.44
#   resnet101_fisher_rmsprop      4    0.103232          98.60
#   resnet101_fisher_rmsprop      5    0.095311          99.26
#   resnet101_fisher_rmsprop      6    0.086823          98.80
#   resnet101_fisher_rmsprop      7    0.076981          99.08
#   resnet101_fisher_rmsprop      8    0.071459          99.34
#   resnet101_fisher_rmsprop      9    0.061900          99.29
#       resnet101_fisher_sgd      0    2.186048          22.76
#       resnet101_fisher_sgd      1    1.971989          28.75
#       resnet101_fisher_sgd      2    1.824627          29.66
#       resnet101_fisher_sgd      3    1.705289          41.06
#       resnet101_fisher_sgd      4    1.599032          26.37
#       resnet101_fisher_sgd      5    1.458290          34.82
#       resnet101_fisher_sgd      6    1.334967          56.67
#       resnet101_fisher_sgd      7    1.226253          62.39
#       resnet101_fisher_sgd      8    1.126282          68.93
#       resnet101_fisher_sgd      9    1.039992          71.53
#     resnet18_baseline_adam      0    0.136451          97.97
#     resnet18_baseline_adam      1    0.058246          98.04
#     resnet18_baseline_adam      2    0.044646          98.61
#     resnet18_baseline_adam      3    0.039177          98.77
#     resnet18_baseline_adam      4    0.031702          98.83
#     resnet18_baseline_adam      5    0.028794          99.17
#     resnet18_baseline_adam      6    0.025435          99.13
#     resnet18_baseline_adam      7    0.022707          99.19
#     resnet18_baseline_adam      8    0.023371          99.01
#     resnet18_baseline_adam      9    0.017866          99.19
#  resnet18_baseline_rmsprop      0    0.160728          94.05
#  resnet18_baseline_rmsprop      1    0.063584          98.49
#  resnet18_baseline_rmsprop      2    0.045120          98.71
#  resnet18_baseline_rmsprop      3    0.035211          99.10
#  resnet18_baseline_rmsprop      4    0.031099          96.00
#  resnet18_baseline_rmsprop      5    0.024644          98.69
#  resnet18_baseline_rmsprop      6    0.021396          99.35
#  resnet18_baseline_rmsprop      7    0.018636          99.26
#  resnet18_baseline_rmsprop      8    0.017028          98.97
#  resnet18_baseline_rmsprop      9    0.014308          99.29
#      resnet18_baseline_sgd      0    0.545001          94.50
#      resnet18_baseline_sgd      1    0.173398          96.46
#      resnet18_baseline_sgd      2    0.116961          97.07
#      resnet18_baseline_sgd      3    0.089336          97.52
#      resnet18_baseline_sgd      4    0.071088          97.65
#      resnet18_baseline_sgd      5    0.059068          97.88
#      resnet18_baseline_sgd      6    0.048050          97.95
#      resnet18_baseline_sgd      7    0.041188          98.09
#      resnet18_baseline_sgd      8    0.036336          98.26
#      resnet18_baseline_sgd      9    0.031457          98.22
#       resnet18_fisher_adam      0    0.179922          97.86
#       resnet18_fisher_adam      1    0.069112          99.05
#       resnet18_fisher_adam      2    0.051582          99.30
#       resnet18_fisher_adam      3    0.045248          99.12
#       resnet18_fisher_adam      4    0.038576          99.02
#       resnet18_fisher_adam      5    0.035792          99.12
#       resnet18_fisher_adam      6    0.029747          99.33
#       resnet18_fisher_adam      7    0.026911          99.37
#       resnet18_fisher_adam      8    0.027300          99.31
#       resnet18_fisher_adam      9    0.022549          99.35
#    resnet18_fisher_rmsprop      0    0.314919          95.27
#    resnet18_fisher_rmsprop      1    0.088825          98.99
#    resnet18_fisher_rmsprop      2    0.064514          99.17
#    resnet18_fisher_rmsprop      3    0.050602          98.89
#    resnet18_fisher_rmsprop      4    0.042779          99.37
#    resnet18_fisher_rmsprop      5    0.037541          97.20
#    resnet18_fisher_rmsprop      6    0.033945          99.26
#    resnet18_fisher_rmsprop      7    0.028375          99.16
#    resnet18_fisher_rmsprop      8    0.026152          99.17
#    resnet18_fisher_rmsprop      9    0.025757          99.46
#        resnet18_fisher_sgd      0    2.224770          28.30
#        resnet18_fisher_sgd      1    1.961970          47.45
#        resnet18_fisher_sgd      2    1.752656          57.77
#        resnet18_fisher_sgd      3    1.513862          65.52
#        resnet18_fisher_sgd      4    1.170877          81.66
#        resnet18_fisher_sgd      5    0.842615          80.74
#        resnet18_fisher_sgd      6    0.620332          92.01
#        resnet18_fisher_sgd      7    0.476829          91.71
#        resnet18_fisher_sgd      8    0.384371          94.40
#        resnet18_fisher_sgd      9    0.319808          95.87
#     resnet50_baseline_adam      0    0.254228          97.36
#     resnet50_baseline_adam      1    0.077123          98.35
#     resnet50_baseline_adam      2    0.148650          98.08
#     resnet50_baseline_adam      3    0.068414          98.19
#     resnet50_baseline_adam      4    0.079925          98.47
#     resnet50_baseline_adam      5    0.105707          98.44
#     resnet50_baseline_adam      6    0.082865          98.80
#     resnet50_baseline_adam      7    0.046197          98.79
#     resnet50_baseline_adam      8    0.034679          98.60
#     resnet50_baseline_adam      9    0.034098          98.22
#  resnet50_baseline_rmsprop      0    0.442532          96.62
#  resnet50_baseline_rmsprop      1    0.178227          97.82
#  resnet50_baseline_rmsprop      2    0.118189          98.13
#  resnet50_baseline_rmsprop      3    0.083888          98.73
#  resnet50_baseline_rmsprop      4    0.073575          98.27
#  resnet50_baseline_rmsprop      5    0.060014          99.08
#  resnet50_baseline_rmsprop      6    0.046417          98.73
#  resnet50_baseline_rmsprop      7    0.041819          97.92
#  resnet50_baseline_rmsprop      8    0.031246          96.84
#  resnet50_baseline_rmsprop      9    0.030497          99.23
#      resnet50_baseline_sgd      0    1.504023          82.66
#      resnet50_baseline_sgd      1    0.405477          92.43
#      resnet50_baseline_sgd      2    0.231086          94.84
#      resnet50_baseline_sgd      3    0.165585          95.86
#      resnet50_baseline_sgd      4    0.128666          96.25
#      resnet50_baseline_sgd      5    0.103462          96.76
#      resnet50_baseline_sgd      6    0.085216          96.95
#      resnet50_baseline_sgd      7    0.069055          97.18
#      resnet50_baseline_sgd      8    0.056591          97.24
#      resnet50_baseline_sgd      9    0.046620          97.34
#       resnet50_fisher_adam      0    0.372681          97.56
#       resnet50_fisher_adam      1    0.161060          98.76
#       resnet50_fisher_adam      2    0.132310          98.85
#       resnet50_fisher_adam      3    0.108945          99.23
#       resnet50_fisher_adam      4    0.100353          98.30
#       resnet50_fisher_adam      5    0.091826          97.88
#       resnet50_fisher_adam      6    0.083656          99.12
#       resnet50_fisher_adam      7    0.076758          99.05
#       resnet50_fisher_adam      8    0.067719          99.21
#       resnet50_fisher_adam      9    0.067663          99.21
#    resnet50_fisher_rmsprop      0    0.881076          95.86
#    resnet50_fisher_rmsprop      1    0.389663          94.08
#    resnet50_fisher_rmsprop      2    0.299618          97.73
#    resnet50_fisher_rmsprop      3    0.240073          98.96
#    resnet50_fisher_rmsprop      4    0.196995          97.84
#    resnet50_fisher_rmsprop      5    0.182697          98.24
#    resnet50_fisher_rmsprop      6    0.165423          98.89
#    resnet50_fisher_rmsprop      7    0.159394          99.01
#    resnet50_fisher_rmsprop      8    0.135121          98.76
#    resnet50_fisher_rmsprop      9    0.124978          98.94
#        resnet50_fisher_sgd      0    2.160077          27.08
#        resnet50_fisher_sgd      1    1.902041          13.86
#        resnet50_fisher_sgd      2    1.773533          28.97
#        resnet50_fisher_sgd      3    1.641556          48.23
#        resnet50_fisher_sgd      4    1.470916          53.75
#        resnet50_fisher_sgd      5    1.301671          63.80
#        resnet50_fisher_sgd      6    1.160329          51.02
#        resnet50_fisher_sgd      7    1.011299          70.03
#        resnet50_fisher_sgd      8    0.867184          76.77
#        resnet50_fisher_sgd      9    0.720329          84.61
#          vit_baseline_adam      0    2.202783          19.90
#          vit_baseline_adam      1    1.980394          25.96
#          vit_baseline_adam      2    1.982849          25.29
#          vit_baseline_adam      3    1.950822          27.63
#          vit_baseline_adam      4    1.904928          28.14
#          vit_baseline_adam      5    1.839452          19.49
#          vit_baseline_adam      6    2.187273          22.79
#          vit_baseline_adam      7    2.098136          23.00
#          vit_baseline_adam      8    2.120069          22.38
#          vit_baseline_adam      9    2.052541          21.45
#       vit_baseline_rmsprop      0    2.294248          22.94
#       vit_baseline_rmsprop      1    2.039065          23.14
#       vit_baseline_rmsprop      2    2.062261          23.79
#       vit_baseline_rmsprop      3    2.045333          19.03
#       vit_baseline_rmsprop      4    2.059651          22.91
#       vit_baseline_rmsprop      5    2.011928          21.77
#       vit_baseline_rmsprop      6    2.071658          20.55
#       vit_baseline_rmsprop      7    2.057452          21.00
#       vit_baseline_rmsprop      8    2.070240          21.70
#       vit_baseline_rmsprop      9    2.085733          15.25
#           vit_baseline_sgd      0    1.566339          56.00
#           vit_baseline_sgd      1    1.072802          68.60
#           vit_baseline_sgd      2    0.774681          71.61
#           vit_baseline_sgd      3    0.564993          72.48
#           vit_baseline_sgd      4    0.419056          79.40
#           vit_baseline_sgd      5    0.329485          86.75
#           vit_baseline_sgd      6    0.258088          93.29
#           vit_baseline_sgd      7    0.213788          93.69
#           vit_baseline_sgd      8    0.178253          94.11
#           vit_baseline_sgd      9    0.155738          91.88
#            vit_fisher_adam      0    2.303218          11.35
#            vit_fisher_adam      1    2.301294          11.35
#            vit_fisher_adam      2    2.301296          11.35
#            vit_fisher_adam      3    2.301287          11.35
#            vit_fisher_adam      4    2.301279          11.35
#            vit_fisher_adam      5    2.301311          11.35
#            vit_fisher_adam      6    2.301299          11.35
#            vit_fisher_adam      7    2.301300          11.35
#            vit_fisher_adam      8    2.301296          11.35
#            vit_fisher_adam      9    2.301321          11.35
#         vit_fisher_rmsprop      0    2.311151          11.35
#         vit_fisher_rmsprop      1    2.301303          11.35
#         vit_fisher_rmsprop      2    2.301295          11.35
#         vit_fisher_rmsprop      3    2.301254          11.35
#         vit_fisher_rmsprop      4    2.301257          11.35
#         vit_fisher_rmsprop      5    2.301293          11.35
#         vit_fisher_rmsprop      6    2.301308          11.35
#         vit_fisher_rmsprop      7    2.301286          11.35
#         vit_fisher_rmsprop      8    2.301277          11.35
#         vit_fisher_rmsprop      9    2.301282          11.35
#             vit_fisher_sgd      0    1.863929          42.30
#             vit_fisher_sgd      1    1.444994          59.37
#             vit_fisher_sgd      2    1.186965          63.79
#             vit_fisher_sgd      3    0.980155          72.43
#             vit_fisher_sgd      4    0.775296          81.09
#             vit_fisher_sgd      5    0.598606          67.34
#             vit_fisher_sgd      6    0.476973          84.70
#             vit_fisher_sgd      7    0.393341          89.86
#             vit_fisher_sgd      8    0.325111          90.24
#             vit_fisher_sgd      9    0.283364          85.68

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import colorsys

def _adjust_lightness(color, factor):
    r, g, b = mcolors.to_rgb(color)
    h, l, s = colorsys.rgb_to_hls(r, g, b)
    l = max(0.0, min(1.0, l * factor))
    return colorsys.hls_to_rgb(h, l, s)

def _first_token(experiment_name):
    parts = str(experiment_name).lower().split('_')
    return parts[0] if parts else str(experiment_name).lower()

def experiment_color(experiment_name, token_to_base):
    first_token = _first_token(experiment_name)
    is_baseline = 'baseline' in str(experiment_name).lower()

    base = token_to_base[first_token]
    if is_baseline:
        return _adjust_lightness(base, 0.55)  # darker for baseline
    return _adjust_lightness(base, 1.35)      # brighter for non-baseline

# filter experiments containing 'adam'
df_adam = df[df['experiment'].str.contains('adam', case=False, na=False)]

if df_adam.empty:
    print("No experiments with 'adam' found in 'experiment' column.")
else:
    token_order = sorted({str(name).split('_')[0].lower() for name in df_adam['experiment'].unique()})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for name, grp in df_adam.groupby('experiment'):
        color = experiment_color(name, token_to_base)
        axes[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
        axes[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('train_loss')
    axes[0].set_title("Train Loss (experiments containing 'adam')")
    axes[0].legend(fontsize='small', loc='best')
    axes[0].grid(True)

    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('test_accuracy')
    axes[1].set_title("Test Accuracy (experiments containing 'adam')")
    axes[1].legend(fontsize='small', loc='best')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %%
# filter experiments containing 'adam' but exclude any with 'vit'
df_adam_no_vit = df[
    df['experiment'].str.contains('adam', case=False, na=False) &
    ~df['experiment'].str.contains('vit', case=False, na=False)
]

if df_adam_no_vit.empty:
    print("No 'adam' experiments found after excluding ViT.")
else:
    token_order = sorted({_first_token(name) for name in df_adam_no_vit['experiment'].unique()})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for name, grp in df_adam_no_vit.groupby('experiment'):
        color = experiment_color(name, token_to_base)
        axes[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
        axes[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('train_loss')
    axes[0].set_title("Train Loss (adam, excluding ViT)")
    axes[0].legend(fontsize='small', loc='best')
    axes[0].grid(True)

    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('test_accuracy')
    axes[1].set_title("Test Accuracy (adam, excluding ViT)")
    axes[1].legend(fontsize='small', loc='best')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %%
# filter experiments containing 'sgd' but exclude any with 'vit'
df_sgd_no_vit = df[
    df['experiment'].str.contains('sgd', case=False, na=False) &
    ~df['experiment'].str.contains('vit', case=False, na=False)
]

if df_sgd_no_vit.empty:
    print("No 'sgd' experiments found after excluding ViT.")
else:
    token_order = sorted({_first_token(name) for name in df_sgd_no_vit['experiment'].unique()})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for name, grp in df_sgd_no_vit.groupby('experiment'):
        color = experiment_color(name, token_to_base)
        axes[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
        axes[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('train_loss')
    axes[0].set_title("Train Loss (sgd, excluding ViT)")
    axes[0].legend(fontsize='small', loc='best')
    axes[0].grid(True)

    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('test_accuracy')
    axes[1].set_title("Test Accuracy (sgd, excluding ViT)")
    axes[1].legend(fontsize='small', loc='best')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %%
# filter experiments containing 'rmsprop' but exclude any with 'vit'
df_rmsprop_no_vit = df[
    df['experiment'].str.contains('rmsprop', case=False, na=False) &
    ~df['experiment'].str.contains('vit', case=False, na=False)
]

# additional filtered set (excluding res101)
df_rmsprop_no_vit_res101 = df[
    df['experiment'].str.contains('rmsprop', case=False, na=False) &
    ~df['experiment'].str.contains('vit', case=False, na=False) &
    ~df['experiment'].str.contains('resnet101', case=False, na=False)
]

if df_rmsprop_no_vit.empty and df_rmsprop_no_vit_res101.empty:
    print("No 'rmsprop' experiments found after excluding ViT.")
else:
    # shared color mapping across both dataframes (same experiment -> same color)
    all_names = set(df_rmsprop_no_vit['experiment'].unique()).union(
        set(df_rmsprop_no_vit_res101['experiment'].unique())
    )
    token_order = sorted({_first_token(name) for name in all_names})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    # Figure 1: df_rmsprop_no_vit
    if not df_rmsprop_no_vit.empty:
        fig1, axes1 = plt.subplots(1, 2, figsize=(14, 5))
        for name, grp in df_rmsprop_no_vit.groupby('experiment'):
            color = experiment_color(name, token_to_base)
            axes1[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
            axes1[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

        axes1[0].set_xlabel('epoch')
        axes1[0].set_ylabel('train_loss')
        axes1[0].set_title("Train Loss (rmsprop, excluding ViT)")
        axes1[0].legend(fontsize='small', loc='best')
        axes1[0].grid(True)

        axes1[1].set_xlabel('epoch')
        axes1[1].set_ylabel('test_accuracy')
        axes1[1].set_title("Test Accuracy (rmsprop, excluding ViT)")
        axes1[1].legend(fontsize='small', loc='best')
        axes1[1].grid(True)

        plt.tight_layout()
        plt.show()
    else:
        print("df_rmsprop_no_vit is empty.")

    # Figure 2: df_rmsprop_no_vit_res101
    if not df_rmsprop_no_vit_res101.empty:
        fig2, axes2 = plt.subplots(1, 2, figsize=(14, 5))
        for name, grp in df_rmsprop_no_vit_res101.groupby('experiment'):
            color = experiment_color(name, token_to_base)
            axes2[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
            axes2[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

        axes2[0].set_xlabel('epoch')
        axes2[0].set_ylabel('train_loss')
        axes2[0].set_title("Train Loss (rmsprop, excluding ViT and res101)")
        axes2[0].legend(fontsize='small', loc='best')
        axes2[0].grid(True)

        axes2[1].set_xlabel('epoch')
        axes2[1].set_ylabel('test_accuracy')
        axes2[1].set_title("Test Accuracy (rmsprop, excluding ViT and res101)")
        axes2[1].legend(fontsize='small', loc='best')
        axes2[1].grid(True)

        plt.tight_layout()
        plt.show()
    else:
        print("df_rmsprop_no_vit_res101 is empty.")

# %%
def _last_token(experiment_name):
    parts = str(experiment_name).lower().split('_')
    return parts[-1] if parts else str(experiment_name).lower()

def experiment_color_last_token(experiment_name, token_to_base):
    last_token = _last_token(experiment_name)
    is_baseline = 'baseline' in str(experiment_name).lower()

    base = token_to_base[last_token]
    if is_baseline:
        return _adjust_lightness(base, 0.55)  # darker for baseline
    return _adjust_lightness(base, 1.35)      # brighter for non-baseline

# filter experiments containing 'vit'
df_vit = df[
    df['experiment'].str.contains('vit', case=False, na=False)
]

if df_vit.empty:
    print("No 'vit' experiments found.")
else:
    token_order = sorted({_last_token(name) for name in df_vit['experiment'].unique()})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for name, grp in df_vit.groupby('experiment'):
        color = experiment_color_last_token(name, token_to_base)
        axes[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
        axes[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('train_loss')
    axes[0].set_title("Train Loss (vit)")
    axes[0].legend(fontsize='small', loc='best')
    axes[0].grid(True)

    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('test_accuracy')
    axes[1].set_title("Test Accuracy (vit)")
    axes[1].legend(fontsize='small', loc='best')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()

# %%
# filter experiments containing 'vit'
df_vit = df[
    df['experiment'].str.contains('vit', case=False, na=False) &
    ~df['experiment'].str.contains('sgd', case=False, na=False)
]

if df_vit.empty:
    print("No 'vit' experiments found.")
else:
    token_order = sorted({_last_token(name) for name in df_vit['experiment'].unique()})
    cmap = plt.get_cmap('tab10')
    token_to_base = {token: cmap(i % 10) for i, token in enumerate(token_order)}

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    for name, grp in df_vit.groupby('experiment'):
        color = experiment_color_last_token(name, token_to_base)
        axes[0].plot(grp['epoch'], grp['train_loss'], marker='o', label=name, color=color)
        axes[1].plot(grp['epoch'], grp['test_accuracy'], marker='o', label=name, color=color)

    axes[0].set_xlabel('epoch')
    axes[0].set_ylabel('train_loss')
    axes[0].set_title("Train Loss (vit)")
    axes[0].legend(fontsize='small', loc='best')
    axes[0].grid(True)

    axes[1].set_xlabel('epoch')
    axes[1].set_ylabel('test_accuracy')
    axes[1].set_title("Test Accuracy (vit)")
    axes[1].legend(fontsize='small', loc='best')
    axes[1].grid(True)

    plt.tight_layout()
    plt.show()
